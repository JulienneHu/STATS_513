# %% [markdown]
# ## Final Project

# %% [markdown]
# ## Abstract

# %%
library(ggplot2)
library(ggpubr)
library(GGally)
library(dplyr)
library(tidyr)
library(moments)
library(car)
library(faraway)
library(faraway)
library(leaps)
library(pls)
library(MASS)
library(Metrics)
library(lars)

# %% [markdown]
# 1 $Life.expectancy$: Life expectancy in years.\
# 2 $Status$: Developing status for each country with 2-levels:\
# – Developed\
# – Developing\
# 3 $infant.deaths$: Number of infant deaths per 1000 population; value should be less than or equal to 1000.\
# 4 $Alcohol$: recorded per capita (15+) consumption (in litres of pure alcohol).\
# 5 $Hepatitis.B$: Hepatitis B (HepB) immunization coverage among 1-year-olds (%).\
# 6 $BMI$: Average Body Mass Index of entire population.\
# 7 $under.five.deaths$: Number of under-five deaths per 1000 population; value should be less than or equal to 1000.\
# 8 $Polio$: Polio (Pol3) immunization coverage among 1-year-olds (%).\
# 9 $Diphtheria$: Diphtheria tetanus toxoid and pertussis (DTP3) immunization coverage among 1-year-olds (%).\
# 10 $GDP$ : Gross Domestic Product per capita (in USD).\
# 11 $Schooling$: Number of years of Schooling (in years).

# %%
# read data from RData file
life = get(load('FinalExam.RData'))

# change data type
life$Status = factor(life$Status)

# %%
head(life)
dim(life)
# Out:
#    Life.expectancy Status     infant.deaths Alcohol Hepatitis.B BMI
# 6  58.8            Developing 74            0.01    66          16.7
# 22 76.2            Developing  1            5.28    99          54.3
# 38 74.7            Developing 21            0.45    95          53.9
# 54 49.6            Developing 78            7.80    77           2.4
# 70 75.6            Developing  0            7.84    98          44.4
# 86 75.5            Developing 10            8.15    94          59.8
#    under.five.deaths Polio Diphtheria GDP        Schooling
# 6  102               66    66           553.3289  9.2
# 22   1               99    99           494.3588 12.5
# 38  24               95    95          4463.3947 13.6
# 54 121               81    77          3529.5348  9.0
# 70   0               99    98         12126.8761 14.1
# 86  11               95    94          1276.2650 16.8
# [1] 183  11

# %%
hst = ggplot(data = life, aes(x=Life.expectancy,fill=Status))+geom_histogram()
box = ggplot(data=life,aes(x=Status,y=Life.expectancy,fill=Status))+geom_boxplot(outlier.size = 2,outlier.shape = 2)
ggarrange(hst, box, labels = c("histogram", "boxplot"),ncol = 2, nrow = 1)
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %% [markdown]
# ## 1 Introduction and Data Summary (10 points)
# In this report, our scientific goal is to understand how these health and economical factors impact
# the life expectancy of countries. Firstly, check the missingness or entry errors of the data. Report
# notable issues. Report the missing data and potential data entry errors. If you find any missing
# data and potential data entry errors, please clean the dataset by deleting the countries with missing
# data and potential data entry in your analysis.
# Secondly, summarize the demographics in this sample by reporting summary statistics for each
# variable. Remember to code categorical data appropriately.
# Thirdly, comment the collinearity between predictors in the training dataset.

# %% [markdown]
# #### (1) Check the missingness or entry errors of the data

# %% [markdown]
# ##### a. missingness

# %%
# check missing values
life[!complete.cases(life),]
# Out:
#      Life.expectancy Status     infant.deaths Alcohol Hepatitis.B BMI
# 166  75.0            Developing   0            9.19   98          61.3
# 310  68.7            Developing   9            3.95   91          49.3
# 438  51.5            Developing  60            3.15   85          25.0
# 614  62.0            Developing   7            3.53   74          24.5
# 695  77.5            Developed    0           12.69   99          63.6
# 711  69.0            Developing   8            3.12   93           3.3
# 727  57.4            Developing 239            1.81    6          19.1
# 743  79.2            Developed    0           10.28   NA          57.0
# 808  70.0            Developing  54            0.22   97          57.0
# 840  56.1            Developing   3            9.93   NA          22.1
# 920  79.9            Developing   0            9.72   NA           6.2
# 968  59.3            Developing   3            3.48   97          24.1
# 1128 36.3            Developing  23            5.76   NA          44.2
# 1160 74.5            Developed    0           10.78   NA          61.7
# 1176 81.8            Developed    0            8.25   NA          58.9
# 1224 74.1            Developing  22            0.03   99          53.6
# 1320 83.0            Developed    3            6.90   NA          26.9
# 1416 68.8            Developing   4            2.73   96           4.7
# 1432 63.6            Developing  10            5.95   74          18.0
# 1705 68.7            Developing   0            1.76   88          66.4
# 1835 88.0            Developed    1            9.33   NA          59.3
# 1916 81.0            Developed    0            6.59   NA          58.9
# 2093 87.0            Developing   2            9.23   94          29.5
# 2109 68.8            Developing   1            8.25   98           5.4
# 2174 74.2            Developing   0           10.87   97          43.8
# 2190 72.5            Developing   0            7.00   99          49.3
# 2335 75.1            Developed    0           10.13   99          55.9
# 2351 79.5            Developed    0           10.32   NA          57.0
# 2383 52.4            Developing  52            0.01   NA          22.0
# 2415 55.0            Developing  27              NA   NA            NA
# 2463 62.5            Developing  62            1.77   75            NA
# 2511 81.5            Developed    0            7.20   NA          57.3
# 2527 82.3            Developed    0           10.01   NA          55.4
# 2543 73.7            Developing   7            0.78   84          52.3
# 2591 74.7            Developing   0            1.47    9          57.4
# 2768 82.0            Developed    3           10.88   NA          63.6
# 2784 57.5            Developing  89            4.19   91           2.7
# 2800 78.7            Developed   25            8.55   92          66.9
# 2864 73.7            Developing   9            7.22   78          59.3
# 2880 75.2            Developing  29            3.93   88          14.0
# 2896 64.4            Developing  35            0.06   76          37.2
#      under.five.deaths Polio Diphtheria GDP        Schooling
# 166    0               97    99                 NA 12.6
# 310   12                9    91                 NA 13.8
# 438   84               81    85                 NA   NA
# 614   10               72    74                 NA 10.5
# 695    0               99    99                 NA   NA
# 711   10               99    93                 NA   NA
# 727  321               76     6                 NA   NA
# 743    0                9     9          5841.4112 16.8
# 808   64               97    97                 NA 12.2
# 840    4               59    44         17136.4457  9.2
# 920    0               99    99          4622.4152 16.8
# 968    6               97    97                 NA  8.8
# 1128  58               66    66           662.2795  8.6
# 1160   1               99    99          1325.5338 15.3
# 1176   0               96    96         41676.4453 18.4
# 1224  26               99    99                 NA 12.9
# 1320   4               98    97          4457.6764 15.1
# 1416   4               88    96                 NA 12.2
# 1432  13               76    74                 NA  9.6
# 1705   0               85    85                 NA 11.5
# 1835   1               97    97          5338.2548 17.0
# 1916   0               93    93         87646.7535 17.4
# 2093   2               95    94                 NA   NA
# 2109   1               97     9                 NA   NA
# 2174   0               97    97                 NA 12.8
# 2190   0               99    99                 NA 13.3
# 2335   0               99    99                 NA 15.0
# 2351   0               96    96         23437.4722 16.9
# 2383  83               49    45                 NA   NA
# 2415  41               NA    NA          1562.2393  0.0
# 2463  92                9     9          1476.4789  7.0
# 2511   0               98    98          5276.2559 15.8
# 2527   0               96    95         74276.7184 15.4
# 2543   9               83     8                 NA 11.7
# 2591   0               95    95                 NA 13.0
# 2768   4               94    94                 NA   NA
# 2784 131               94    91                 NA   NA
# 2800  30               93    95                 NA   NA
# 2864  10               74    78                 NA 14.0
# 2880  35               94    93                 NA 11.9
# 2896  45               77    76                 NA  8.5

# %% [markdown]
# There are 41 rows in our dataframe that contains missing values.

# %%
# remove rows containing na
life <- na.omit(life)

# %% [markdown]
# ##### b.entry errors

# %%
# summarize data
summary(life)
# Out:
#  Life.expectancy        Status    infant.deaths        Alcohol
#  Min.   :48.10   Developed : 19   Min.   :   0.00   Min.   : 0.010
#  1st Qu.:63.55   Developing:123   1st Qu.:   0.00   1st Qu.: 1.173
#  Median :72.80                    Median :   2.50   Median : 3.895
#  Mean   :69.88                    Mean   :  30.45   Mean   : 4.639
#  3rd Qu.:75.60                    3rd Qu.:  20.75   3rd Qu.: 7.565
#  Max.   :89.00                    Max.   :1200.00   Max.   :14.970
#   Hepatitis.B         BMI        under.five.deaths     Polio
#  Min.   : 7.00   Min.   : 2.20   Min.   :   0.00   Min.   : 7.00
#  1st Qu.:75.25   1st Qu.:19.12   1st Qu.:   1.00   1st Qu.:82.00
#  Median :92.00   Median :43.15   Median :   3.00   Median :93.50
#  Mean   :80.18   Mean   :37.87   Mean   :  41.92   Mean   :84.07
#  3rd Qu.:96.00   3rd Qu.:57.38   3rd Qu.:  24.00   3rd Qu.:97.00
#  Max.   :99.00   Max.   :75.20   Max.   :1600.00   Max.   :99.00
#    Diphtheria         GDP             Schooling
#  Min.   : 7.00   Min.   :    8.38   Min.   : 4.50
#  1st Qu.:82.00   1st Qu.:  602.66   1st Qu.:10.53
#  Median :93.00   Median : 1930.80   Median :12.60
#  Mean   :83.75   Mean   : 6265.66   Mean   :12.39
#  3rd Qu.:97.00   3rd Qu.: 5441.72   3rd Qu.:14.30
#  Max.   :99.00   Max.   :51874.85   Max.   :20.30

# %% [markdown]
# According to the description, we know that $infant.deaths$ and $under.five.deaths$ should be equal or less than 1000. However the maximum of $i$nfant.deaths$ is 1200.00 and the maximum of under.five.deaths$ is 1600.00. Therefor there are some entry errors for the two variables, we are supposed to filter these errors.

# %%
par(mfrow=c(1,2))
plot(life$infant.deaths)
plot(life$under.five.deaths)
# Out:
# plot without title

# %%
# filter the data
life = life %>% filter(infant.deaths <= 1000) %>% filter(under.five.deaths <= 1000)

par(mfrow=c(1,2))
plot(life$infant.deaths)
plot(life$under.five.deaths)
# Out:
# plot without title

# %% [markdown]
# #### (2) summarize the demographics

# %%
# numerical data
life_num = life %>% select_if(is.numeric)
ggcorr(life_num, label = T, label_size = 2, label_round = 2, hjust = 1, size = 3, 
       color = "royalblue", layout.exp = 5, low = "green3", mid = "gray95", high = "darkorange", name = "Correlation")
# Out:
# plot without title

# %% [markdown]
# The $Life.expectancy$ as dependent variable has somewhat strong positive correlation with $Schooling$, we are going to see it further on the model analysis. On the other hand, it has negative correlation with $Infant.death$, it is valid since $infant.death$ usually happens at a very young age.

# %%
# categorical data
life %>% group_by(Status) %>% summarise(count = n()) %>% mutate(percentage = paste0(round(count/sum(count)*100, 2), "%"))

ggplot(life, aes(Status, Life.expectancy, color = Status))+geom_boxplot(outlier.colour="black", outlier.shape=16,outlier.size=3, notch=FALSE)

summary(aov(Life.expectancy ~ Status, data = life))
# Out:
#   Status     count percentage
# 1 Developed   19   13.48%
# 2 Developing 122   86.52%
#              Df Sum Sq Mean Sq F value   Pr(>F)
# Status        1   2252  2252.5   36.46 1.34e-08 ***
# Residuals   139   8587    61.8
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# plot without title

# %% [markdown]
# The number of Developing Countries on this observations are way bigger than the Developed Countries. On the Development Status, it was clearly that distribution of higher $Life.expectancy$ lies on the Developed Countries, with a significant Median distance. As the $p$-value ANOVA Analysis is less than the significance level 0.05, we can conclude that there are significant differences of Life Expectancy between the Developed and Developing Countries.

# %% [markdown]
# #### (3) comment the colinearity between the data

# %%
train_data = life[1:115,]
test_data = life[-c(1:115),]
life_model <- lm(Life.expectancy ~., data = train_data)
summary(life_model)
# Out:
# Call:
# lm(formula = Life.expectancy ~ ., data = train_data)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -16.0755  -2.8057   0.3676   3.0179  10.4312
#
# Coefficients:
#                     Estimate Std. Error t value Pr(>|t|)
# (Intercept)        4.779e+01  3.425e+00  13.953  < 2e-16 ***
# StatusDeveloping  -2.796e+00  1.774e+00  -1.576  0.11800
# infant.deaths      1.545e-01  5.626e-02   2.746  0.00711 **
# Alcohol           -2.394e-01  1.692e-01  -1.415  0.16017
# Hepatitis.B       -2.170e-02  2.694e-02  -0.805  0.42249
# BMI                6.212e-02  2.675e-02   2.322  0.02217 *
# under.five.deaths -1.143e-01  3.960e-02  -2.885  0.00476 **
# Polio             -9.302e-03  3.099e-02  -0.300  0.76468
# Diphtheria         5.114e-02  4.166e-02   1.227  0.22241
# GDP                4.416e-05  5.318e-05   0.830  0.40817
# Schooling          1.754e+00  2.717e-01   6.456 3.49e-09 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 4.931 on 104 degrees of freedom
# Multiple R-squared:  0.7084,	Adjusted R-squared:  0.6803
# F-statistic: 25.26 on 10 and 104 DF,  p-value: < 2.2e-16

# %% [markdown]
# One of the first things we should notice is that the F-test for the regression tells us that the regression is significant, however some individuals predictor is not. This happens as a result of the predictors being highly correlated.

# %%
data.frame(vif(life_model))
# Out:
#                   vif.life_model.
# StatusDeveloping   1.874758
# infant.deaths     66.175794
# Alcohol            2.208582
# Hepatitis.B        2.018049
# BMI                1.554635
# under.five.deaths 67.467059
# Polio              2.295877
# Diphtheria         3.781750
# GDP                1.753947
# Schooling          3.220494

# %%
X = model.matrix(life_model)[, -1]
round(cor(X),2)
# Out:
#                   StatusDeveloping infant.deaths Alcohol Hepatitis.B BMI
# StatusDeveloping   1.00             0.15         -0.60   -0.06       -0.31
# infant.deaths      0.15             1.00         -0.12   -0.15       -0.27
# Alcohol           -0.60            -0.12          1.00    0.16        0.29
# Hepatitis.B       -0.06            -0.15          0.16    1.00        0.21
# BMI               -0.31            -0.27          0.29    0.21        1.00
# under.five.deaths  0.15             0.99         -0.11   -0.17       -0.27
# Polio             -0.18            -0.19          0.25    0.50        0.33
# Diphtheria        -0.18            -0.22          0.33    0.69        0.34
# GDP               -0.52            -0.16          0.40   -0.01        0.42
# Schooling         -0.50            -0.33          0.63    0.27        0.56
#                   under.five.deaths Polio Diphtheria GDP   Schooling
# StatusDeveloping   0.15             -0.18 -0.18      -0.52 -0.50
# infant.deaths      0.99             -0.19 -0.22      -0.16 -0.33
# Alcohol           -0.11              0.25  0.33       0.40  0.63
# Hepatitis.B       -0.17              0.50  0.69      -0.01  0.27
# BMI               -0.27              0.33  0.34       0.42  0.56
# under.five.deaths  1.00             -0.21 -0.25      -0.16 -0.34
# Polio             -0.21              1.00  0.74       0.20  0.45
# Diphtheria        -0.25              0.74  1.00       0.20  0.54
# GDP               -0.16              0.20  0.20       1.00  0.56
# Schooling         -0.34              0.45  0.54       0.56  1.00

# %% [markdown]
# The VIF of $infant.deaths$ and $under.five.deaths$ are 66.175794 and 67.467059 respectively. And the correlation between the two variables is 0.99. Both tell us that the two variables are highly corelated. This strong correlation indicates multicollinearity among them. Therefore, we are going to deselect $under.5.deaths$, with consideration that other variables seems more related with conditions during infants period.

# %% [markdown]
# ## 2 Data Analysis (20 points)
# Hint: Note that the training dataset is used to create the model, and the testing dataset is used
# to evaluate the model fitting. After selecting the final model, please remember to use the whole
# cleaned dataset to refit the selected model and interpret your results.

# %% [markdown]
# ### 2.1 Data Analysis A.1 (10 points)
# The investigator want to find the health and economical factors can significantly affect the life
# expectancy. Create a model to investigate the association between these health and economical
# factors and the life expectancy of countries. In this step, you do not need to consider interaction
# terms in your model. To build the final model to answer this question, you need to use model
# diagnostic tools to evaluate the model. If you find any problems in model diagnostic, you may
# consider the following tools to build final model\
# •Identify and deal with unusual points (leverage points, outliers, influential points)\
# •Variable transformation\
# •Variable selection\
# •Robust method\
# Please state your final model with justification. Check the performance of your final linear regression
# model. Summarize your findings from the final model.

# %%
## define plotting functions
plot_residuals <- function(model, model_name){
  par(mfrow=c(1,2))
  ## Residuals vs Fitted
  par(col.lab="white")
  plot(model, which=1)
  par(col.lab="black")
  title(xlab=paste("Fitted Values (", model_name, ")", sep=""), ylab="Residuals")
  ## Q-Q Plot
  par(col.lab="white")
  plot(model, which=2)
  par(col.lab="black")
  title(xlab=paste("Theoretical Quantiles (", model_name, ")", sep=""), ylab="Residuals")
}

# %% [markdown]
# ##### a.simple linear regression-remove under.five.deaths

# %%
mod1 <- lm(Life.expectancy ~ Status + infant.deaths + Alcohol+ Hepatitis.B 
            + BMI + Polio+ Diphtheria + GDP + Schooling, data = train_data)
summary(mod1)

train_predict1 <- predict.lm(mod1, train_data)
(train_mse_OLS1 <- mean((train_predict1 - train_data$Life.expectancy)^2))

test_predict1 = predict.lm(mod1, test_data)
(test_mse_OLS1 = mean((test_predict1 - test_data$Life.expectancy)^2))

plot_residuals(mod1, 'mod1')
ggplot (data = test_data, aes (x=Life.expectancy,y= test_predict1)) +
  geom_smooth(se=F,method = "lm",colour = "gray35") + geom_point() +
  ggtitle('Linear Regression: Ground Truth vs Predicted') +
  xlab('Ground Truth') +
  ylab('Predicted')
# Out:
# Call:
# lm(formula = Life.expectancy ~ Status + infant.deaths + Alcohol +
#     Hepatitis.B + BMI + Polio + Diphtheria + GDP + Schooling,
#     data = train_data)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -16.4151  -3.1769   0.5027   3.0220  10.6207
#
# Coefficients:
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)       4.603e+01  3.486e+00  13.205  < 2e-16 ***
# StatusDeveloping -3.051e+00  1.832e+00  -1.665   0.0989 .
# infant.deaths    -6.393e-03  7.686e-03  -0.832   0.4074
# Alcohol          -3.474e-01  1.707e-01  -2.036   0.0443 *
# Hepatitis.B      -1.495e-02  2.776e-02  -0.539   0.5913
# BMI               5.924e-02  2.765e-02   2.142   0.0345 *
# Polio            -6.419e-03  3.204e-02  -0.200   0.8416
# Diphtheria        5.843e-02  4.301e-02   1.359   0.1772
# GDP               3.875e-05  5.497e-05   0.705   0.4823
# Schooling         1.857e+00  2.785e-01   6.669 1.24e-09 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 5.1 on 105 degrees of freedom
# Multiple R-squared:  0.685,	Adjusted R-squared:  0.658
# F-statistic: 25.37 on 9 and 105 DF,  p-value: < 2.2e-16
# [1] 23.7446
# [1] 40.5546
# `geom_smooth()` using formula 'y ~ x'
# Plot with title “”
# plot without title

# %% [markdown]
# To find the influential points, use cook's distance:

# %%
n =dim(life)[1]
p = dim(life)[2]
cook=cooks.distance(mod1)
cook[which(cook > 10/(n-p-1))]
halfnorm(cook, 2, ylab="Cook's distances")
# Out:
#         91         97         99
# 0.08399898 0.32329669 0.07802908
# plot without title

# %% [markdown]
# Omit the outlier and fit a new modeL:

# %%
mod1_new=lm(Life.expectancy ~ Status + infant.deaths + Alcohol+ Hepatitis.B 
            + BMI + Polio+ Diphtheria + GDP + Schooling, data = train_data[-c(91,97,99),])
summary(mod1_new)
train_predict1_new <- predict.lm(mod1_new, train_data)
(train_mse_OLS1_new <- mean((train_predict1_new - train_data$Life.expectancy)^2))

test_predict1_new = predict.lm(mod1_new, test_data)
(test_mse_OLS1_new = mean((test_predict1_new - test_data$Life.expectancy)^2))

plot_residuals(mod1, 'mod1')
ggplot (data = test_data, aes (x=Life.expectancy,y= test_predict1_new)) +
  geom_smooth(se=F,method = "lm",colour = "gray35") + geom_point() +
  ggtitle('Linear Regression: Ground Truth vs Predicted') +
  xlab('Ground Truth') +
  ylab('Predicted')
# Out:
# Call:
# lm(formula = Life.expectancy ~ Status + infant.deaths + Alcohol +
#     Hepatitis.B + BMI + Polio + Diphtheria + GDP + Schooling,
#     data = train_data[-c(91, 97, 99), ])
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -16.1926  -3.2228   0.5078   2.9211  10.5012
#
# Coefficients:
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)       4.498e+01  3.528e+00  12.749  < 2e-16 ***
# StatusDeveloping -2.752e+00  1.824e+00  -1.508   0.1346
# infant.deaths    -5.589e-04  1.520e-02  -0.037   0.9707
# Alcohol          -2.794e-01  1.725e-01  -1.620   0.1084
# Hepatitis.B      -3.400e-02  3.026e-02  -1.123   0.2639
# BMI               6.295e-02  2.785e-02   2.260   0.0259 *
# Polio            -2.418e-03  3.201e-02  -0.076   0.9399
# Diphtheria        7.947e-02  4.631e-02   1.716   0.0892 .
# GDP               3.361e-05  5.450e-05   0.617   0.5388
# Schooling         1.827e+00  2.796e-01   6.533 2.57e-09 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 5.05 on 102 degrees of freedom
# Multiple R-squared:  0.6857,	Adjusted R-squared:  0.6579
# F-statistic: 24.72 on 9 and 102 DF,  p-value: < 2.2e-16
# [1] 24.06977
# [1] 42.18034
# `geom_smooth()` using formula 'y ~ x'
# Plot with title “”
# plot without title

# %% [markdown]
# ##### b. simple linear regression-add new features

# %%
# 9 + 8 + 8 + 7 + 6 + 5 + 4 + 3 + 2 + 1 = 9 + 32 + 28 = 53 
mod2 <- lm(formula = Life.expectancy ~ Status + infant.deaths + Alcohol+ Hepatitis.B 
            + BMI + Polio + Diphtheria + GDP + Schooling 
            + I(infant.deaths ^ 2) + I(Alcohol ^ 2) + I(Hepatitis.B ^ 2) + I(BMI ^2)
            + I(Polio ^ 2) + I(Diphtheria ^ 2) + I(GDP ^ 2) + I(Schooling ^ 2)
            + Status * infant.deaths + Status * Alcohol + Status * Hepatitis.B
            + Status * BMI + Status * Polio + Status * Diphtheria + Status * GDP + Status * Schooling
            + infant.deaths * Alcohol + infant.deaths * Hepatitis.B + infant.deaths * BMI
            + infant.deaths * Polio + infant.deaths * Diphtheria + infant.deaths * GDP + infant.deaths * Schooling
            + Alcohol * Hepatitis.B + Alcohol * BMI + Alcohol * Polio
            + Alcohol * Diphtheria + Alcohol * GDP + Alcohol * Schooling
            + Hepatitis.B * BMI + Hepatitis.B * Polio
            + Hepatitis.B * Diphtheria + Hepatitis.B * GDP + Hepatitis.B * Schooling
            + BMI * Polio + BMI * Diphtheria 
            + BMI * GDP + BMI * Schooling
            + Polio * Diphtheria + Polio * GDP + Polio * Schooling
            + Diphtheria * GDP + Diphtheria * Schooling + GDP * Schooling, data = train_data)
summary(mod2)
train_predict2 <- predict.lm(mod2, train_data)
(train_mse_OLS2 <- mean((train_predict2 - train_data$Life.expectancy)^2))

test_predict2 = predict.lm(mod2, test_data)
(test_mse_OLS2 = mean((test_predict2 - test_data$Life.expectancy)^2))

plot_residuals(mod2, 'mod2')
ggplot (data = test_data, aes (x=Life.expectancy,y= test_predict2)) +
  geom_smooth(se=F,method = "lm",colour = "gray35") + geom_point() +
  ggtitle('Linear Regression: Ground Truth vs Predicted') +
  xlab('Ground Truth') +
  ylab('Predicted')
# Out:
# Call:
# lm(formula = Life.expectancy ~ Status + infant.deaths + Alcohol +
#     Hepatitis.B + BMI + Polio + Diphtheria + GDP + Schooling +
#     I(infant.deaths^2) + I(Alcohol^2) + I(Hepatitis.B^2) + I(BMI^2) +
#     I(Polio^2) + I(Diphtheria^2) + I(GDP^2) + I(Schooling^2) +
#     Status * infant.deaths + Status * Alcohol + Status * Hepatitis.B +
#     Status * BMI + Status * Polio + Status * Diphtheria + Status *
#     GDP + Status * Schooling + infant.deaths * Alcohol + infant.deaths *
#     Hepatitis.B + infant.deaths * BMI + infant.deaths * Polio +
#     infant.deaths * Diphtheria + infant.deaths * GDP + infant.deaths *
#     Schooling + Alcohol * Hepatitis.B + Alcohol * BMI + Alcohol *
#     Polio + Alcohol * Diphtheria + Alcohol * GDP + Alcohol *
#     Schooling + Hepatitis.B * BMI + Hepatitis.B * Polio + Hepatitis.B *
#     Diphtheria + Hepatitis.B * GDP + Hepatitis.B * Schooling +
#     BMI * Polio + BMI * Diphtheria + BMI * GDP + BMI * Schooling +
#     Polio * Diphtheria + Polio * GDP + Polio * Schooling + Diphtheria *
#     GDP + Diphtheria * Schooling + GDP * Schooling, data = train_data)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -15.4317  -1.1797   0.1141   2.1542   8.2411
#
# Coefficients:
#                                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)                     1.016e+02  4.182e+01   2.429  0.01811 *
# StatusDeveloping               -5.077e+01  4.066e+01  -1.249  0.21651
# infant.deaths                  -3.097e+00  2.170e+00  -1.427  0.15875
# Alcohol                        -3.619e+00  3.101e+00  -1.167  0.24785
# Hepatitis.B                     1.434e+00  1.681e+00   0.853  0.39716
# BMI                             6.224e-01  3.640e-01   1.710  0.09234 .
# Polio                          -3.036e+00  1.974e+00  -1.538  0.12914
# Diphtheria                      1.402e+00  2.515e+00   0.558  0.57921
# GDP                             4.543e-04  1.733e-03   0.262  0.79412
# Schooling                      -1.373e+00  3.013e+00  -0.456  0.65027
# I(infant.deaths^2)              5.217e-05  1.355e-04   0.385  0.70148
# I(Alcohol^2)                   -4.226e-02  5.238e-02  -0.807  0.42292
# I(Hepatitis.B^2)                3.800e-03  5.522e-03   0.688  0.49401
# I(BMI^2)                        3.698e-03  1.885e-03   1.961  0.05442 .
# I(Polio^2)                      2.234e-03  4.174e-03   0.535  0.59451
# I(Diphtheria^2)                 4.432e-03  7.564e-03   0.586  0.56012
# I(GDP^2)                        2.126e-09  8.744e-09   0.243  0.80870
# I(Schooling^2)                  5.501e-02  1.338e-01   0.411  0.68234
# StatusDeveloping:infant.deaths  2.732e+00  2.166e+00   1.261  0.21211
# StatusDeveloping:Alcohol        2.254e+00  1.598e+00   1.411  0.16344
# StatusDeveloping:Hepatitis.B    3.435e-01  4.249e-01   0.808  0.42200
# StatusDeveloping:BMI           -3.043e-02  1.460e-01  -0.208  0.83557
# StatusDeveloping:Polio          1.342e+00  1.816e+00   0.739  0.46270
# StatusDeveloping:Diphtheria    -1.864e+00  1.813e+00  -1.028  0.30790
# StatusDeveloping:GDP            1.647e-04  3.322e-04   0.496  0.62176
# StatusDeveloping:Schooling      2.769e+00  2.306e+00   1.201  0.23448
# infant.deaths:Alcohol          -2.181e-02  1.015e-02  -2.149  0.03563 *
# infant.deaths:Hepatitis.B      -4.458e-02  1.792e-02  -2.487  0.01562 *
# infant.deaths:BMI               1.145e-04  2.243e-03   0.051  0.95946
# infant.deaths:Polio             2.148e-02  7.532e-03   2.852  0.00592 **
# infant.deaths:Diphtheria        2.579e-02  1.526e-02   1.691  0.09603 .
# infant.deaths:GDP              -5.778e-06  9.144e-06  -0.632  0.52982
# infant.deaths:Schooling         1.848e-02  1.352e-02   1.367  0.17653
# Alcohol:Hepatitis.B            -3.297e-02  6.317e-02  -0.522  0.60359
# Alcohol:BMI                     2.729e-03  1.354e-02   0.202  0.84091
# Alcohol:Polio                  -5.710e-02  7.358e-02  -0.776  0.44071
# Alcohol:Diphtheria              1.032e-01  9.819e-02   1.051  0.29742
# Alcohol:GDP                     3.436e-05  3.398e-05   1.011  0.31589
# Alcohol:Schooling               1.755e-02  1.699e-01   0.103  0.91806
# Hepatitis.B:BMI                -3.288e-03  2.356e-03  -1.395  0.16797
# Hepatitis.B:Polio              -1.979e-02  1.357e-02  -1.458  0.14987
# Hepatitis.B:Diphtheria         -6.579e-03  9.437e-03  -0.697  0.48835
# Hepatitis.B:GDP                 4.237e-06  8.901e-06   0.476  0.63580
# Hepatitis.B:Schooling           4.391e-02  7.634e-02   0.575  0.56727
# BMI:Polio                      -1.259e-03  8.265e-03  -0.152  0.87945
# BMI:Diphtheria                  1.502e-03  9.878e-03   0.152  0.87966
# BMI:GDP                         1.074e-06  8.512e-06   0.126  0.89996
# BMI:Schooling                  -4.230e-02  2.484e-02  -1.703  0.09365 .
# Polio:Diphtheria                1.923e-02  1.259e-02   1.528  0.13160
# Polio:GDP                       1.643e-05  7.208e-05   0.228  0.82040
# Polio:Schooling                 1.282e-01  5.087e-02   2.521  0.01434 *
# Diphtheria:GDP                 -2.949e-05  7.245e-05  -0.407  0.68545
# Diphtheria:Schooling           -1.707e-01  1.001e-01  -1.704  0.09341 .
# GDP:Schooling                   7.164e-06  6.519e-05   0.110  0.91286
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 4.591 on 61 degrees of freedom
# Multiple R-squared:  0.8517,	Adjusted R-squared:  0.7229
# F-statistic:  6.61 on 53 and 61 DF,  p-value: 6.244e-12
# [1] 11.17898
# [1] 657.7469
# `geom_smooth()` using formula 'y ~ x'
# Plot with title “”
# plot without title

# %% [markdown]
# ##### c. AIC

# %%
AICSelect = step(mod2)
# Out:
# Start:  AIC=385.61
# Life.expectancy ~ Status + infant.deaths + Alcohol + Hepatitis.B +
#     BMI + Polio + Diphtheria + GDP + Schooling + I(infant.deaths^2) +
#     I(Alcohol^2) + I(Hepatitis.B^2) + I(BMI^2) + I(Polio^2) +
#     I(Diphtheria^2) + I(GDP^2) + I(Schooling^2) + Status * infant.deaths +
#     Status * Alcohol + Status * Hepatitis.B + Status * BMI +
#     Status * Polio + Status * Diphtheria + Status * GDP + Status *
#     Schooling + infant.deaths * Alcohol + infant.deaths * Hepatitis.B +
#     infant.deaths * BMI + infant.deaths * Polio + infant.deaths *
#     Diphtheria + infant.deaths * GDP + infant.deaths * Schooling +
#     Alcohol * Hepatitis.B + Alcohol * BMI + Alcohol * Polio +
#     Alcohol * Diphtheria + Alcohol * GDP + Alcohol * Schooling +
#     Hepatitis.B * BMI + Hepatitis.B * Polio + Hepatitis.B * Diphtheria +
#     Hepatitis.B * GDP + Hepatitis.B * Schooling + BMI * Polio +
#     BMI * Diphtheria + BMI * GDP + BMI * Schooling + Polio *
#     Diphtheria + Polio * GDP + Polio * Schooling + Diphtheria *
#     GDP + Diphtheria * Schooling + GDP * Schooling
#
#                             Df Sum of Sq    RSS    AIC
# - infant.deaths:BMI          1     0.055 1285.6 383.62
# - Alcohol:Schooling          1     0.225 1285.8 383.63
# - GDP:Schooling              1     0.254 1285.8 383.64
# - BMI:GDP                    1     0.336 1285.9 383.64
# - BMI:Diphtheria             1     0.487 1286.1 383.66
# - BMI:Polio                  1     0.489 1286.1 383.66
# - Alcohol:BMI                1     0.856 1286.4 383.69
# - Status:BMI                 1     0.916 1286.5 383.70
# - Polio:GDP                  1     1.096 1286.7 383.71
# - I(GDP^2)                   1     1.246 1286.8 383.73
# - I(infant.deaths^2)         1     3.126 1288.7 383.89
# - Diphtheria:GDP             1     3.491 1289.1 383.93
# - I(Schooling^2)             1     3.564 1289.2 383.93
# - Hepatitis.B:GDP            1     4.774 1290.4 384.04
# - Status:GDP                 1     5.182 1290.8 384.08
# - Alcohol:Hepatitis.B        1     5.742 1291.3 384.13
# - I(Polio^2)                 1     6.035 1291.6 384.15
# - Hepatitis.B:Schooling      1     6.973 1292.6 384.24
# - I(Diphtheria^2)            1     7.234 1292.8 384.26
# - infant.deaths:GDP          1     8.415 1294.0 384.36
# - I(Hepatitis.B^2)           1     9.978 1295.6 384.50
# - Hepatitis.B:Diphtheria     1    10.243 1295.8 384.53
# - Status:Polio               1    11.512 1297.1 384.64
# - Alcohol:Polio              1    12.693 1298.3 384.74
# - I(Alcohol^2)               1    13.718 1299.3 384.83
# - Status:Hepatitis.B         1    13.773 1299.4 384.84
# - Alcohol:GDP                1    21.552 1307.1 385.53
# - Status:Diphtheria          1    22.282 1307.9 385.59
# <none>                                   1285.6 385.61
# - Alcohol:Diphtheria         1    23.278 1308.9 385.68
# - Status:Schooling           1    30.387 1316.0 386.30
# - Status:infant.deaths       1    33.512 1319.1 386.57
# - infant.deaths:Schooling    1    39.403 1325.0 387.09
# - Hepatitis.B:BMI            1    41.034 1326.6 387.23
# - Status:Alcohol             1    41.936 1327.5 387.31
# - Hepatitis.B:Polio          1    44.822 1330.4 387.56
# - Polio:Diphtheria           1    49.226 1334.8 387.94
# - infant.deaths:Diphtheria   1    60.230 1345.8 388.88
# - BMI:Schooling              1    61.126 1346.7 388.96
# - Diphtheria:Schooling       1    61.217 1346.8 388.96
# - I(BMI^2)                   1    81.067 1366.7 390.65
# - infant.deaths:Alcohol      1    97.314 1382.9 392.01
# - infant.deaths:Hepatitis.B  1   130.390 1416.0 394.72
# - Polio:Schooling            1   133.915 1419.5 395.01
# - infant.deaths:Polio        1   171.458 1457.0 398.01
#
# Step:  AIC=383.62
# Life.expectancy ~ Status + infant.deaths + Alcohol + Hepatitis.B +
#     BMI + Polio + Diphtheria + GDP + Schooling + I(infant.deaths^2) +
#     I(Alcohol^2) + I(Hepatitis.B^2) + I(BMI^2) + I(Polio^2) +
#     I(Diphtheria^2) + I(GDP^2) + I(Schooling^2) + Status:infant.deaths +
#     Status:Alcohol + Status:Hepatitis.B + Status:BMI + Status:Polio +
#     Status:Diphtheria + Status:GDP + Status:Schooling + infant.deaths:Alcohol +
#     infant.deaths:Hepatitis.B + infant.deaths:Polio + infant.deaths:Diphtheria +
#     infant.deaths:GDP + infant.deaths:Schooling + Alcohol:Hepatitis.B +
#     Alcohol:BMI + Alcohol:Polio + Alcohol:Diphtheria + Alcohol:GDP +
#     Alcohol:Schooling + Hepatitis.B:BMI + Hepatitis.B:Polio +
#     Hepatitis.B:Diphtheria + Hepatitis.B:GDP + Hepatitis.B:Schooling +
#     BMI:Polio + BMI:Diphtheria + BMI:GDP + BMI:Schooling + Polio:Diphtheria +
#     Polio:GDP + Polio:Schooling + Diphtheria:GDP + Diphtheria:Schooling +
#     GDP:Schooling
#
#                             Df Sum of Sq    RSS    AIC
# - Alcohol:Schooling          1     0.214 1285.8 381.64
# - GDP:Schooling              1     0.246 1285.9 381.64
# - BMI:GDP                    1     0.396 1286.0 381.65
# - BMI:Diphtheria             1     0.532 1286.2 381.67
# - BMI:Polio                  1     0.534 1286.2 381.67
# - Status:BMI                 1     0.875 1286.5 381.70
# - Alcohol:BMI                1     0.936 1286.6 381.70
# - Polio:GDP                  1     1.182 1286.8 381.72
# - I(GDP^2)                   1     1.252 1286.9 381.73
# - Diphtheria:GDP             1     3.602 1289.2 381.94
# - I(infant.deaths^2)         1     3.609 1289.2 381.94
# - I(Schooling^2)             1     3.684 1289.3 381.95
# - Hepatitis.B:GDP            1     4.723 1290.4 382.04
# - Status:GDP                 1     5.128 1290.8 382.08
# - Alcohol:Hepatitis.B        1     5.707 1291.3 382.13
# - I(Polio^2)                 1     5.992 1291.6 382.15
# - Hepatitis.B:Schooling      1     6.951 1292.6 382.24
# - I(Diphtheria^2)            1     7.217 1292.9 382.26
# - infant.deaths:GDP          1     8.549 1294.2 382.38
# - I(Hepatitis.B^2)           1     9.939 1295.6 382.50
# - Hepatitis.B:Diphtheria     1    10.215 1295.8 382.53
# - Status:Polio               1    11.467 1297.1 382.64
# - Alcohol:Polio              1    13.136 1298.8 382.79
# - I(Alcohol^2)               1    13.699 1299.3 382.84
# - Status:Hepatitis.B         1    13.743 1299.4 382.84
# - Alcohol:GDP                1    21.565 1307.2 383.53
# - Status:Diphtheria          1    22.244 1307.9 383.59
# <none>                                   1285.6 383.62
# - Alcohol:Diphtheria         1    23.319 1309.0 383.69
# - Status:Schooling           1    30.350 1316.0 384.30
# - Status:infant.deaths       1    33.525 1319.2 384.58
# - Hepatitis.B:BMI            1    41.007 1326.6 385.23
# - infant.deaths:Schooling    1    41.700 1327.3 385.29
# - Status:Alcohol             1    41.881 1327.5 385.31
# - Hepatitis.B:Polio          1    46.601 1332.2 385.71
# - Polio:Diphtheria           1    51.587 1337.2 386.14
# - Diphtheria:Schooling       1    61.185 1346.8 386.97
# - infant.deaths:Diphtheria   1    61.536 1347.2 387.00
# - BMI:Schooling              1    69.771 1355.4 387.70
# - I(BMI^2)                   1    85.051 1370.7 388.99
# - infant.deaths:Alcohol      1    98.318 1384.0 390.09
# - infant.deaths:Hepatitis.B  1   132.750 1418.4 392.92
# - Polio:Schooling            1   136.964 1422.6 393.26
# - infant.deaths:Polio        1   173.900 1459.5 396.21
#
# Step:  AIC=381.64
# Life.expectancy ~ Status + infant.deaths + Alcohol + Hepatitis.B +
#     BMI + Polio + Diphtheria + GDP + Schooling + I(infant.deaths^2) +
#     I(Alcohol^2) + I(Hepatitis.B^2) + I(BMI^2) + I(Polio^2) +
#     I(Diphtheria^2) + I(GDP^2) + I(Schooling^2) + Status:infant.deaths +
#     Status:Alcohol + Status:Hepatitis.B + Status:BMI + Status:Polio +
#     Status:Diphtheria + Status:GDP + Status:Schooling + infant.deaths:Alcohol +
#     infant.deaths:Hepatitis.B + infant.deaths:Polio + infant.deaths:Diphtheria +
#     infant.deaths:GDP + infant.deaths:Schooling + Alcohol:Hepatitis.B +
#     Alcohol:BMI + Alcohol:Polio + Alcohol:Diphtheria + Alcohol:GDP +
#     Hepatitis.B:BMI + Hepatitis.B:Polio + Hepatitis.B:Diphtheria +
#     Hepatitis.B:GDP + Hepatitis.B:Schooling + BMI:Polio + BMI:Diphtheria +
#     BMI:GDP + BMI:Schooling + Polio:Diphtheria + Polio:GDP +
#     Polio:Schooling + Diphtheria:GDP + Diphtheria:Schooling +
#     GDP:Schooling
#
#                             Df Sum of Sq    RSS    AIC
# - GDP:Schooling              1     0.152 1286.0 379.65
# - BMI:GDP                    1     0.421 1286.3 379.68
# - BMI:Polio                  1     0.465 1286.3 379.68
# - BMI:Diphtheria             1     0.538 1286.4 379.69
# - Status:BMI                 1     0.736 1286.6 379.70
# - Polio:GDP                  1     1.175 1287.0 379.74
# - I(GDP^2)                   1     1.393 1287.2 379.76
# - Alcohol:BMI                1     1.566 1287.4 379.78
# - I(infant.deaths^2)         1     3.494 1289.3 379.95
# - Diphtheria:GDP             1     3.580 1289.4 379.96
# - Hepatitis.B:GDP            1     5.150 1291.0 380.10
# - Alcohol:Hepatitis.B        1     5.773 1291.6 380.15
# - I(Polio^2)                 1     5.955 1291.8 380.17
# - Status:GDP                 1     6.016 1291.9 380.17
# - Hepatitis.B:Schooling      1     7.145 1293.0 380.28
# - I(Diphtheria^2)            1     7.321 1293.2 380.29
# - I(Schooling^2)             1     9.489 1295.3 380.48
# - I(Hepatitis.B^2)           1     9.735 1295.6 380.51
# - Hepatitis.B:Diphtheria     1    10.144 1296.0 380.54
# - infant.deaths:GDP          1    10.162 1296.0 380.54
# - Status:Polio               1    11.322 1297.2 380.65
# - Alcohol:Polio              1    12.927 1298.8 380.79
# - Status:Hepatitis.B         1    14.092 1299.9 380.89
# - I(Alcohol^2)               1    17.922 1303.8 381.23
# - Status:Diphtheria          1    22.075 1307.9 381.60
# <none>                                   1285.8 381.64
# - Alcohol:Diphtheria         1    23.398 1309.2 381.71
# - Alcohol:GDP                1    26.017 1311.9 381.94
# - Status:infant.deaths       1    33.342 1319.2 382.58
# - Status:Schooling           1    35.375 1321.2 382.76
# - Status:Alcohol             1    42.801 1328.7 383.40
# - infant.deaths:Schooling    1    44.461 1330.3 383.55
# - Hepatitis.B:BMI            1    47.813 1333.7 383.84
# - Hepatitis.B:Polio          1    54.599 1340.5 384.42
# - Polio:Diphtheria           1    60.897 1346.8 384.96
# - Diphtheria:Schooling       1    62.413 1348.3 385.09
# - infant.deaths:Diphtheria   1    74.687 1360.5 386.13
# - BMI:Schooling              1    80.077 1365.9 386.59
# - I(BMI^2)                   1    87.747 1373.6 387.23
# - infant.deaths:Alcohol      1   112.998 1398.8 389.32
# - Polio:Schooling            1   137.207 1423.1 391.30
# - infant.deaths:Hepatitis.B  1   161.330 1447.2 393.23
# - infant.deaths:Polio        1   184.303 1470.2 395.04
#
# Step:  AIC=379.65
# Life.expectancy ~ Status + infant.deaths + Alcohol + Hepatitis.B +
#     BMI + Polio + Diphtheria + GDP + Schooling + I(infant.deaths^2) +
#     I(Alcohol^2) + I(Hepatitis.B^2) + I(BMI^2) + I(Polio^2) +
#     I(Diphtheria^2) + I(GDP^2) + I(Schooling^2) + Status:infant.deaths +
#     Status:Alcohol + Status:Hepatitis.B + Status:BMI + Status:Polio +
#     Status:Diphtheria + Status:GDP + Status:Schooling + infant.deaths:Alcohol +
#     infant.deaths:Hepatitis.B + infant.deaths:Polio + infant.deaths:Diphtheria +
#     infant.deaths:GDP + infant.deaths:Schooling + Alcohol:Hepatitis.B +
#     Alcohol:BMI + Alcohol:Polio + Alcohol:Diphtheria + Alcohol:GDP +
#     Hepatitis.B:BMI + Hepatitis.B:Polio + Hepatitis.B:Diphtheria +
#     Hepatitis.B:GDP + Hepatitis.B:Schooling + BMI:Polio + BMI:Diphtheria +
#     BMI:GDP + BMI:Schooling + Polio:Diphtheria + Polio:GDP +
#     Polio:Schooling + Diphtheria:GDP + Diphtheria:Schooling
#
#                             Df Sum of Sq    RSS    AIC
# - BMI:GDP                    1     0.559 1286.6 377.70
# - BMI:Polio                  1     0.646 1286.7 377.71
# - BMI:Diphtheria             1     0.677 1286.7 377.71
# - Status:BMI                 1     0.678 1286.7 377.71
# - Alcohol:BMI                1     1.521 1287.5 377.79
# - Polio:GDP                  1     1.538 1287.5 377.79
# - I(GDP^2)                   1     2.514 1288.5 377.88
# - I(infant.deaths^2)         1     3.633 1289.6 377.98
# - Diphtheria:GDP             1     4.096 1290.1 378.02
# - Hepatitis.B:GDP            1     5.338 1291.3 378.13
# - Alcohol:Hepatitis.B        1     5.670 1291.7 378.16
# - I(Polio^2)                 1     5.869 1291.9 378.18
# - Status:GDP                 1     6.576 1292.6 378.24
# - Hepatitis.B:Schooling      1     7.078 1293.1 378.28
# - I(Diphtheria^2)            1     7.650 1293.7 378.33
# - I(Hepatitis.B^2)           1     9.699 1295.7 378.52
# - infant.deaths:GDP          1    10.065 1296.1 378.55
# - Hepatitis.B:Diphtheria     1    10.476 1296.5 378.58
# - I(Schooling^2)             1    10.817 1296.8 378.61
# - Status:Polio               1    11.777 1297.8 378.70
# - Alcohol:Polio              1    13.384 1299.4 378.84
# - Status:Hepatitis.B         1    14.387 1300.4 378.93
# - I(Alcohol^2)               1    18.440 1304.4 379.29
# <none>                                   1286.0 379.65
# - Status:Diphtheria          1    23.368 1309.4 379.72
# - Alcohol:Diphtheria         1    23.565 1309.6 379.74
# - Status:infant.deaths       1    33.531 1319.5 380.61
# - Alcohol:GDP                1    44.296 1330.3 381.55
# - infant.deaths:Schooling    1    45.287 1331.3 381.63
# - Status:Alcohol             1    46.693 1332.7 381.75
# - Hepatitis.B:BMI            1    48.069 1334.1 381.87
# - Status:Schooling           1    53.577 1339.6 382.35
# - Hepatitis.B:Polio          1    54.488 1340.5 382.42
# - Polio:Diphtheria           1    60.907 1346.9 382.97
# - Diphtheria:Schooling       1    62.390 1348.4 383.10
# - infant.deaths:Diphtheria   1    74.952 1361.0 384.17
# - BMI:Schooling              1    80.119 1366.1 384.60
# - I(BMI^2)                   1    88.447 1374.5 385.30
# - infant.deaths:Alcohol      1   114.550 1400.5 387.46
# - Polio:Schooling            1   137.249 1423.2 389.31
# - infant.deaths:Hepatitis.B  1   161.980 1448.0 391.29
# - infant.deaths:Polio        1   184.838 1470.8 393.10
#
# Step:  AIC=377.7
# Life.expectancy ~ Status + infant.deaths + Alcohol + Hepatitis.B +
#     BMI + Polio + Diphtheria + GDP + Schooling + I(infant.deaths^2) +
#     I(Alcohol^2) + I(Hepatitis.B^2) + I(BMI^2) + I(Polio^2) +
#     I(Diphtheria^2) + I(GDP^2) + I(Schooling^2) + Status:infant.deaths +
#     Status:Alcohol + Status:Hepatitis.B + Status:BMI + Status:Polio +
#     Status:Diphtheria + Status:GDP + Status:Schooling + infant.deaths:Alcohol +
#     infant.deaths:Hepatitis.B + infant.deaths:Polio + infant.deaths:Diphtheria +
#     infant.deaths:GDP + infant.deaths:Schooling + Alcohol:Hepatitis.B +
#     Alcohol:BMI + Alcohol:Polio + Alcohol:Diphtheria + Alcohol:GDP +
#     Hepatitis.B:BMI + Hepatitis.B:Polio + Hepatitis.B:Diphtheria +
#     Hepatitis.B:GDP + Hepatitis.B:Schooling + BMI:Polio + BMI:Diphtheria +
#     BMI:Schooling + Polio:Diphtheria + Polio:GDP + Polio:Schooling +
#     Diphtheria:GDP + Diphtheria:Schooling
#
#                             Df Sum of Sq    RSS    AIC
# - BMI:Polio                  1     0.202 1286.8 375.72
# - BMI:Diphtheria             1     0.255 1286.8 375.72
# - Status:BMI                 1     0.894 1287.5 375.78
# - Polio:GDP                  1     1.028 1287.6 375.79
# - Alcohol:BMI                1     1.367 1287.9 375.82
# - I(infant.deaths^2)         1     3.770 1290.3 376.04
# - Diphtheria:GDP             1     4.905 1291.5 376.14
# - I(Polio^2)                 1     5.830 1292.4 376.22
# - Alcohol:Hepatitis.B        1     5.836 1292.4 376.22
# - I(GDP^2)                   1     6.168 1292.7 376.25
# - Hepatitis.B:GDP            1     6.799 1293.4 376.31
# - Hepatitis.B:Schooling      1     6.836 1293.4 376.31
# - I(Diphtheria^2)            1     7.130 1293.7 376.34
# - Status:GDP                 1     7.679 1294.2 376.39
# - Hepatitis.B:Diphtheria     1     9.963 1296.5 376.59
# - I(Hepatitis.B^2)           1    10.154 1296.7 376.61
# - I(Schooling^2)             1    10.709 1297.3 376.65
# - infant.deaths:GDP          1    10.997 1297.6 376.68
# - Status:Polio               1    11.284 1297.8 376.71
# - Alcohol:Polio              1    12.835 1299.4 376.84
# - Status:Hepatitis.B         1    15.170 1301.7 377.05
# - I(Alcohol^2)               1    18.193 1304.8 377.32
# <none>                                   1286.6 377.70
# - Alcohol:Diphtheria         1    23.031 1309.6 377.74
# - Status:Diphtheria          1    23.047 1309.6 377.74
# - Status:infant.deaths       1    34.778 1321.3 378.77
# - Alcohol:GDP                1    44.812 1331.4 379.64
# - infant.deaths:Schooling    1    46.413 1333.0 379.78
# - Hepatitis.B:BMI            1    48.898 1335.5 379.99
# - Status:Alcohol             1    51.471 1338.0 380.21
# - Status:Schooling           1    56.809 1343.4 380.67
# - Hepatitis.B:Polio          1    59.595 1346.2 380.91
# - Diphtheria:Schooling       1    62.513 1349.1 381.16
# - Polio:Diphtheria           1    65.109 1351.7 381.38
# - infant.deaths:Diphtheria   1    75.248 1361.8 382.24
# - BMI:Schooling              1    82.515 1369.1 382.85
# - I(BMI^2)                   1    87.998 1374.6 383.31
# - infant.deaths:Alcohol      1   115.567 1402.1 385.59
# - Polio:Schooling            1   140.593 1427.2 387.63
# - infant.deaths:Hepatitis.B  1   162.740 1449.3 389.40
# - infant.deaths:Polio        1   185.641 1472.2 391.20
#
# Step:  AIC=375.72
# Life.expectancy ~ Status + infant.deaths + Alcohol + Hepatitis.B +
#     BMI + Polio + Diphtheria + GDP + Schooling + I(infant.deaths^2) +
#     I(Alcohol^2) + I(Hepatitis.B^2) + I(BMI^2) + I(Polio^2) +
#     I(Diphtheria^2) + I(GDP^2) + I(Schooling^2) + Status:infant.deaths +
#     Status:Alcohol + Status:Hepatitis.B + Status:BMI + Status:Polio +
#     Status:Diphtheria + Status:GDP + Status:Schooling + infant.deaths:Alcohol +
#     infant.deaths:Hepatitis.B + infant.deaths:Polio + infant.deaths:Diphtheria +
#     infant.deaths:GDP + infant.deaths:Schooling + Alcohol:Hepatitis.B +
#     Alcohol:BMI + Alcohol:Polio + Alcohol:Diphtheria + Alcohol:GDP +
#     Hepatitis.B:BMI + Hepatitis.B:Polio + Hepatitis.B:Diphtheria +
#     Hepatitis.B:GDP + Hepatitis.B:Schooling + BMI:Diphtheria +
#     BMI:Schooling + Polio:Diphtheria + Polio:GDP + Polio:Schooling +
#     Diphtheria:GDP + Diphtheria:Schooling
#
#                             Df Sum of Sq    RSS    AIC
# - BMI:Diphtheria             1     0.054 1286.8 373.72
# - Status:BMI                 1     0.806 1287.6 373.79
# - Polio:GDP                  1     0.896 1287.7 373.80
# - Alcohol:BMI                1     1.533 1288.3 373.86
# - I(infant.deaths^2)         1     3.737 1290.5 374.05
# - Diphtheria:GDP             1     5.754 1292.5 374.23
# - I(GDP^2)                   1     6.303 1293.1 374.28
# - Alcohol:Hepatitis.B        1     7.165 1293.9 374.36
# - I(Diphtheria^2)            1     7.191 1294.0 374.36
# - Hepatitis.B:GDP            1     7.551 1294.3 374.39
# - Hepatitis.B:Schooling      1     7.583 1294.3 374.40
# - Status:GDP                 1     8.310 1295.1 374.46
# - I(Polio^2)                 1     9.664 1296.4 374.58
# - Hepatitis.B:Diphtheria     1     9.812 1296.6 374.59
# - I(Schooling^2)             1    10.508 1297.3 374.66
# - infant.deaths:GDP          1    11.146 1297.9 374.71
# - I(Hepatitis.B^2)           1    11.410 1298.2 374.74
# - Status:Polio               1    12.354 1299.1 374.82
# - Status:Hepatitis.B         1    16.039 1302.8 375.14
# - I(Alcohol^2)               1    20.044 1306.8 375.50
# - Alcohol:Polio              1    21.679 1308.4 375.64
# <none>                                   1286.8 375.72
# - Alcohol:Diphtheria         1    23.918 1310.7 375.84
# - Status:Diphtheria          1    25.487 1312.2 375.98
# - Status:infant.deaths       1    34.904 1321.7 376.80
# - Alcohol:GDP                1    44.611 1331.4 377.64
# - infant.deaths:Schooling    1    46.213 1333.0 377.78
# - Hepatitis.B:BMI            1    48.699 1335.5 377.99
# - Status:Alcohol             1    51.401 1338.2 378.22
# - Status:Schooling           1    56.643 1343.4 378.67
# - Hepatitis.B:Polio          1    62.655 1349.4 379.19
# - Diphtheria:Schooling       1    63.194 1350.0 379.23
# - Polio:Diphtheria           1    64.908 1351.7 379.38
# - infant.deaths:Diphtheria   1    75.145 1361.9 380.25
# - BMI:Schooling              1    82.479 1369.2 380.86
# - I(BMI^2)                   1    90.228 1377.0 381.51
# - infant.deaths:Alcohol      1   115.406 1402.2 383.60
# - Polio:Schooling            1   142.399 1429.2 385.79
# - infant.deaths:Hepatitis.B  1   163.478 1450.2 387.47
# - infant.deaths:Polio        1   190.655 1477.4 389.61
#
# Step:  AIC=373.72
# Life.expectancy ~ Status + infant.deaths + Alcohol + Hepatitis.B +
#     BMI + Polio + Diphtheria + GDP + Schooling + I(infant.deaths^2) +
#     I(Alcohol^2) + I(Hepatitis.B^2) + I(BMI^2) + I(Polio^2) +
#     I(Diphtheria^2) + I(GDP^2) + I(Schooling^2) + Status:infant.deaths +
#     Status:Alcohol + Status:Hepatitis.B + Status:BMI + Status:Polio +
#     Status:Diphtheria + Status:GDP + Status:Schooling + infant.deaths:Alcohol +
#     infant.deaths:Hepatitis.B + infant.deaths:Polio + infant.deaths:Diphtheria +
#     infant.deaths:GDP + infant.deaths:Schooling + Alcohol:Hepatitis.B +
#     Alcohol:BMI + Alcohol:Polio + Alcohol:Diphtheria + Alcohol:GDP +
#     Hepatitis.B:BMI + Hepatitis.B:Polio + Hepatitis.B:Diphtheria +
#     Hepatitis.B:GDP + Hepatitis.B:Schooling + BMI:Schooling +
#     Polio:Diphtheria + Polio:GDP + Polio:Schooling + Diphtheria:GDP +
#     Diphtheria:Schooling
#
#                             Df Sum of Sq    RSS    AIC
# - Status:BMI                 1     0.793 1287.6 371.80
# - Polio:GDP                  1     0.927 1287.8 371.81
# - Alcohol:BMI                1     1.533 1288.3 371.86
# - I(infant.deaths^2)         1     3.694 1290.5 372.05
# - Diphtheria:GDP             1     5.712 1292.5 372.23
# - I(GDP^2)                   1     6.264 1293.1 372.28
# - Alcohol:Hepatitis.B        1     7.119 1293.9 372.36
# - I(Diphtheria^2)            1     7.464 1294.3 372.39
# - Hepatitis.B:GDP            1     7.676 1294.5 372.41
# - Hepatitis.B:Schooling      1     7.795 1294.6 372.42
# - Status:GDP                 1     8.372 1295.2 372.47
# - Hepatitis.B:Diphtheria     1     9.818 1296.6 372.60
# - I(Schooling^2)             1    10.503 1297.3 372.66
# - I(Polio^2)                 1    10.935 1297.8 372.70
# - infant.deaths:GDP          1    11.103 1297.9 372.71
# - I(Hepatitis.B^2)           1    11.392 1298.2 372.74
# - Status:Polio               1    12.571 1299.4 372.84
# - Status:Hepatitis.B         1    16.967 1303.8 373.23
# - I(Alcohol^2)               1    20.174 1307.0 373.51
# - Alcohol:Polio              1    22.043 1308.9 373.68
# <none>                                   1286.8 373.72
# - Alcohol:Diphtheria         1    24.803 1311.6 373.92
# - Status:Diphtheria          1    25.579 1312.4 373.99
# - Status:infant.deaths       1    35.815 1322.6 374.88
# - Alcohol:GDP                1    44.624 1331.4 375.64
# - infant.deaths:Schooling    1    46.251 1333.1 375.79
# - Status:Alcohol             1    51.708 1338.5 376.26
# - Status:Schooling           1    57.314 1344.1 376.74
# - Hepatitis.B:Polio          1    63.481 1350.3 377.26
# - Polio:Diphtheria           1    65.972 1352.8 377.47
# - Diphtheria:Schooling       1    76.315 1363.1 378.35
# - infant.deaths:Diphtheria   1    76.584 1363.4 378.37
# - Hepatitis.B:BMI            1    76.916 1363.7 378.40
# - BMI:Schooling              1    92.882 1379.7 379.74
# - I(BMI^2)                   1    94.453 1381.3 379.87
# - infant.deaths:Alcohol      1   115.938 1402.8 381.65
# - Polio:Schooling            1   161.365 1448.2 385.31
# - infant.deaths:Hepatitis.B  1   174.633 1461.5 386.36
# - infant.deaths:Polio        1   215.599 1502.4 389.54
#
# Step:  AIC=371.8
# Life.expectancy ~ Status + infant.deaths + Alcohol + Hepatitis.B +
#     BMI + Polio + Diphtheria + GDP + Schooling + I(infant.deaths^2) +
#     I(Alcohol^2) + I(Hepatitis.B^2) + I(BMI^2) + I(Polio^2) +
#     I(Diphtheria^2) + I(GDP^2) + I(Schooling^2) + Status:infant.deaths +
#     Status:Alcohol + Status:Hepatitis.B + Status:Polio + Status:Diphtheria +
#     Status:GDP + Status:Schooling + infant.deaths:Alcohol + infant.deaths:Hepatitis.B +
#     infant.deaths:Polio + infant.deaths:Diphtheria + infant.deaths:GDP +
#     infant.deaths:Schooling + Alcohol:Hepatitis.B + Alcohol:BMI +
#     Alcohol:Polio + Alcohol:Diphtheria + Alcohol:GDP + Hepatitis.B:BMI +
#     Hepatitis.B:Polio + Hepatitis.B:Diphtheria + Hepatitis.B:GDP +
#     Hepatitis.B:Schooling + BMI:Schooling + Polio:Diphtheria +
#     Polio:GDP + Polio:Schooling + Diphtheria:GDP + Diphtheria:Schooling
#
#                             Df Sum of Sq    RSS    AIC
# - Polio:GDP                  1     0.943 1288.5 369.88
# - I(infant.deaths^2)         1     3.672 1291.3 370.12
# - Alcohol:BMI                1     5.400 1293.0 370.28
# - Diphtheria:GDP             1     6.469 1294.1 370.37
# - I(GDP^2)                   1     6.543 1294.2 370.38
# - Alcohol:Hepatitis.B        1     7.153 1294.8 370.43
# - Hepatitis.B:Schooling      1     8.104 1295.7 370.52
# - Status:GDP                 1     8.446 1296.1 370.55
# - I(Diphtheria^2)            1     8.625 1296.2 370.56
# - Hepatitis.B:Diphtheria     1     9.713 1297.3 370.66
# - Hepatitis.B:GDP            1    10.373 1298.0 370.72
# - I(Schooling^2)             1    10.412 1298.0 370.72
# - I(Polio^2)                 1    10.599 1298.2 370.74
# - I(Hepatitis.B^2)           1    10.612 1298.2 370.74
# - infant.deaths:GDP          1    10.623 1298.2 370.74
# - Status:Polio               1    13.543 1301.2 371.00
# - Status:Hepatitis.B         1    20.083 1307.7 371.58
# <none>                                   1287.6 371.80
# - Alcohol:Polio              1    23.075 1310.7 371.84
# - I(Alcohol^2)               1    24.317 1311.9 371.95
# - Alcohol:Diphtheria         1    24.930 1312.5 372.00
# - Status:Diphtheria          1    28.167 1315.8 372.28
# - Status:infant.deaths       1    35.718 1323.3 372.94
# - Alcohol:GDP                1    44.603 1332.2 373.71
# - infant.deaths:Schooling    1    45.467 1333.1 373.79
# - Status:Schooling           1    56.786 1344.4 374.76
# - Hepatitis.B:Polio          1    62.740 1350.3 375.27
# - Status:Alcohol             1    62.800 1350.4 375.27
# - Polio:Diphtheria           1    65.335 1353.0 375.49
# - infant.deaths:Diphtheria   1    76.342 1364.0 376.42
# - Hepatitis.B:BMI            1    76.661 1364.3 376.45
# - Diphtheria:Schooling       1    76.707 1364.3 376.45
# - BMI:Schooling              1    93.518 1381.1 377.86
# - I(BMI^2)                   1    95.220 1382.8 378.00
# - infant.deaths:Alcohol      1   116.914 1404.5 379.79
# - Polio:Schooling            1   160.627 1448.2 383.31
# - infant.deaths:Hepatitis.B  1   176.473 1464.1 384.57
# - infant.deaths:Polio        1   214.807 1502.4 387.54
#
# Step:  AIC=369.88
# Life.expectancy ~ Status + infant.deaths + Alcohol + Hepatitis.B +
#     BMI + Polio + Diphtheria + GDP + Schooling + I(infant.deaths^2) +
#     I(Alcohol^2) + I(Hepatitis.B^2) + I(BMI^2) + I(Polio^2) +
#     I(Diphtheria^2) + I(GDP^2) + I(Schooling^2) + Status:infant.deaths +
#     Status:Alcohol + Status:Hepatitis.B + Status:Polio + Status:Diphtheria +
#     Status:GDP + Status:Schooling + infant.deaths:Alcohol + infant.deaths:Hepatitis.B +
#     infant.deaths:Polio + infant.deaths:Diphtheria + infant.deaths:GDP +
#     infant.deaths:Schooling + Alcohol:Hepatitis.B + Alcohol:BMI +
#     Alcohol:Polio + Alcohol:Diphtheria + Alcohol:GDP + Hepatitis.B:BMI +
#     Hepatitis.B:Polio + Hepatitis.B:Diphtheria + Hepatitis.B:GDP +
#     Hepatitis.B:Schooling + BMI:Schooling + Polio:Diphtheria +
#     Polio:Schooling + Diphtheria:GDP + Diphtheria:Schooling
#
#                             Df Sum of Sq    RSS    AIC
# - I(infant.deaths^2)         1     3.224 1291.8 368.17
# - Alcohol:BMI                1     6.114 1294.7 368.42
# - I(GDP^2)                   1     7.034 1295.6 368.51
# - I(Diphtheria^2)            1     9.209 1297.8 368.70
# - Alcohol:Hepatitis.B        1     9.510 1298.1 368.73
# - I(Polio^2)                 1     9.660 1298.2 368.74
# - Status:GDP                 1     9.964 1298.5 368.77
# - infant.deaths:GDP          1    10.359 1298.9 368.80
# - Diphtheria:GDP             1    10.965 1299.5 368.85
# - Hepatitis.B:Schooling      1    11.032 1299.6 368.86
# - I(Schooling^2)             1    12.089 1300.6 368.95
# - Hepatitis.B:Diphtheria     1    12.620 1301.2 369.00
# - Status:Polio               1    12.689 1301.2 369.01
# - I(Hepatitis.B^2)           1    12.833 1301.4 369.02
# - Hepatitis.B:GDP            1    12.988 1301.5 369.03
# <none>                                   1288.5 369.88
# - I(Alcohol^2)               1    23.641 1312.2 369.97
# - Status:Hepatitis.B         1    25.517 1314.1 370.13
# - Status:Diphtheria          1    27.448 1316.0 370.30
# - Status:infant.deaths       1    35.391 1324.0 371.00
# - Alcohol:Diphtheria         1    42.872 1331.4 371.64
# - Alcohol:GDP                1    43.915 1332.5 371.73
# - infant.deaths:Schooling    1    44.797 1333.3 371.81
# - Alcohol:Polio              1    50.065 1338.6 372.26
# - Status:Schooling           1    57.054 1345.6 372.86
# - Hepatitis.B:Polio          1    62.955 1351.5 373.37
# - Status:Alcohol             1    64.236 1352.8 373.47
# - Polio:Diphtheria           1    64.410 1353.0 373.49
# - infant.deaths:Diphtheria   1    75.600 1364.2 374.44
# - Hepatitis.B:BMI            1    77.664 1366.2 374.61
# - I(BMI^2)                   1    95.732 1384.3 376.12
# - BMI:Schooling              1    98.233 1386.8 376.33
# - Diphtheria:Schooling       1   100.678 1389.2 376.53
# - infant.deaths:Alcohol      1   117.842 1406.4 377.94
# - infant.deaths:Hepatitis.B  1   175.781 1464.3 382.59
# - Polio:Schooling            1   183.603 1472.2 383.20
# - infant.deaths:Polio        1   214.555 1503.1 385.59
#
# Step:  AIC=368.17
# Life.expectancy ~ Status + infant.deaths + Alcohol + Hepatitis.B +
#     BMI + Polio + Diphtheria + GDP + Schooling + I(Alcohol^2) +
#     I(Hepatitis.B^2) + I(BMI^2) + I(Polio^2) + I(Diphtheria^2) +
#     I(GDP^2) + I(Schooling^2) + Status:infant.deaths + Status:Alcohol +
#     Status:Hepatitis.B + Status:Polio + Status:Diphtheria + Status:GDP +
#     Status:Schooling + infant.deaths:Alcohol + infant.deaths:Hepatitis.B +
#     infant.deaths:Polio + infant.deaths:Diphtheria + infant.deaths:GDP +
#     infant.deaths:Schooling + Alcohol:Hepatitis.B + Alcohol:BMI +
#     Alcohol:Polio + Alcohol:Diphtheria + Alcohol:GDP + Hepatitis.B:BMI +
#     Hepatitis.B:Polio + Hepatitis.B:Diphtheria + Hepatitis.B:GDP +
#     Hepatitis.B:Schooling + BMI:Schooling + Polio:Diphtheria +
#     Polio:Schooling + Diphtheria:GDP + Diphtheria:Schooling
#
#                             Df Sum of Sq    RSS    AIC
# - I(GDP^2)                   1     6.960 1298.7 366.78
# - Alcohol:BMI                1     7.171 1299.0 366.80
# - I(Diphtheria^2)            1     8.883 1300.7 366.96
# - I(Polio^2)                 1    10.513 1302.3 367.10
# - Status:GDP                 1    10.698 1302.5 367.12
# - Alcohol:Hepatitis.B        1    11.806 1303.6 367.21
# - Diphtheria:GDP             1    12.297 1304.1 367.26
# - Hepatitis.B:GDP            1    12.737 1304.5 367.30
# - Hepatitis.B:Schooling      1    13.308 1305.1 367.35
# - Status:Polio               1    13.763 1305.5 367.39
# - I(Schooling^2)             1    14.187 1306.0 367.42
# - infant.deaths:GDP          1    14.589 1306.4 367.46
# - Hepatitis.B:Diphtheria     1    14.899 1306.7 367.49
# - I(Hepatitis.B^2)           1    16.145 1307.9 367.60
# <none>                                   1291.8 368.17
# - I(Alcohol^2)               1    25.328 1317.1 368.40
# - Status:Hepatitis.B         1    26.445 1318.2 368.50
# - Status:Diphtheria          1    29.405 1321.2 368.76
# - Status:infant.deaths       1    35.758 1327.5 369.31
# - infant.deaths:Schooling    1    41.902 1333.7 369.84
# - Alcohol:Diphtheria         1    42.950 1334.7 369.93
# - Alcohol:GDP                1    44.520 1336.3 370.06
# - Alcohol:Polio              1    46.844 1338.6 370.26
# - Status:Schooling           1    57.752 1349.5 371.20
# - Hepatitis.B:Polio          1    65.575 1357.3 371.86
# - Status:Alcohol             1    66.701 1358.5 371.96
# - Polio:Diphtheria           1    68.142 1359.9 372.08
# - Hepatitis.B:BMI            1    88.317 1380.1 373.77
# - I(BMI^2)                   1    95.567 1387.3 374.37
# - Diphtheria:Schooling       1    98.105 1389.9 374.58
# - infant.deaths:Diphtheria   1   111.895 1403.7 375.72
# - infant.deaths:Alcohol      1   114.743 1406.5 375.95
# - BMI:Schooling              1   121.521 1413.3 376.51
# - Polio:Schooling            1   188.455 1480.2 381.83
# - infant.deaths:Hepatitis.B  1   202.241 1494.0 382.89
# - infant.deaths:Polio        1   220.498 1512.3 384.29
#
# Step:  AIC=366.78
# Life.expectancy ~ Status + infant.deaths + Alcohol + Hepatitis.B +
#     BMI + Polio + Diphtheria + GDP + Schooling + I(Alcohol^2) +
#     I(Hepatitis.B^2) + I(BMI^2) + I(Polio^2) + I(Diphtheria^2) +
#     I(Schooling^2) + Status:infant.deaths + Status:Alcohol +
#     Status:Hepatitis.B + Status:Polio + Status:Diphtheria + Status:GDP +
#     Status:Schooling + infant.deaths:Alcohol + infant.deaths:Hepatitis.B +
#     infant.deaths:Polio + infant.deaths:Diphtheria + infant.deaths:GDP +
#     infant.deaths:Schooling + Alcohol:Hepatitis.B + Alcohol:BMI +
#     Alcohol:Polio + Alcohol:Diphtheria + Alcohol:GDP + Hepatitis.B:BMI +
#     Hepatitis.B:Polio + Hepatitis.B:Diphtheria + Hepatitis.B:GDP +
#     Hepatitis.B:Schooling + BMI:Schooling + Polio:Diphtheria +
#     Polio:Schooling + Diphtheria:GDP + Diphtheria:Schooling
#
#                             Df Sum of Sq    RSS    AIC
# - Status:GDP                 1     4.958 1303.7 365.22
# - Hepatitis.B:GDP            1     6.873 1305.6 365.39
# - Alcohol:BMI                1     8.140 1306.9 365.50
# - Alcohol:Hepatitis.B        1     9.651 1308.4 365.64
# - I(Polio^2)                 1     9.852 1308.6 365.65
# - Status:Polio               1    10.968 1309.7 365.75
# - I(Diphtheria^2)            1    11.048 1309.8 365.76
# - Hepatitis.B:Schooling      1    11.721 1310.5 365.82
# - I(Hepatitis.B^2)           1    12.082 1310.8 365.85
# - Diphtheria:GDP             1    12.467 1311.2 365.88
# - Hepatitis.B:Diphtheria     1    13.954 1312.7 366.01
# - I(Schooling^2)             1    15.940 1314.7 366.19
# - Status:Hepatitis.B         1    20.162 1318.9 366.56
# - infant.deaths:GDP          1    22.558 1321.3 366.77
# <none>                                   1298.7 366.78
# - Status:Diphtheria          1    23.337 1322.1 366.83
# - I(Alcohol^2)               1    24.344 1323.1 366.92
# - Status:infant.deaths       1    35.250 1334.0 367.86
# - Alcohol:GDP                1    37.640 1336.4 368.07
# - Alcohol:Diphtheria         1    42.703 1341.4 368.51
# - infant.deaths:Schooling    1    45.629 1344.4 368.76
# - Alcohol:Polio              1    50.739 1349.5 369.19
# - Status:Schooling           1    54.047 1352.8 369.47
# - Status:Alcohol             1    60.130 1358.9 369.99
# - Hepatitis.B:Polio          1    66.877 1365.6 370.56
# - Polio:Diphtheria           1    70.993 1369.7 370.91
# - Hepatitis.B:BMI            1    87.963 1386.7 372.32
# - Diphtheria:Schooling       1    95.501 1394.2 372.94
# - I(BMI^2)                   1    98.336 1397.1 373.18
# - infant.deaths:Diphtheria   1   112.674 1411.4 374.35
# - infant.deaths:Alcohol      1   114.456 1413.2 374.50
# - BMI:Schooling              1   115.661 1414.4 374.60
# - Polio:Schooling            1   188.541 1487.3 380.37
# - infant.deaths:Hepatitis.B  1   204.071 1502.8 381.57
# - infant.deaths:Polio        1   220.890 1519.6 382.85
#
# Step:  AIC=365.22
# Life.expectancy ~ Status + infant.deaths + Alcohol + Hepatitis.B +
#     BMI + Polio + Diphtheria + GDP + Schooling + I(Alcohol^2) +
#     I(Hepatitis.B^2) + I(BMI^2) + I(Polio^2) + I(Diphtheria^2) +
#     I(Schooling^2) + Status:infant.deaths + Status:Alcohol +
#     Status:Hepatitis.B + Status:Polio + Status:Diphtheria + Status:Schooling +
#     infant.deaths:Alcohol + infant.deaths:Hepatitis.B + infant.deaths:Polio +
#     infant.deaths:Diphtheria + infant.deaths:GDP + infant.deaths:Schooling +
#     Alcohol:Hepatitis.B + Alcohol:BMI + Alcohol:Polio + Alcohol:Diphtheria +
#     Alcohol:GDP + Hepatitis.B:BMI + Hepatitis.B:Polio + Hepatitis.B:Diphtheria +
#     Hepatitis.B:GDP + Hepatitis.B:Schooling + BMI:Schooling +
#     Polio:Diphtheria + Polio:Schooling + Diphtheria:GDP + Diphtheria:Schooling
#
#                             Df Sum of Sq    RSS    AIC
# - Hepatitis.B:GDP            1     2.326 1306.0 363.43
# - Alcohol:Hepatitis.B        1     5.359 1309.1 363.69
# - I(Diphtheria^2)            1     6.622 1310.3 363.81
# - Hepatitis.B:Schooling      1     6.819 1310.5 363.82
# - Diphtheria:GDP             1     7.535 1311.2 363.89
# - I(Hepatitis.B^2)           1     8.980 1312.7 364.01
# - Hepatitis.B:Diphtheria     1     9.116 1312.8 364.02
# - Alcohol:BMI                1     9.280 1313.0 364.04
# - I(Polio^2)                 1    10.568 1314.3 364.15
# - Status:Polio               1    11.343 1315.0 364.22
# - Status:Hepatitis.B         1    17.254 1321.0 364.74
# - I(Schooling^2)             1    17.633 1321.3 364.77
# - Status:Diphtheria          1    20.969 1324.7 365.06
# - infant.deaths:GDP          1    21.664 1325.4 365.12
# - I(Alcohol^2)               1    21.737 1325.4 365.12
# <none>                                   1303.7 365.22
# - Alcohol:Diphtheria         1    38.478 1342.2 366.57
# - Alcohol:GDP                1    41.343 1345.0 366.81
# - infant.deaths:Schooling    1    47.401 1351.1 367.33
# - Status:infant.deaths       1    49.000 1352.7 367.47
# - Alcohol:Polio              1    49.536 1353.2 367.51
# - Status:Alcohol             1    56.130 1359.8 368.07
# - Status:Schooling           1    82.554 1386.2 370.28
# - Hepatitis.B:BMI            1    85.195 1388.9 370.50
# - Diphtheria:Schooling       1    95.950 1399.7 371.39
# - I(BMI^2)                   1    96.394 1400.1 371.43
# - Hepatitis.B:Polio          1    96.963 1400.7 371.47
# - Polio:Diphtheria           1   100.288 1404.0 371.75
# - BMI:Schooling              1   118.173 1421.9 373.20
# - infant.deaths:Alcohol      1   123.031 1426.7 373.59
# - infant.deaths:Diphtheria   1   123.108 1426.8 373.60
# - Polio:Schooling            1   194.645 1498.3 379.23
# - infant.deaths:Hepatitis.B  1   218.610 1522.3 381.05
# - infant.deaths:Polio        1   227.104 1530.8 381.69
#
# Step:  AIC=363.43
# Life.expectancy ~ Status + infant.deaths + Alcohol + Hepatitis.B +
#     BMI + Polio + Diphtheria + GDP + Schooling + I(Alcohol^2) +
#     I(Hepatitis.B^2) + I(BMI^2) + I(Polio^2) + I(Diphtheria^2) +
#     I(Schooling^2) + Status:infant.deaths + Status:Alcohol +
#     Status:Hepatitis.B + Status:Polio + Status:Diphtheria + Status:Schooling +
#     infant.deaths:Alcohol + infant.deaths:Hepatitis.B + infant.deaths:Polio +
#     infant.deaths:Diphtheria + infant.deaths:GDP + infant.deaths:Schooling +
#     Alcohol:Hepatitis.B + Alcohol:BMI + Alcohol:Polio + Alcohol:Diphtheria +
#     Alcohol:GDP + Hepatitis.B:BMI + Hepatitis.B:Polio + Hepatitis.B:Diphtheria +
#     Hepatitis.B:Schooling + BMI:Schooling + Polio:Diphtheria +
#     Polio:Schooling + Diphtheria:GDP + Diphtheria:Schooling
#
#                             Df Sum of Sq    RSS    AIC
# - I(Diphtheria^2)            1     5.200 1311.2 361.89
# - Diphtheria:GDP             1     5.275 1311.3 361.89
# - Alcohol:Hepatitis.B        1     7.171 1313.2 362.06
# - Hepatitis.B:Schooling      1     7.879 1313.9 362.12
# - Alcohol:BMI                1     8.314 1314.3 362.16
# - Hepatitis.B:Diphtheria     1    10.050 1316.1 362.31
# - I(Polio^2)                 1    11.601 1317.6 362.45
# - I(Hepatitis.B^2)           1    15.291 1321.3 362.77
# - Status:Polio               1    15.531 1321.5 362.79
# - Status:Hepatitis.B         1    16.118 1322.1 362.84
# - I(Schooling^2)             1    17.733 1323.8 362.98
# - I(Alcohol^2)               1    20.394 1326.4 363.21
# - infant.deaths:GDP          1    22.042 1328.1 363.35
# <none>                                   1306.0 363.43
# - Status:Diphtheria          1    24.223 1330.2 363.54
# - Alcohol:GDP                1    40.101 1346.1 364.91
# - Alcohol:Diphtheria         1    42.470 1348.5 365.11
# - infant.deaths:Schooling    1    48.738 1354.8 365.64
# - Alcohol:Polio              1    49.785 1355.8 365.73
# - Status:infant.deaths       1    51.190 1357.2 365.85
# - Status:Alcohol             1    57.202 1363.2 366.36
# - Status:Schooling           1    80.388 1386.4 368.30
# - Hepatitis.B:BMI            1    82.930 1389.0 368.51
# - I(BMI^2)                   1    96.013 1402.0 369.59
# - Hepatitis.B:Polio          1    99.919 1405.9 369.91
# - Polio:Diphtheria           1   102.150 1408.2 370.09
# - Diphtheria:Schooling       1   104.590 1410.6 370.29
# - BMI:Schooling              1   121.442 1427.5 371.65
# - infant.deaths:Alcohol      1   130.427 1436.5 372.37
# - infant.deaths:Diphtheria   1   137.252 1443.3 372.92
# - Polio:Schooling            1   203.340 1509.4 378.07
# - infant.deaths:Polio        1   237.141 1543.2 380.62
# - infant.deaths:Hepatitis.B  1   240.330 1546.3 380.85
#
# Step:  AIC=361.89
# Life.expectancy ~ Status + infant.deaths + Alcohol + Hepatitis.B +
#     BMI + Polio + Diphtheria + GDP + Schooling + I(Alcohol^2) +
#     I(Hepatitis.B^2) + I(BMI^2) + I(Polio^2) + I(Schooling^2) +
#     Status:infant.deaths + Status:Alcohol + Status:Hepatitis.B +
#     Status:Polio + Status:Diphtheria + Status:Schooling + infant.deaths:Alcohol +
#     infant.deaths:Hepatitis.B + infant.deaths:Polio + infant.deaths:Diphtheria +
#     infant.deaths:GDP + infant.deaths:Schooling + Alcohol:Hepatitis.B +
#     Alcohol:BMI + Alcohol:Polio + Alcohol:Diphtheria + Alcohol:GDP +
#     Hepatitis.B:BMI + Hepatitis.B:Polio + Hepatitis.B:Diphtheria +
#     Hepatitis.B:Schooling + BMI:Schooling + Polio:Diphtheria +
#     Polio:Schooling + Diphtheria:GDP + Diphtheria:Schooling
#
#                             Df Sum of Sq    RSS    AIC
# - Diphtheria:GDP             1     2.013 1313.2 360.06
# - Hepatitis.B:Schooling      1     4.111 1315.3 360.25
# - Hepatitis.B:Diphtheria     1     4.861 1316.1 360.31
# - Alcohol:Hepatitis.B        1     5.653 1316.9 360.38
# - Alcohol:BMI                1     8.859 1320.1 360.66
# - Status:Hepatitis.B         1    11.060 1322.3 360.85
# - I(Hepatitis.B^2)           1    14.925 1326.2 361.19
# - Status:Polio               1    17.215 1328.4 361.39
# - I(Schooling^2)             1    17.892 1329.1 361.44
# <none>                                   1311.2 361.89
# - I(Alcohol^2)               1    23.007 1334.2 361.89
# - infant.deaths:GDP          1    24.906 1336.1 362.05
# - Status:Diphtheria          1    25.639 1336.9 362.11
# - I(Polio^2)                 1    28.255 1339.5 362.34
# - Alcohol:Diphtheria         1    37.447 1348.7 363.12
# - Alcohol:Polio              1    44.590 1355.8 363.73
# - Alcohol:GDP                1    51.433 1362.7 364.31
# - infant.deaths:Schooling    1    53.696 1364.9 364.50
# - Status:infant.deaths       1    54.053 1365.3 364.53
# - Status:Alcohol             1    55.131 1366.3 364.62
# - Hepatitis.B:BMI            1    78.497 1389.7 366.57
# - Status:Schooling           1    85.234 1396.5 367.13
# - I(BMI^2)                   1    94.522 1405.8 367.89
# - Diphtheria:Schooling       1   104.828 1416.0 368.73
# - BMI:Schooling              1   127.919 1439.1 370.59
# - Polio:Diphtheria           1   142.701 1453.9 371.77
# - infant.deaths:Alcohol      1   143.161 1454.4 371.80
# - Hepatitis.B:Polio          1   167.060 1478.3 373.68
# - infant.deaths:Diphtheria   1   174.792 1486.0 374.28
# - Polio:Schooling            1   198.802 1510.0 376.12
# - infant.deaths:Polio        1   233.815 1545.0 378.76
# - infant.deaths:Hepatitis.B  1   258.313 1569.5 380.56
#
# Step:  AIC=360.06
# Life.expectancy ~ Status + infant.deaths + Alcohol + Hepatitis.B +
#     BMI + Polio + Diphtheria + GDP + Schooling + I(Alcohol^2) +
#     I(Hepatitis.B^2) + I(BMI^2) + I(Polio^2) + I(Schooling^2) +
#     Status:infant.deaths + Status:Alcohol + Status:Hepatitis.B +
#     Status:Polio + Status:Diphtheria + Status:Schooling + infant.deaths:Alcohol +
#     infant.deaths:Hepatitis.B + infant.deaths:Polio + infant.deaths:Diphtheria +
#     infant.deaths:GDP + infant.deaths:Schooling + Alcohol:Hepatitis.B +
#     Alcohol:BMI + Alcohol:Polio + Alcohol:Diphtheria + Alcohol:GDP +
#     Hepatitis.B:BMI + Hepatitis.B:Polio + Hepatitis.B:Diphtheria +
#     Hepatitis.B:Schooling + BMI:Schooling + Polio:Diphtheria +
#     Polio:Schooling + Diphtheria:Schooling
#
#                             Df Sum of Sq    RSS    AIC
# - Hepatitis.B:Schooling      1     3.182 1316.4 358.34
# - Hepatitis.B:Diphtheria     1     3.887 1317.1 358.40
# - Alcohol:Hepatitis.B        1     4.679 1317.9 358.47
# - Alcohol:BMI                1     9.065 1322.3 358.85
# - Status:Hepatitis.B         1     9.610 1322.8 358.90
# - I(Hepatitis.B^2)           1    13.721 1327.0 359.26
# - Status:Polio               1    15.346 1328.6 359.40
# - I(Schooling^2)             1    17.766 1331.0 359.61
# - I(Alcohol^2)               1    22.315 1335.5 360.00
# <none>                                   1313.2 360.06
# - Status:Diphtheria          1    23.631 1336.9 360.11
# - infant.deaths:GDP          1    25.564 1338.8 360.28
# - I(Polio^2)                 1    26.242 1339.5 360.34
# - Alcohol:Diphtheria         1    35.467 1348.7 361.13
# - Alcohol:Polio              1    47.305 1360.5 362.13
# - Status:Alcohol             1    53.715 1367.0 362.67
# - infant.deaths:Schooling    1    53.963 1367.2 362.69
# - Status:infant.deaths       1    55.118 1368.4 362.79
# - Alcohol:GDP                1    66.432 1379.7 363.74
# - Hepatitis.B:BMI            1    80.767 1394.0 364.93
# - Status:Schooling           1    88.450 1401.7 365.56
# - I(BMI^2)                   1    93.115 1406.3 365.94
# - Diphtheria:Schooling       1   103.223 1416.5 366.76
# - BMI:Schooling              1   129.512 1442.8 368.88
# - infant.deaths:Alcohol      1   142.537 1455.8 369.91
# - Polio:Diphtheria           1   147.793 1461.0 370.33
# - Hepatitis.B:Polio          1   170.951 1484.2 372.13
# - infant.deaths:Diphtheria   1   172.782 1486.0 372.28
# - Polio:Schooling            1   206.495 1519.7 374.86
# - infant.deaths:Polio        1   242.448 1555.7 377.54
# - infant.deaths:Hepatitis.B  1   256.968 1570.2 378.61
#
# Step:  AIC=358.34
# Life.expectancy ~ Status + infant.deaths + Alcohol + Hepatitis.B +
#     BMI + Polio + Diphtheria + GDP + Schooling + I(Alcohol^2) +
#     I(Hepatitis.B^2) + I(BMI^2) + I(Polio^2) + I(Schooling^2) +
#     Status:infant.deaths + Status:Alcohol + Status:Hepatitis.B +
#     Status:Polio + Status:Diphtheria + Status:Schooling + infant.deaths:Alcohol +
#     infant.deaths:Hepatitis.B + infant.deaths:Polio + infant.deaths:Diphtheria +
#     infant.deaths:GDP + infant.deaths:Schooling + Alcohol:Hepatitis.B +
#     Alcohol:BMI + Alcohol:Polio + Alcohol:Diphtheria + Alcohol:GDP +
#     Hepatitis.B:BMI + Hepatitis.B:Polio + Hepatitis.B:Diphtheria +
#     BMI:Schooling + Polio:Diphtheria + Polio:Schooling + Diphtheria:Schooling
#
#                             Df Sum of Sq    RSS    AIC
# - Hepatitis.B:Diphtheria     1     1.151 1317.6 356.44
# - Alcohol:Hepatitis.B        1     1.519 1317.9 356.47
# - Status:Hepatitis.B         1     6.441 1322.9 356.90
# - Alcohol:BMI                1     9.752 1326.2 357.19
# - I(Hepatitis.B^2)           1    12.213 1328.6 357.40
# - Status:Polio               1    14.454 1330.9 357.60
# - I(Schooling^2)             1    15.897 1332.3 357.72
# - I(Alcohol^2)               1    20.543 1337.0 358.12
# - Status:Diphtheria          1    21.343 1337.8 358.19
# <none>                                   1316.4 358.34
# - I(Polio^2)                 1    23.733 1340.2 358.39
# - infant.deaths:GDP          1    26.322 1342.7 358.62
# - Alcohol:Diphtheria         1    37.309 1353.7 359.55
# - Status:Alcohol             1    50.656 1367.1 360.68
# - Alcohol:Polio              1    51.595 1368.0 360.76
# - infant.deaths:Schooling    1    53.198 1369.6 360.90
# - Status:infant.deaths       1    53.248 1369.7 360.90
# - Alcohol:GDP                1    64.365 1380.8 361.83
# - Hepatitis.B:BMI            1    77.642 1394.1 362.93
# - Status:Schooling           1    85.920 1402.3 363.61
# - I(BMI^2)                   1    90.098 1406.5 363.95
# - BMI:Schooling              1   127.944 1444.4 367.01
# - infant.deaths:Alcohol      1   139.739 1456.2 367.94
# - Diphtheria:Schooling       1   164.179 1480.6 369.86
# - Polio:Diphtheria           1   168.394 1484.8 370.18
# - infant.deaths:Diphtheria   1   169.649 1486.1 370.28
# - Hepatitis.B:Polio          1   188.977 1505.4 371.77
# - Polio:Schooling            1   210.406 1526.8 373.39
# - infant.deaths:Polio        1   245.707 1562.1 376.02
# - infant.deaths:Hepatitis.B  1   253.919 1570.3 376.62
#
# Step:  AIC=356.44
# ...
#     Status:Polio + Status:Diphtheria + Status:Schooling + infant.deaths:Alcohol +
#     infant.deaths:Hepatitis.B + infant.deaths:Polio + infant.deaths:Diphtheria +
#     infant.deaths:GDP + infant.deaths:Schooling + Alcohol:BMI +
#     Alcohol:Polio + Alcohol:Diphtheria + Alcohol:GDP + Hepatitis.B:BMI +
#     Hepatitis.B:Polio + BMI:Schooling + Polio:Diphtheria + Polio:Schooling +
#     Diphtheria:Schooling
#
#                             Df Sum of Sq    RSS    AIC
# - Alcohol:BMI                1    10.552 1328.7 353.41
# - Status:Polio               1    14.099 1332.3 353.72
# - I(Schooling^2)             1    16.391 1334.6 353.91
# - I(Hepatitis.B^2)           1    20.251 1338.4 354.25
# - I(Alcohol^2)               1    20.761 1338.9 354.29
# - Status:Hepatitis.B         1    21.471 1339.7 354.35
# - Status:Diphtheria          1    21.563 1339.7 354.36
# <none>                                   1318.2 354.49
# - infant.deaths:GDP          1    29.289 1347.5 355.02
# - I(Polio^2)                 1    34.271 1352.5 355.44
# - Status:Alcohol             1    49.776 1368.0 356.76
# - Alcohol:Polio              1    50.012 1368.2 356.78
# - Alcohol:Diphtheria         1    51.242 1369.4 356.88
# - Status:infant.deaths       1    51.631 1369.8 356.91
# - infant.deaths:Schooling    1    59.896 1378.1 357.60
# - Alcohol:GDP                1    65.047 1383.2 358.03
# - Status:Schooling           1    85.649 1403.8 359.73
# - Hepatitis.B:BMI            1    86.033 1404.2 359.76
# - I(BMI^2)                   1    91.475 1409.7 360.21
# - BMI:Schooling              1   127.447 1445.6 363.11
# - infant.deaths:Alcohol      1   149.307 1467.5 364.83
# - Diphtheria:Schooling       1   163.375 1481.5 365.93
# - infant.deaths:Diphtheria   1   173.467 1491.6 366.71
# - Polio:Schooling            1   208.717 1526.9 369.40
# - Polio:Diphtheria           1   226.788 1545.0 370.75
# - infant.deaths:Polio        1   244.393 1562.6 372.05
# - infant.deaths:Hepatitis.B  1   257.220 1575.4 372.99
# - Hepatitis.B:Polio          1   269.406 1587.6 373.88
#
# Step:  AIC=353.41
# Life.expectancy ~ Status + infant.deaths + Alcohol + Hepatitis.B +
#     BMI + Polio + Diphtheria + GDP + Schooling + I(Alcohol^2) +
#     I(Hepatitis.B^2) + I(BMI^2) + I(Polio^2) + I(Schooling^2) +
#     Status:infant.deaths + Status:Alcohol + Status:Hepatitis.B +
#     Status:Polio + Status:Diphtheria + Status:Schooling + infant.deaths:Alcohol +
#     infant.deaths:Hepatitis.B + infant.deaths:Polio + infant.deaths:Diphtheria +
#     infant.deaths:GDP + infant.deaths:Schooling + Alcohol:Polio +
#     Alcohol:Diphtheria + Alcohol:GDP + Hepatitis.B:BMI + Hepatitis.B:Polio +
#     BMI:Schooling + Polio:Diphtheria + Polio:Schooling + Diphtheria:Schooling
#
#                             Df Sum of Sq    RSS    AIC
# - I(Schooling^2)             1    10.909 1339.6 352.35
# - I(Alcohol^2)               1    16.294 1345.0 352.81
# - Status:Polio               1    17.857 1346.6 352.95
# - Status:Hepatitis.B         1    21.992 1350.7 353.30
# <none>                                   1328.7 353.41
# - I(Hepatitis.B^2)           1    24.892 1353.6 353.54
# - Status:Diphtheria          1    26.462 1355.2 353.68
# - I(Polio^2)                 1    31.824 1360.5 354.13
# - infant.deaths:GDP          1    36.540 1365.3 354.53
# - Alcohol:Polio              1    50.985 1379.7 355.74
# - Status:infant.deaths       1    55.817 1384.5 356.14
# - Alcohol:Diphtheria         1    57.999 1386.7 356.32
# - Status:Alcohol             1    67.894 1396.6 357.14
# - infant.deaths:Schooling    1    76.850 1405.6 357.88
# - I(BMI^2)                   1    82.842 1411.6 358.37
# - Alcohol:GDP                1    92.188 1420.9 359.12
# - Status:Schooling           1    92.470 1421.2 359.15
# - Hepatitis.B:BMI            1   102.391 1431.1 359.95
# - BMI:Schooling              1   139.358 1468.1 362.88
# - Diphtheria:Schooling       1   165.484 1494.2 364.91
# - infant.deaths:Alcohol      1   185.112 1513.8 366.41
# - Polio:Schooling            1   211.140 1539.9 368.37
# - infant.deaths:Diphtheria   1   211.640 1540.4 368.41
# - infant.deaths:Polio        1   248.121 1576.8 371.10
# - Polio:Diphtheria           1   256.100 1584.8 371.68
# - infant.deaths:Hepatitis.B  1   296.190 1624.9 374.55
# - Hepatitis.B:Polio          1   305.904 1634.6 375.24
#
# Step:  AIC=352.35
# Life.expectancy ~ Status + infant.deaths + Alcohol + Hepatitis.B +
#     BMI + Polio + Diphtheria + GDP + Schooling + I(Alcohol^2) +
#     I(Hepatitis.B^2) + I(BMI^2) + I(Polio^2) + Status:infant.deaths +
#     Status:Alcohol + Status:Hepatitis.B + Status:Polio + Status:Diphtheria +
#     Status:Schooling + infant.deaths:Alcohol + infant.deaths:Hepatitis.B +
#     infant.deaths:Polio + infant.deaths:Diphtheria + infant.deaths:GDP +
#     infant.deaths:Schooling + Alcohol:Polio + Alcohol:Diphtheria +
#     Alcohol:GDP + Hepatitis.B:BMI + Hepatitis.B:Polio + BMI:Schooling +
#     Polio:Diphtheria + Polio:Schooling + Diphtheria:Schooling
#
#                             Df Sum of Sq    RSS    AIC
# - I(Alcohol^2)               1     12.90 1352.5 351.45
# - Status:Polio               1     17.41 1357.0 351.84
# - Status:Hepatitis.B         1     21.67 1361.3 352.20
# - I(Hepatitis.B^2)           1     22.62 1362.3 352.28
# <none>                                   1339.6 352.35
# - Status:Diphtheria          1     25.27 1364.9 352.50
# - I(Polio^2)                 1     31.44 1371.1 353.02
# - infant.deaths:GDP          1     41.67 1381.3 353.87
# - Status:infant.deaths       1     56.18 1395.8 355.07
# - Alcohol:Polio              1     66.77 1406.4 355.94
# - Status:Alcohol             1     67.61 1407.2 356.01
# - Alcohol:Diphtheria         1     73.11 1412.7 356.46
# - infant.deaths:Schooling    1     78.21 1417.8 356.88
# - I(BMI^2)                   1     82.72 1422.3 357.24
# - Status:Schooling           1     83.99 1423.6 357.34
# - Alcohol:GDP                1     90.05 1429.7 357.83
# - Hepatitis.B:BMI            1    116.68 1456.3 359.95
# - BMI:Schooling              1    130.05 1469.7 361.01
# - Diphtheria:Schooling       1    162.53 1502.2 363.52
# - infant.deaths:Alcohol      1    198.45 1538.1 366.24
# - infant.deaths:Diphtheria   1    227.68 1567.3 368.40
# - Polio:Schooling            1    232.90 1572.5 368.78
# - infant.deaths:Polio        1    259.25 1598.9 370.69
# - Polio:Diphtheria           1    272.81 1612.5 371.67
# - infant.deaths:Hepatitis.B  1    316.83 1656.5 374.76
# - Hepatitis.B:Polio          1    324.30 1663.9 375.28
#
# Step:  AIC=351.45
# Life.expectancy ~ Status + infant.deaths + Alcohol + Hepatitis.B +
#     BMI + Polio + Diphtheria + GDP + Schooling + I(Hepatitis.B^2) +
#     I(BMI^2) + I(Polio^2) + Status:infant.deaths + Status:Alcohol +
#     Status:Hepatitis.B + Status:Polio + Status:Diphtheria + Status:Schooling +
#     infant.deaths:Alcohol + infant.deaths:Hepatitis.B + infant.deaths:Polio +
#     infant.deaths:Diphtheria + infant.deaths:GDP + infant.deaths:Schooling +
#     Alcohol:Polio + Alcohol:Diphtheria + Alcohol:GDP + Hepatitis.B:BMI +
#     Hepatitis.B:Polio + BMI:Schooling + Polio:Diphtheria + Polio:Schooling +
#     Diphtheria:Schooling
#
#                             Df Sum of Sq    RSS    AIC
# - Status:Polio               1    18.659 1371.2 351.03
# - Status:Hepatitis.B         1    20.473 1373.0 351.18
# <none>                                   1352.5 351.45
# - I(Hepatitis.B^2)           1    25.213 1377.8 351.58
# - Status:Diphtheria          1    27.356 1379.9 351.76
# - I(Polio^2)                 1    32.563 1385.1 352.19
# - infant.deaths:GDP          1    37.616 1390.2 352.61
# - Status:infant.deaths       1    56.750 1409.3 354.18
# - Alcohol:Polio              1    67.995 1420.5 355.09
# - Alcohol:Diphtheria         1    68.511 1421.0 355.14
# - infant.deaths:Schooling    1    70.182 1422.7 355.27
# - I(BMI^2)                   1    72.832 1425.4 355.48
# - Status:Schooling           1    84.239 1436.8 356.40
# - Status:Alcohol             1    89.882 1442.4 356.85
# - Alcohol:GDP                1    93.541 1446.1 357.14
# - Hepatitis.B:BMI            1   115.044 1467.6 358.84
# - BMI:Schooling              1   130.820 1483.4 360.07
# - Diphtheria:Schooling       1   165.900 1518.4 362.76
# - infant.deaths:Alcohol      1   186.014 1538.6 364.27
# - infant.deaths:Diphtheria   1   215.754 1568.3 366.47
# - Polio:Schooling            1   234.295 1586.8 367.83
# - infant.deaths:Polio        1   261.699 1614.2 369.79
# - Polio:Diphtheria           1   262.455 1615.0 369.85
# - infant.deaths:Hepatitis.B  1   305.429 1658.0 372.87
# - Hepatitis.B:Polio          1   313.247 1665.8 373.41
#
# Step:  AIC=351.03
# Life.expectancy ~ Status + infant.deaths + Alcohol + Hepatitis.B +
#     BMI + Polio + Diphtheria + GDP + Schooling + I(Hepatitis.B^2) +
#     I(BMI^2) + I(Polio^2) + Status:infant.deaths + Status:Alcohol +
#     Status:Hepatitis.B + Status:Diphtheria + Status:Schooling +
#     infant.deaths:Alcohol + infant.deaths:Hepatitis.B + infant.deaths:Polio +
#     infant.deaths:Diphtheria + infant.deaths:GDP + infant.deaths:Schooling +
#     Alcohol:Polio + Alcohol:Diphtheria + Alcohol:GDP + Hepatitis.B:BMI +
#     Hepatitis.B:Polio + BMI:Schooling + Polio:Diphtheria + Polio:Schooling +
#     Diphtheria:Schooling
#
#                             Df Sum of Sq    RSS    AIC
# - Status:Diphtheria          1     23.20 1394.4 350.96
# <none>                                   1371.2 351.03
# - I(Polio^2)                 1     26.79 1398.0 351.25
# - I(Hepatitis.B^2)           1     28.10 1399.3 351.36
# - Status:Hepatitis.B         1     33.11 1404.3 351.77
# - infant.deaths:GDP          1     38.14 1409.3 352.18
# - Status:infant.deaths       1     43.40 1414.6 352.61
# - infant.deaths:Schooling    1     71.29 1442.5 354.86
# - I(BMI^2)                   1     73.42 1444.6 355.03
# - Alcohol:Polio              1     80.45 1451.7 355.59
# - Status:Alcohol             1     80.74 1452.0 355.61
# - Alcohol:Diphtheria         1     81.30 1452.5 355.65
# - Alcohol:GDP                1    102.88 1474.1 357.35
# - Hepatitis.B:BMI            1    114.20 1485.4 358.23
# - BMI:Schooling              1    125.92 1497.1 359.13
# - Status:Schooling           1    141.51 1512.7 360.32
# - Diphtheria:Schooling       1    177.19 1548.4 363.00
# - infant.deaths:Alcohol      1    189.68 1560.9 363.93
# - infant.deaths:Diphtheria   1    225.17 1596.4 366.51
# - Polio:Schooling            1    245.56 1616.8 367.97
# - infant.deaths:Polio        1    271.10 1642.3 369.78
# - Polio:Diphtheria           1    277.88 1649.1 370.25
# - infant.deaths:Hepatitis.B  1    317.82 1689.0 373.00
# - Hepatitis.B:Polio          1    326.27 1697.5 373.58
#
# Step:  AIC=350.96
# Life.expectancy ~ Status + infant.deaths + Alcohol + Hepatitis.B +
#     BMI + Polio + Diphtheria + GDP + Schooling + I(Hepatitis.B^2) +
#     I(BMI^2) + I(Polio^2) + Status:infant.deaths + Status:Alcohol +
#     Status:Hepatitis.B + Status:Schooling + infant.deaths:Alcohol +
#     infant.deaths:Hepatitis.B + infant.deaths:Polio + infant.deaths:Diphtheria +
#     infant.deaths:GDP + infant.deaths:Schooling + Alcohol:Polio +
#     Alcohol:Diphtheria + Alcohol:GDP + Hepatitis.B:BMI + Hepatitis.B:Polio +
#     BMI:Schooling + Polio:Diphtheria + Polio:Schooling + Diphtheria:Schooling
#
#                             Df Sum of Sq    RSS    AIC
# - I(Hepatitis.B^2)           1    19.845 1414.2 350.58
# - Status:Hepatitis.B         1    23.795 1418.2 350.90
# <none>                                   1394.4 350.96
# - Status:infant.deaths       1    26.897 1421.3 351.16
# - infant.deaths:GDP          1    35.171 1429.6 351.82
# - I(Polio^2)                 1    36.581 1431.0 351.94
# - Status:Alcohol             1    57.630 1452.0 353.62
# - I(BMI^2)                   1    63.533 1457.9 354.08
# - infant.deaths:Schooling    1    67.613 1462.0 354.40
# - Alcohol:Polio              1    70.959 1465.4 354.67
# - Alcohol:GDP                1    81.882 1476.3 355.52
# - Alcohol:Diphtheria         1    82.748 1477.2 355.59
# - BMI:Schooling              1   111.623 1506.0 357.81
# - Hepatitis.B:BMI            1   114.056 1508.5 358.00
# - Status:Schooling           1   123.600 1518.0 358.73
# - Diphtheria:Schooling       1   160.075 1554.5 361.46
# - infant.deaths:Alcohol      1   179.086 1573.5 362.85
# - infant.deaths:Diphtheria   1   217.582 1612.0 365.63
# - Polio:Schooling            1   224.898 1619.3 366.15
# - infant.deaths:Polio        1   250.469 1644.9 367.96
# - Polio:Diphtheria           1   262.548 1657.0 368.80
# - infant.deaths:Hepatitis.B  1   301.754 1696.2 371.49
# - Hepatitis.B:Polio          1   309.941 1704.3 372.04
#
# Step:  AIC=350.58
# Life.expectancy ~ Status + infant.deaths + Alcohol + Hepatitis.B +
#     BMI + Polio + Diphtheria + GDP + Schooling + I(BMI^2) + I(Polio^2) +
#     Status:infant.deaths + Status:Alcohol + Status:Hepatitis.B +
#     Status:Schooling + infant.deaths:Alcohol + infant.deaths:Hepatitis.B +
#     infant.deaths:Polio + infant.deaths:Diphtheria + infant.deaths:GDP +
#     infant.deaths:Schooling + Alcohol:Polio + Alcohol:Diphtheria +
#     Alcohol:GDP + Hepatitis.B:BMI + Hepatitis.B:Polio + BMI:Schooling +
#     Polio:Diphtheria + Polio:Schooling + Diphtheria:Schooling
#
#                             Df Sum of Sq    RSS    AIC
# - Status:Hepatitis.B         1    16.904 1431.2 349.95
# - Status:infant.deaths       1    24.687 1438.9 350.57
# <none>                                   1414.2 350.58
# - infant.deaths:GDP          1    36.253 1450.5 351.49
# - I(BMI^2)                   1    51.590 1465.8 352.70
# - Status:Alcohol             1    54.210 1468.5 352.91
# - infant.deaths:Schooling    1    68.510 1482.8 354.02
# - Alcohol:GDP                1    69.339 1483.6 354.09
# - Alcohol:Polio              1    73.828 1488.1 354.44
# - Alcohol:Diphtheria         1    80.465 1494.7 354.95
# - BMI:Schooling              1    98.071 1512.3 356.29
# - I(Polio^2)                 1   101.058 1515.3 356.52
# - Status:Schooling           1   111.467 1525.7 357.31
# - Hepatitis.B:BMI            1   114.224 1528.5 357.52
# - Diphtheria:Schooling       1   150.142 1564.4 360.19
# - infant.deaths:Alcohol      1   173.665 1587.9 361.90
# - infant.deaths:Diphtheria   1   205.971 1620.2 364.22
# - Polio:Schooling            1   215.422 1629.7 364.89
# - infant.deaths:Polio        1   242.981 1657.2 366.82
# - Polio:Diphtheria           1   254.552 1668.8 367.62
# - infant.deaths:Hepatitis.B  1   289.326 1703.6 369.99
# - Hepatitis.B:Polio          1   297.063 1711.3 370.51
#
# Step:  AIC=349.95
# Life.expectancy ~ Status + infant.deaths + Alcohol + Hepatitis.B +
#     BMI + Polio + Diphtheria + GDP + Schooling + I(BMI^2) + I(Polio^2) +
#     Status:infant.deaths + Status:Alcohol + Status:Schooling +
#     infant.deaths:Alcohol + infant.deaths:Hepatitis.B + infant.deaths:Polio +
#     infant.deaths:Diphtheria + infant.deaths:GDP + infant.deaths:Schooling +
#     Alcohol:Polio + Alcohol:Diphtheria + Alcohol:GDP + Hepatitis.B:BMI +
#     Hepatitis.B:Polio + BMI:Schooling + Polio:Diphtheria + Polio:Schooling +
#     Diphtheria:Schooling
#
#                             Df Sum of Sq    RSS    AIC
# <none>                                   1431.2 349.95
# - infant.deaths:GDP          1     40.60 1471.8 351.17
# - Status:infant.deaths       1     50.38 1481.5 351.93
# - I(BMI^2)                   1     52.65 1483.8 352.10
# - Status:Alcohol             1     66.72 1497.9 353.19
# - Alcohol:GDP                1     69.92 1501.1 353.44
# - Alcohol:Polio              1     78.60 1509.8 354.10
# - Alcohol:Diphtheria         1     78.80 1510.0 354.11
# - infant.deaths:Schooling    1     79.39 1510.5 354.16
# - BMI:Schooling              1     86.54 1517.7 354.70
# - Status:Schooling           1     96.61 1527.8 355.46
# - I(Polio^2)                 1    104.81 1536.0 356.08
# - Diphtheria:Schooling       1    152.72 1583.9 359.61
# - Hepatitis.B:BMI            1    157.59 1588.8 359.96
# - infant.deaths:Alcohol      1    191.06 1622.2 362.36
# - infant.deaths:Diphtheria   1    219.51 1650.7 364.36
# - Polio:Schooling            1    221.36 1652.5 364.49
# - infant.deaths:Polio        1    250.81 1682.0 366.52
# - Polio:Diphtheria           1    274.27 1705.4 368.11
# - infant.deaths:Hepatitis.B  1    306.51 1737.7 370.27
# - Hepatitis.B:Polio          1    317.52 1748.7 370.99

# %%
AICmod = lm(Life.expectancy ~ Status + infant.deaths + Alcohol + Hepatitis.B + 
    BMI + Polio + Diphtheria + GDP + Schooling + Status:infant.deaths + 
    Status:Alcohol + Status:Schooling + infant.deaths:Alcohol + 
    infant.deaths:Hepatitis.B + infant.deaths:Polio + infant.deaths:Diphtheria + 
    Alcohol:Polio + Alcohol:Diphtheria + Alcohol:GDP + Hepatitis.B:BMI + 
    Hepatitis.B:Polio + Hepatitis.B:Diphtheria + Hepatitis.B:Schooling + 
    BMI:Schooling + Polio:Diphtheria + Polio:Schooling + Diphtheria:Schooling, data = train_data)

summary(AICmod)

AICtrain_predict = predict.lm(AICmod, train_data)
(AICtrain_mse_OLS = mean((AICtrain_predict - train_data$Life.expectancy)^2))

AICtest_predict = predict.lm(AICmod, test_data)
(AICtest_mse_ols = mean((AICtest_predict - test_data$Life.expectancy)^2))

plot_residuals(AICmod, 'AICmod')
ggplot (data = test_data, aes (x=Life.expectancy,y= AICtest_predict)) +
  geom_smooth(se=F,method = "lm",colour = "gray35") + geom_point() +
  ggtitle('Linear Regression: Ground Truth vs Predicted') +
  xlab('Ground Truth') +
  ylab('Predicted')
# Out:
# Call:
# lm(formula = Life.expectancy ~ Status + infant.deaths + Alcohol +
#     Hepatitis.B + BMI + Polio + Diphtheria + GDP + Schooling +
#     Status:infant.deaths + Status:Alcohol + Status:Schooling +
#     infant.deaths:Alcohol + infant.deaths:Hepatitis.B + infant.deaths:Polio +
#     infant.deaths:Diphtheria + Alcohol:Polio + Alcohol:Diphtheria +
#     Alcohol:GDP + Hepatitis.B:BMI + Hepatitis.B:Polio + Hepatitis.B:Diphtheria +
#     Hepatitis.B:Schooling + BMI:Schooling + Polio:Diphtheria +
#     Polio:Schooling + Diphtheria:Schooling, data = train_data)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -16.3890  -1.3503   0.5317   2.0532   7.9130
#
# Coefficients:
#                                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)                     1.052e+02  1.949e+01   5.396 5.82e-07 ***
# StatusDeveloping               -6.436e+01  1.764e+01  -3.648 0.000450 ***
# infant.deaths                  -2.833e+00  1.476e+00  -1.920 0.058176 .
# Alcohol                        -3.587e+00  1.813e+00  -1.979 0.050969 .
# Hepatitis.B                     2.213e+00  5.573e-01   3.971 0.000147 ***
# BMI                             6.136e-01  1.541e-01   3.981 0.000142 ***
# Polio                          -1.245e+00  3.750e-01  -3.321 0.001312 **
# Diphtheria                     -1.310e+00  3.880e-01  -3.377 0.001098 **
# GDP                            -4.225e-07  8.687e-05  -0.005 0.996130
# Schooling                       6.089e-01  1.362e+00   0.447 0.655835
# StatusDeveloping:infant.deaths  2.562e+00  1.482e+00   1.729 0.087283 .
# StatusDeveloping:Alcohol        1.754e+00  9.113e-01   1.924 0.057572 .
# StatusDeveloping:Schooling      2.744e+00  9.014e-01   3.044 0.003090 **
# infant.deaths:Alcohol          -1.142e-02  3.761e-03  -3.036 0.003167 **
# infant.deaths:Hepatitis.B      -3.638e-02  9.791e-03  -3.715 0.000358 ***
# infant.deaths:Polio             1.805e-02  5.192e-03   3.477 0.000794 ***
# infant.deaths:Diphtheria        2.186e-02  7.470e-03   2.926 0.004380 **
# Alcohol:Polio                  -5.790e-02  2.749e-02  -2.106 0.038043 *
# Alcohol:Diphtheria              7.240e-02  3.056e-02   2.369 0.020046 *
# Alcohol:GDP                     2.453e-05  1.078e-05   2.275 0.025378 *
# Hepatitis.B:BMI                -1.891e-03  1.236e-03  -1.530 0.129591
# Hepatitis.B:Polio              -2.286e-02  5.879e-03  -3.888 0.000197 ***
# Hepatitis.B:Diphtheria          2.953e-03  1.576e-03   1.874 0.064281 .
# Hepatitis.B:Schooling          -1.846e-02  1.147e-02  -1.610 0.111006
# BMI:Schooling                  -3.088e-02  1.097e-02  -2.814 0.006048 **
# Polio:Diphtheria                2.262e-02  5.946e-03   3.804 0.000264 ***
# Polio:Schooling                 1.115e-01  3.354e-02   3.326 0.001294 **
# Diphtheria:Schooling           -9.655e-02  3.943e-02  -2.449 0.016352 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 4.17 on 87 degrees of freedom
# Multiple R-squared:  0.8255,	Adjusted R-squared:  0.7713
# F-statistic: 15.24 on 27 and 87 DF,  p-value: < 2.2e-16
# [1] 13.15596
# [1] 350.0095
# `geom_smooth()` using formula 'y ~ x'
# Plot with title “”
# plot without title

# %% [markdown]
# Delete insiginificant variables:

# %%
AICM = lm(Status + infant.deaths + Alcohol + Hepatitis.B + 
    BMI + Polio + Diphtheria + GDP + Schooling + I(BMI^2) + I(Polio^2) + 
    Status:infant.deaths + Status:Alcohol + Status:Schooling + 
    infant.deaths:Alcohol + infant.deaths:Hepatitis.B + infant.deaths:Polio + 
    infant.deaths:Diphtheria + infant.deaths:GDP + infant.deaths:Schooling + 
    Alcohol:Polio + Alcohol:Diphtheria + Alcohol:GDP + Hepatitis.B:BMI + 
    Hepatitis.B:Polio + BMI:Schooling + Polio:Diphtheria + Polio:Schooling + 
    Diphtheria:Schooling, data = train_data)

summary(AICM)

AICMtrain_predict = predict.lm(AICM, train_data)
(AICMtrain_mse_OLS = mean((AICMtrain_predict - train_data$Life.expectancy)^2))

AICMtest_predict = predict.lm(AICM, test_data)
(AICMtest_mse_ols = mean((AICMtest_predict - test_data$Life.expectancy)^2))

plot_residuals(AICmod, 'AICmod')
ggplot (data = test_data, aes (x=Life.expectancy,y= AICMtest_predict)) +
  geom_smooth(se=F,method = "lm",colour = "gray35") + geom_point() +
  ggtitle('Linear Regression: Ground Truth vs Predicted') +
  xlab('Ground Truth') +
  ylab('Predicted')
# Out:
# Error in stats::model.frame(formula = Status + infant.deaths + Alcohol + : object 'Status' not found
# Traceback:
#
# 1. lm(Status + infant.deaths + Alcohol + Hepatitis.B + BMI + Polio +
#  .     Diphtheria + GDP + Schooling + I(BMI^2) + I(Polio^2) + Status:infant.deaths +
#  .     Status:Alcohol + Status:Schooling + infant.deaths:Alcohol +
#  .     infant.deaths:Hepatitis.B + infant.deaths:Polio + infant.deaths:Diphtheria +
#  .     infant.deaths:GDP + infant.deaths:Schooling + Alcohol:Polio +
#  .     Alcohol:Diphtheria + Alcohol:GDP + Hepatitis.B:BMI + Hepatitis.B:Polio +
#  .     BMI:Schooling + Polio:Diphtheria + Polio:Schooling + Diphtheria:Schooling,
#  .     data = train_data)
# 2. eval(mf, parent.frame())
# 3. eval(mf, parent.frame())
# 4. stats::model.frame(formula = Status + infant.deaths + Alcohol +
#  .     Hepatitis.B + BMI + Polio + Diphtheria + GDP + Schooling +
#  .     I(BMI^2) + I(Polio^2) + Status:infant.deaths + Status:Alcohol +
#  .     Status:Schooling + infant.deaths:Alcohol + infant.deaths:Hepatitis.B +
#  .     infant.deaths:Polio + infant.deaths:Diphtheria + infant.deaths:GDP +
#  .     infant.deaths:Schooling + Alcohol:Polio + Alcohol:Diphtheria +
#  .     Alcohol:GDP + Hepatitis.B:BMI + Hepatitis.B:Polio + BMI:Schooling +
#  .     Polio:Diphtheria + Polio:Schooling + Diphtheria:Schooling,
#  .     data = train_data, drop.unused.levels = TRUE)

# %% [markdown]
# ##### d.BIC

# %%
BICSelect = step(mod2, k = log(45))
# Out:
# Start:  AIC=483.17
# Life.expectancy ~ Status + infant.deaths + Alcohol + Hepatitis.B +
#     BMI + Polio + Diphtheria + GDP + Schooling + I(infant.deaths^2) +
#     I(Alcohol^2) + I(Hepatitis.B^2) + I(BMI^2) + I(Polio^2) +
#     I(Diphtheria^2) + I(GDP^2) + I(Schooling^2) + Status * infant.deaths +
#     Status * Alcohol + Status * Hepatitis.B + Status * BMI +
#     Status * Polio + Status * Diphtheria + Status * GDP + Status *
#     Schooling + infant.deaths * Alcohol + infant.deaths * Hepatitis.B +
#     infant.deaths * BMI + infant.deaths * Polio + infant.deaths *
#     Diphtheria + infant.deaths * GDP + infant.deaths * Schooling +
#     Alcohol * Hepatitis.B + Alcohol * BMI + Alcohol * Polio +
#     Alcohol * Diphtheria + Alcohol * GDP + Alcohol * Schooling +
#     Hepatitis.B * BMI + Hepatitis.B * Polio + Hepatitis.B * Diphtheria +
#     Hepatitis.B * GDP + Hepatitis.B * Schooling + BMI * Polio +
#     BMI * Diphtheria + BMI * GDP + BMI * Schooling + Polio *
#     Diphtheria + Polio * GDP + Polio * Schooling + Diphtheria *
#     GDP + Diphtheria * Schooling + GDP * Schooling
#
#                             Df Sum of Sq    RSS    AIC
# - infant.deaths:BMI          1     0.055 1285.6 479.37
# - Alcohol:Schooling          1     0.225 1285.8 479.39
# - GDP:Schooling              1     0.254 1285.8 479.39
# - BMI:GDP                    1     0.336 1285.9 479.40
# - BMI:Diphtheria             1     0.487 1286.1 479.41
# - BMI:Polio                  1     0.489 1286.1 479.41
# - Alcohol:BMI                1     0.856 1286.4 479.44
# - Status:BMI                 1     0.916 1286.5 479.45
# - Polio:GDP                  1     1.096 1286.7 479.47
# - I(GDP^2)                   1     1.246 1286.8 479.48
# - I(infant.deaths^2)         1     3.126 1288.7 479.65
# - Diphtheria:GDP             1     3.491 1289.1 479.68
# - I(Schooling^2)             1     3.564 1289.2 479.69
# - Hepatitis.B:GDP            1     4.774 1290.4 479.79
# - Status:GDP                 1     5.182 1290.8 479.83
# - Alcohol:Hepatitis.B        1     5.742 1291.3 479.88
# - I(Polio^2)                 1     6.035 1291.6 479.91
# - Hepatitis.B:Schooling      1     6.973 1292.6 479.99
# - I(Diphtheria^2)            1     7.234 1292.8 480.01
# - infant.deaths:GDP          1     8.415 1294.0 480.12
# - I(Hepatitis.B^2)           1     9.978 1295.6 480.26
# - Hepatitis.B:Diphtheria     1    10.243 1295.8 480.28
# - Status:Polio               1    11.512 1297.1 480.39
# - Alcohol:Polio              1    12.693 1298.3 480.50
# - I(Alcohol^2)               1    13.718 1299.3 480.59
# - Status:Hepatitis.B         1    13.773 1299.4 480.59
# - Alcohol:GDP                1    21.552 1307.1 481.28
# - Status:Diphtheria          1    22.282 1307.9 481.34
# - Alcohol:Diphtheria         1    23.278 1308.9 481.43
# - Status:Schooling           1    30.387 1316.0 482.05
# - Status:infant.deaths       1    33.512 1319.1 482.33
# - infant.deaths:Schooling    1    39.403 1325.0 482.84
# - Hepatitis.B:BMI            1    41.034 1326.6 482.98
# - Status:Alcohol             1    41.936 1327.5 483.06
# <none>                                   1285.6 483.17
# - Hepatitis.B:Polio          1    44.822 1330.4 483.31
# - Polio:Diphtheria           1    49.226 1334.8 483.69
# - infant.deaths:Diphtheria   1    60.230 1345.8 484.63
# - BMI:Schooling              1    61.126 1346.7 484.71
# - Diphtheria:Schooling       1    61.217 1346.8 484.72
# - I(BMI^2)                   1    81.067 1366.7 486.40
# - infant.deaths:Alcohol      1    97.314 1382.9 487.76
# - infant.deaths:Hepatitis.B  1   130.390 1416.0 490.48
# - Polio:Schooling            1   133.915 1419.5 490.76
# - infant.deaths:Polio        1   171.458 1457.0 493.76
#
# Step:  AIC=479.37
# Life.expectancy ~ Status + infant.deaths + Alcohol + Hepatitis.B +
#     BMI + Polio + Diphtheria + GDP + Schooling + I(infant.deaths^2) +
#     I(Alcohol^2) + I(Hepatitis.B^2) + I(BMI^2) + I(Polio^2) +
#     I(Diphtheria^2) + I(GDP^2) + I(Schooling^2) + Status:infant.deaths +
#     Status:Alcohol + Status:Hepatitis.B + Status:BMI + Status:Polio +
#     Status:Diphtheria + Status:GDP + Status:Schooling + infant.deaths:Alcohol +
#     infant.deaths:Hepatitis.B + infant.deaths:Polio + infant.deaths:Diphtheria +
#     infant.deaths:GDP + infant.deaths:Schooling + Alcohol:Hepatitis.B +
#     Alcohol:BMI + Alcohol:Polio + Alcohol:Diphtheria + Alcohol:GDP +
#     Alcohol:Schooling + Hepatitis.B:BMI + Hepatitis.B:Polio +
#     Hepatitis.B:Diphtheria + Hepatitis.B:GDP + Hepatitis.B:Schooling +
#     BMI:Polio + BMI:Diphtheria + BMI:GDP + BMI:Schooling + Polio:Diphtheria +
#     Polio:GDP + Polio:Schooling + Diphtheria:GDP + Diphtheria:Schooling +
#     GDP:Schooling
#
#                             Df Sum of Sq    RSS    AIC
# - Alcohol:Schooling          1     0.214 1285.8 475.58
# - GDP:Schooling              1     0.246 1285.9 475.59
# - BMI:GDP                    1     0.396 1286.0 475.60
# - BMI:Diphtheria             1     0.532 1286.2 475.61
# - BMI:Polio                  1     0.534 1286.2 475.61
# - Status:BMI                 1     0.875 1286.5 475.64
# - Alcohol:BMI                1     0.936 1286.6 475.65
# - Polio:GDP                  1     1.182 1286.8 475.67
# - I(GDP^2)                   1     1.252 1286.9 475.68
# - Diphtheria:GDP             1     3.602 1289.2 475.89
# - I(infant.deaths^2)         1     3.609 1289.2 475.89
# - I(Schooling^2)             1     3.684 1289.3 475.89
# - Hepatitis.B:GDP            1     4.723 1290.4 475.99
# - Status:GDP                 1     5.128 1290.8 476.02
# - Alcohol:Hepatitis.B        1     5.707 1291.3 476.07
# - I(Polio^2)                 1     5.992 1291.6 476.10
# - Hepatitis.B:Schooling      1     6.951 1292.6 476.19
# - I(Diphtheria^2)            1     7.217 1292.9 476.21
# - infant.deaths:GDP          1     8.549 1294.2 476.33
# - I(Hepatitis.B^2)           1     9.939 1295.6 476.45
# - Hepatitis.B:Diphtheria     1    10.215 1295.8 476.48
# - Status:Polio               1    11.467 1297.1 476.59
# - Alcohol:Polio              1    13.136 1298.8 476.73
# - I(Alcohol^2)               1    13.699 1299.3 476.78
# - Status:Hepatitis.B         1    13.743 1299.4 476.79
# - Alcohol:GDP                1    21.565 1307.2 477.48
# - Status:Diphtheria          1    22.244 1307.9 477.54
# - Alcohol:Diphtheria         1    23.319 1309.0 477.63
# - Status:Schooling           1    30.350 1316.0 478.25
# - Status:infant.deaths       1    33.525 1319.2 478.53
# - Hepatitis.B:BMI            1    41.007 1326.6 479.18
# - infant.deaths:Schooling    1    41.700 1327.3 479.24
# - Status:Alcohol             1    41.881 1327.5 479.25
# <none>                                   1285.6 479.37
# - Hepatitis.B:Polio          1    46.601 1332.2 479.66
# - Polio:Diphtheria           1    51.587 1337.2 480.09
# - Diphtheria:Schooling       1    61.185 1346.8 480.91
# - infant.deaths:Diphtheria   1    61.536 1347.2 480.94
# - BMI:Schooling              1    69.771 1355.4 481.64
# - I(BMI^2)                   1    85.051 1370.7 482.93
# - infant.deaths:Alcohol      1    98.318 1384.0 484.04
# - infant.deaths:Hepatitis.B  1   132.750 1418.4 486.87
# - Polio:Schooling            1   136.964 1422.6 487.21
# - infant.deaths:Polio        1   173.900 1459.5 490.15
#
# Step:  AIC=475.58
# Life.expectancy ~ Status + infant.deaths + Alcohol + Hepatitis.B +
#     BMI + Polio + Diphtheria + GDP + Schooling + I(infant.deaths^2) +
#     I(Alcohol^2) + I(Hepatitis.B^2) + I(BMI^2) + I(Polio^2) +
#     I(Diphtheria^2) + I(GDP^2) + I(Schooling^2) + Status:infant.deaths +
#     Status:Alcohol + Status:Hepatitis.B + Status:BMI + Status:Polio +
#     Status:Diphtheria + Status:GDP + Status:Schooling + infant.deaths:Alcohol +
#     infant.deaths:Hepatitis.B + infant.deaths:Polio + infant.deaths:Diphtheria +
#     infant.deaths:GDP + infant.deaths:Schooling + Alcohol:Hepatitis.B +
#     Alcohol:BMI + Alcohol:Polio + Alcohol:Diphtheria + Alcohol:GDP +
#     Hepatitis.B:BMI + Hepatitis.B:Polio + Hepatitis.B:Diphtheria +
#     Hepatitis.B:GDP + Hepatitis.B:Schooling + BMI:Polio + BMI:Diphtheria +
#     BMI:GDP + BMI:Schooling + Polio:Diphtheria + Polio:GDP +
#     Polio:Schooling + Diphtheria:GDP + Diphtheria:Schooling +
#     GDP:Schooling
#
#                             Df Sum of Sq    RSS    AIC
# - GDP:Schooling              1     0.152 1286.0 471.79
# - BMI:GDP                    1     0.421 1286.3 471.82
# - BMI:Polio                  1     0.465 1286.3 471.82
# - BMI:Diphtheria             1     0.538 1286.4 471.83
# - Status:BMI                 1     0.736 1286.6 471.84
# - Polio:GDP                  1     1.175 1287.0 471.88
# - I(GDP^2)                   1     1.393 1287.2 471.90
# - Alcohol:BMI                1     1.566 1287.4 471.92
# - I(infant.deaths^2)         1     3.494 1289.3 472.09
# - Diphtheria:GDP             1     3.580 1289.4 472.10
# - Hepatitis.B:GDP            1     5.150 1291.0 472.24
# - Alcohol:Hepatitis.B        1     5.773 1291.6 472.29
# - I(Polio^2)                 1     5.955 1291.8 472.31
# - Status:GDP                 1     6.016 1291.9 472.31
# - Hepatitis.B:Schooling      1     7.145 1293.0 472.42
# - I(Diphtheria^2)            1     7.321 1293.2 472.43
# - I(Schooling^2)             1     9.489 1295.3 472.62
# - I(Hepatitis.B^2)           1     9.735 1295.6 472.65
# - Hepatitis.B:Diphtheria     1    10.144 1296.0 472.68
# - infant.deaths:GDP          1    10.162 1296.0 472.68
# - Status:Polio               1    11.322 1297.2 472.79
# - Alcohol:Polio              1    12.927 1298.8 472.93
# - Status:Hepatitis.B         1    14.092 1299.9 473.03
# - I(Alcohol^2)               1    17.922 1303.8 473.37
# - Status:Diphtheria          1    22.075 1307.9 473.74
# - Alcohol:Diphtheria         1    23.398 1309.2 473.85
# - Alcohol:GDP                1    26.017 1311.9 474.08
# - Status:infant.deaths       1    33.342 1319.2 474.72
# - Status:Schooling           1    35.375 1321.2 474.90
# - Status:Alcohol             1    42.801 1328.7 475.54
# <none>                                   1285.8 475.58
# - infant.deaths:Schooling    1    44.461 1330.3 475.69
# - Hepatitis.B:BMI            1    47.813 1333.7 475.98
# - Hepatitis.B:Polio          1    54.599 1340.5 476.56
# - Polio:Diphtheria           1    60.897 1346.8 477.10
# - Diphtheria:Schooling       1    62.413 1348.3 477.23
# - infant.deaths:Diphtheria   1    74.687 1360.5 478.27
# - BMI:Schooling              1    80.077 1365.9 478.73
# - I(BMI^2)                   1    87.747 1373.6 479.37
# - infant.deaths:Alcohol      1   112.998 1398.8 481.46
# - Polio:Schooling            1   137.207 1423.1 483.44
# - infant.deaths:Hepatitis.B  1   161.330 1447.2 485.37
# - infant.deaths:Polio        1   184.303 1470.2 487.18
#
# Step:  AIC=471.79
# Life.expectancy ~ Status + infant.deaths + Alcohol + Hepatitis.B +
#     BMI + Polio + Diphtheria + GDP + Schooling + I(infant.deaths^2) +
#     I(Alcohol^2) + I(Hepatitis.B^2) + I(BMI^2) + I(Polio^2) +
#     I(Diphtheria^2) + I(GDP^2) + I(Schooling^2) + Status:infant.deaths +
#     Status:Alcohol + Status:Hepatitis.B + Status:BMI + Status:Polio +
#     Status:Diphtheria + Status:GDP + Status:Schooling + infant.deaths:Alcohol +
#     infant.deaths:Hepatitis.B + infant.deaths:Polio + infant.deaths:Diphtheria +
#     infant.deaths:GDP + infant.deaths:Schooling + Alcohol:Hepatitis.B +
#     Alcohol:BMI + Alcohol:Polio + Alcohol:Diphtheria + Alcohol:GDP +
#     Hepatitis.B:BMI + Hepatitis.B:Polio + Hepatitis.B:Diphtheria +
#     Hepatitis.B:GDP + Hepatitis.B:Schooling + BMI:Polio + BMI:Diphtheria +
#     BMI:GDP + BMI:Schooling + Polio:Diphtheria + Polio:GDP +
#     Polio:Schooling + Diphtheria:GDP + Diphtheria:Schooling
#
#                             Df Sum of Sq    RSS    AIC
# - BMI:GDP                    1     0.559 1286.6 468.03
# - BMI:Polio                  1     0.646 1286.7 468.04
# - BMI:Diphtheria             1     0.677 1286.7 468.05
# - Status:BMI                 1     0.678 1286.7 468.05
# - Alcohol:BMI                1     1.521 1287.5 468.12
# - Polio:GDP                  1     1.538 1287.5 468.12
# - I(GDP^2)                   1     2.514 1288.5 468.21
# - I(infant.deaths^2)         1     3.633 1289.6 468.31
# - Diphtheria:GDP             1     4.096 1290.1 468.35
# - Hepatitis.B:GDP            1     5.338 1291.3 468.46
# - Alcohol:Hepatitis.B        1     5.670 1291.7 468.49
# - I(Polio^2)                 1     5.869 1291.9 468.51
# - Status:GDP                 1     6.576 1292.6 468.57
# - Hepatitis.B:Schooling      1     7.078 1293.1 468.62
# - I(Diphtheria^2)            1     7.650 1293.7 468.67
# - I(Hepatitis.B^2)           1     9.699 1295.7 468.85
# - infant.deaths:GDP          1    10.065 1296.1 468.88
# - Hepatitis.B:Diphtheria     1    10.476 1296.5 468.92
# - I(Schooling^2)             1    10.817 1296.8 468.95
# - Status:Polio               1    11.777 1297.8 469.03
# - Alcohol:Polio              1    13.384 1299.4 469.18
# - Status:Hepatitis.B         1    14.387 1300.4 469.26
# - I(Alcohol^2)               1    18.440 1304.4 469.62
# - Status:Diphtheria          1    23.368 1309.4 470.06
# - Alcohol:Diphtheria         1    23.565 1309.6 470.07
# - Status:infant.deaths       1    33.531 1319.5 470.94
# <none>                                   1286.0 471.79
# - Alcohol:GDP                1    44.296 1330.3 471.88
# - infant.deaths:Schooling    1    45.287 1331.3 471.96
# - Status:Alcohol             1    46.693 1332.7 472.09
# - Hepatitis.B:BMI            1    48.069 1334.1 472.21
# - Status:Schooling           1    53.577 1339.6 472.68
# - Hepatitis.B:Polio          1    54.488 1340.5 472.76
# - Polio:Diphtheria           1    60.907 1346.9 473.31
# - Diphtheria:Schooling       1    62.390 1348.4 473.43
# - infant.deaths:Diphtheria   1    74.952 1361.0 474.50
# - BMI:Schooling              1    80.119 1366.1 474.94
# - I(BMI^2)                   1    88.447 1374.5 475.63
# - infant.deaths:Alcohol      1   114.550 1400.5 477.80
# - Polio:Schooling            1   137.249 1423.2 479.65
# - infant.deaths:Hepatitis.B  1   161.980 1448.0 481.63
# - infant.deaths:Polio        1   184.838 1470.8 483.43
#
# Step:  AIC=468.03
# Life.expectancy ~ Status + infant.deaths + Alcohol + Hepatitis.B +
#     BMI + Polio + Diphtheria + GDP + Schooling + I(infant.deaths^2) +
#     I(Alcohol^2) + I(Hepatitis.B^2) + I(BMI^2) + I(Polio^2) +
#     I(Diphtheria^2) + I(GDP^2) + I(Schooling^2) + Status:infant.deaths +
#     Status:Alcohol + Status:Hepatitis.B + Status:BMI + Status:Polio +
#     Status:Diphtheria + Status:GDP + Status:Schooling + infant.deaths:Alcohol +
#     infant.deaths:Hepatitis.B + infant.deaths:Polio + infant.deaths:Diphtheria +
#     infant.deaths:GDP + infant.deaths:Schooling + Alcohol:Hepatitis.B +
#     Alcohol:BMI + Alcohol:Polio + Alcohol:Diphtheria + Alcohol:GDP +
#     Hepatitis.B:BMI + Hepatitis.B:Polio + Hepatitis.B:Diphtheria +
#     Hepatitis.B:GDP + Hepatitis.B:Schooling + BMI:Polio + BMI:Diphtheria +
#     BMI:Schooling + Polio:Diphtheria + Polio:GDP + Polio:Schooling +
#     Diphtheria:GDP + Diphtheria:Schooling
#
#                             Df Sum of Sq    RSS    AIC
# - BMI:Polio                  1     0.202 1286.8 464.25
# - BMI:Diphtheria             1     0.255 1286.8 464.25
# - Status:BMI                 1     0.894 1287.5 464.31
# - Polio:GDP                  1     1.028 1287.6 464.32
# - Alcohol:BMI                1     1.367 1287.9 464.35
# - I(infant.deaths^2)         1     3.770 1290.3 464.56
# - Diphtheria:GDP             1     4.905 1291.5 464.67
# - I(Polio^2)                 1     5.830 1292.4 464.75
# - Alcohol:Hepatitis.B        1     5.836 1292.4 464.75
# - I(GDP^2)                   1     6.168 1292.7 464.78
# - Hepatitis.B:GDP            1     6.799 1293.4 464.83
# - Hepatitis.B:Schooling      1     6.836 1293.4 464.84
# - I(Diphtheria^2)            1     7.130 1293.7 464.86
# - Status:GDP                 1     7.679 1294.2 464.91
# - Hepatitis.B:Diphtheria     1     9.963 1296.5 465.12
# - I(Hepatitis.B^2)           1    10.154 1296.7 465.13
# - I(Schooling^2)             1    10.709 1297.3 465.18
# - infant.deaths:GDP          1    10.997 1297.6 465.21
# - Status:Polio               1    11.284 1297.8 465.23
# - Alcohol:Polio              1    12.835 1299.4 465.37
# - Status:Hepatitis.B         1    15.170 1301.7 465.58
# - I(Alcohol^2)               1    18.193 1304.8 465.84
# - Alcohol:Diphtheria         1    23.031 1309.6 466.27
# - Status:Diphtheria          1    23.047 1309.6 466.27
# - Status:infant.deaths       1    34.778 1321.3 467.30
# <none>                                   1286.6 468.03
# - Alcohol:GDP                1    44.812 1331.4 468.17
# - infant.deaths:Schooling    1    46.413 1333.0 468.30
# - Hepatitis.B:BMI            1    48.898 1335.5 468.52
# - Status:Alcohol             1    51.471 1338.0 468.74
# - Status:Schooling           1    56.809 1343.4 469.20
# - Hepatitis.B:Polio          1    59.595 1346.2 469.44
# - Diphtheria:Schooling       1    62.513 1349.1 469.68
# - Polio:Diphtheria           1    65.109 1351.7 469.91
# - infant.deaths:Diphtheria   1    75.248 1361.8 470.76
# - BMI:Schooling              1    82.515 1369.1 471.38
# - I(BMI^2)                   1    87.998 1374.6 471.84
# - infant.deaths:Alcohol      1   115.567 1402.1 474.12
# - Polio:Schooling            1   140.593 1427.2 476.15
# - infant.deaths:Hepatitis.B  1   162.740 1449.3 477.93
# - infant.deaths:Polio        1   185.641 1472.2 479.73
#
# Step:  AIC=464.25
# Life.expectancy ~ Status + infant.deaths + Alcohol + Hepatitis.B +
#     BMI + Polio + Diphtheria + GDP + Schooling + I(infant.deaths^2) +
#     I(Alcohol^2) + I(Hepatitis.B^2) + I(BMI^2) + I(Polio^2) +
#     I(Diphtheria^2) + I(GDP^2) + I(Schooling^2) + Status:infant.deaths +
#     Status:Alcohol + Status:Hepatitis.B + Status:BMI + Status:Polio +
#     Status:Diphtheria + Status:GDP + Status:Schooling + infant.deaths:Alcohol +
#     infant.deaths:Hepatitis.B + infant.deaths:Polio + infant.deaths:Diphtheria +
#     infant.deaths:GDP + infant.deaths:Schooling + Alcohol:Hepatitis.B +
#     Alcohol:BMI + Alcohol:Polio + Alcohol:Diphtheria + Alcohol:GDP +
#     Hepatitis.B:BMI + Hepatitis.B:Polio + Hepatitis.B:Diphtheria +
#     Hepatitis.B:GDP + Hepatitis.B:Schooling + BMI:Diphtheria +
#     BMI:Schooling + Polio:Diphtheria + Polio:GDP + Polio:Schooling +
#     Diphtheria:GDP + Diphtheria:Schooling
#
#                             Df Sum of Sq    RSS    AIC
# - BMI:Diphtheria             1     0.054 1286.8 460.44
# - Status:BMI                 1     0.806 1287.6 460.51
# - Polio:GDP                  1     0.896 1287.7 460.52
# - Alcohol:BMI                1     1.533 1288.3 460.58
# - I(infant.deaths^2)         1     3.737 1290.5 460.77
# - Diphtheria:GDP             1     5.754 1292.5 460.95
# - I(GDP^2)                   1     6.303 1293.1 461.00
# - Alcohol:Hepatitis.B        1     7.165 1293.9 461.08
# - I(Diphtheria^2)            1     7.191 1294.0 461.08
# - Hepatitis.B:GDP            1     7.551 1294.3 461.11
# - Hepatitis.B:Schooling      1     7.583 1294.3 461.12
# - Status:GDP                 1     8.310 1295.1 461.18
# - I(Polio^2)                 1     9.664 1296.4 461.30
# - Hepatitis.B:Diphtheria     1     9.812 1296.6 461.31
# - I(Schooling^2)             1    10.508 1297.3 461.37
# - infant.deaths:GDP          1    11.146 1297.9 461.43
# - I(Hepatitis.B^2)           1    11.410 1298.2 461.45
# - Status:Polio               1    12.354 1299.1 461.54
# - Status:Hepatitis.B         1    16.039 1302.8 461.86
# - I(Alcohol^2)               1    20.044 1306.8 462.22
# - Alcohol:Polio              1    21.679 1308.4 462.36
# - Alcohol:Diphtheria         1    23.918 1310.7 462.56
# - Status:Diphtheria          1    25.487 1312.2 462.70
# - Status:infant.deaths       1    34.904 1321.7 463.52
# <none>                                   1286.8 464.25
# - Alcohol:GDP                1    44.611 1331.4 464.36
# - infant.deaths:Schooling    1    46.213 1333.0 464.50
# - Hepatitis.B:BMI            1    48.699 1335.5 464.71
# - Status:Alcohol             1    51.401 1338.2 464.94
# - Status:Schooling           1    56.643 1343.4 465.39
# - Hepatitis.B:Polio          1    62.655 1349.4 465.91
# - Diphtheria:Schooling       1    63.194 1350.0 465.95
# - Polio:Diphtheria           1    64.908 1351.7 466.10
# - infant.deaths:Diphtheria   1    75.145 1361.9 466.97
# - BMI:Schooling              1    82.479 1369.2 467.58
# - I(BMI^2)                   1    90.228 1377.0 468.23
# - infant.deaths:Alcohol      1   115.406 1402.2 470.32
# - Polio:Schooling            1   142.399 1429.2 472.51
# - infant.deaths:Hepatitis.B  1   163.478 1450.2 474.19
# - infant.deaths:Polio        1   190.655 1477.4 476.33
#
# Step:  AIC=460.44
# Life.expectancy ~ Status + infant.deaths + Alcohol + Hepatitis.B +
#     BMI + Polio + Diphtheria + GDP + Schooling + I(infant.deaths^2) +
#     I(Alcohol^2) + I(Hepatitis.B^2) + I(BMI^2) + I(Polio^2) +
#     I(Diphtheria^2) + I(GDP^2) + I(Schooling^2) + Status:infant.deaths +
#     Status:Alcohol + Status:Hepatitis.B + Status:BMI + Status:Polio +
#     Status:Diphtheria + Status:GDP + Status:Schooling + infant.deaths:Alcohol +
#     infant.deaths:Hepatitis.B + infant.deaths:Polio + infant.deaths:Diphtheria +
#     infant.deaths:GDP + infant.deaths:Schooling + Alcohol:Hepatitis.B +
#     Alcohol:BMI + Alcohol:Polio + Alcohol:Diphtheria + Alcohol:GDP +
#     Hepatitis.B:BMI + Hepatitis.B:Polio + Hepatitis.B:Diphtheria +
#     Hepatitis.B:GDP + Hepatitis.B:Schooling + BMI:Schooling +
#     Polio:Diphtheria + Polio:GDP + Polio:Schooling + Diphtheria:GDP +
#     Diphtheria:Schooling
#
#                             Df Sum of Sq    RSS    AIC
# - Status:BMI                 1     0.793 1287.6 456.71
# - Polio:GDP                  1     0.927 1287.8 456.72
# - Alcohol:BMI                1     1.533 1288.3 456.77
# - I(infant.deaths^2)         1     3.694 1290.5 456.97
# - Diphtheria:GDP             1     5.712 1292.5 457.15
# - I(GDP^2)                   1     6.264 1293.1 457.20
# - Alcohol:Hepatitis.B        1     7.119 1293.9 457.27
# - I(Diphtheria^2)            1     7.464 1294.3 457.30
# - Hepatitis.B:GDP            1     7.676 1294.5 457.32
# - Hepatitis.B:Schooling      1     7.795 1294.6 457.33
# - Status:GDP                 1     8.372 1295.2 457.38
# - Hepatitis.B:Diphtheria     1     9.818 1296.6 457.51
# - I(Schooling^2)             1    10.503 1297.3 457.57
# - I(Polio^2)                 1    10.935 1297.8 457.61
# - infant.deaths:GDP          1    11.103 1297.9 457.63
# - I(Hepatitis.B^2)           1    11.392 1298.2 457.65
# - Status:Polio               1    12.571 1299.4 457.76
# - Status:Hepatitis.B         1    16.967 1303.8 458.14
# - I(Alcohol^2)               1    20.174 1307.0 458.43
# - Alcohol:Polio              1    22.043 1308.9 458.59
# - Alcohol:Diphtheria         1    24.803 1311.6 458.83
# - Status:Diphtheria          1    25.579 1312.4 458.90
# - Status:infant.deaths       1    35.815 1322.6 459.79
# <none>                                   1286.8 460.44
# - Alcohol:GDP                1    44.624 1331.4 460.56
# - infant.deaths:Schooling    1    46.251 1333.1 460.70
# - Status:Alcohol             1    51.708 1338.5 461.17
# - Status:Schooling           1    57.314 1344.1 461.65
# - Hepatitis.B:Polio          1    63.481 1350.3 462.18
# - Polio:Diphtheria           1    65.972 1352.8 462.39
# - Diphtheria:Schooling       1    76.315 1363.1 463.26
# - infant.deaths:Diphtheria   1    76.584 1363.4 463.29
# - Hepatitis.B:BMI            1    76.916 1363.7 463.31
# - BMI:Schooling              1    92.882 1379.7 464.65
# - I(BMI^2)                   1    94.453 1381.3 464.78
# - infant.deaths:Alcohol      1   115.938 1402.8 466.56
# - Polio:Schooling            1   161.365 1448.2 470.22
# - infant.deaths:Hepatitis.B  1   174.633 1461.5 471.27
# - infant.deaths:Polio        1   215.599 1502.4 474.45
#
# Step:  AIC=456.71
# Life.expectancy ~ Status + infant.deaths + Alcohol + Hepatitis.B +
#     BMI + Polio + Diphtheria + GDP + Schooling + I(infant.deaths^2) +
#     I(Alcohol^2) + I(Hepatitis.B^2) + I(BMI^2) + I(Polio^2) +
#     I(Diphtheria^2) + I(GDP^2) + I(Schooling^2) + Status:infant.deaths +
#     Status:Alcohol + Status:Hepatitis.B + Status:Polio + Status:Diphtheria +
#     Status:GDP + Status:Schooling + infant.deaths:Alcohol + infant.deaths:Hepatitis.B +
#     infant.deaths:Polio + infant.deaths:Diphtheria + infant.deaths:GDP +
#     infant.deaths:Schooling + Alcohol:Hepatitis.B + Alcohol:BMI +
#     Alcohol:Polio + Alcohol:Diphtheria + Alcohol:GDP + Hepatitis.B:BMI +
#     Hepatitis.B:Polio + Hepatitis.B:Diphtheria + Hepatitis.B:GDP +
#     Hepatitis.B:Schooling + BMI:Schooling + Polio:Diphtheria +
#     Polio:GDP + Polio:Schooling + Diphtheria:GDP + Diphtheria:Schooling
#
#                             Df Sum of Sq    RSS    AIC
# - Polio:GDP                  1     0.943 1288.5 452.99
# - I(infant.deaths^2)         1     3.672 1291.3 453.23
# - Alcohol:BMI                1     5.400 1293.0 453.38
# - Diphtheria:GDP             1     6.469 1294.1 453.48
# - I(GDP^2)                   1     6.543 1294.2 453.48
# - Alcohol:Hepatitis.B        1     7.153 1294.8 453.54
# - Hepatitis.B:Schooling      1     8.104 1295.7 453.62
# - Status:GDP                 1     8.446 1296.1 453.65
# - I(Diphtheria^2)            1     8.625 1296.2 453.67
# - Hepatitis.B:Diphtheria     1     9.713 1297.3 453.77
# - Hepatitis.B:GDP            1    10.373 1298.0 453.82
# - I(Schooling^2)             1    10.412 1298.0 453.83
# - I(Polio^2)                 1    10.599 1298.2 453.84
# - I(Hepatitis.B^2)           1    10.612 1298.2 453.85
# - infant.deaths:GDP          1    10.623 1298.2 453.85
# - Status:Polio               1    13.543 1301.2 454.11
# - Status:Hepatitis.B         1    20.083 1307.7 454.68
# - Alcohol:Polio              1    23.075 1310.7 454.94
# - I(Alcohol^2)               1    24.317 1311.9 455.05
# - Alcohol:Diphtheria         1    24.930 1312.5 455.11
# - Status:Diphtheria          1    28.167 1315.8 455.39
# - Status:infant.deaths       1    35.718 1323.3 456.05
# <none>                                   1287.6 456.71
# - Alcohol:GDP                1    44.603 1332.2 456.82
# - infant.deaths:Schooling    1    45.467 1333.1 456.89
# - Status:Schooling           1    56.786 1344.4 457.86
# - Hepatitis.B:Polio          1    62.740 1350.3 458.37
# - Status:Alcohol             1    62.800 1350.4 458.38
# - Polio:Diphtheria           1    65.335 1353.0 458.59
# - infant.deaths:Diphtheria   1    76.342 1364.0 459.53
# - Hepatitis.B:BMI            1    76.661 1364.3 459.55
# - Diphtheria:Schooling       1    76.707 1364.3 459.56
# - BMI:Schooling              1    93.518 1381.1 460.96
# - I(BMI^2)                   1    95.220 1382.8 461.11
# - infant.deaths:Alcohol      1   116.914 1404.5 462.90
# - Polio:Schooling            1   160.627 1448.2 466.42
# - infant.deaths:Hepatitis.B  1   176.473 1464.1 467.67
# - infant.deaths:Polio        1   214.807 1502.4 470.64
#
# Step:  AIC=452.99
# Life.expectancy ~ Status + infant.deaths + Alcohol + Hepatitis.B +
#     BMI + Polio + Diphtheria + GDP + Schooling + I(infant.deaths^2) +
#     I(Alcohol^2) + I(Hepatitis.B^2) + I(BMI^2) + I(Polio^2) +
#     I(Diphtheria^2) + I(GDP^2) + I(Schooling^2) + Status:infant.deaths +
#     Status:Alcohol + Status:Hepatitis.B + Status:Polio + Status:Diphtheria +
#     Status:GDP + Status:Schooling + infant.deaths:Alcohol + infant.deaths:Hepatitis.B +
#     infant.deaths:Polio + infant.deaths:Diphtheria + infant.deaths:GDP +
#     infant.deaths:Schooling + Alcohol:Hepatitis.B + Alcohol:BMI +
#     Alcohol:Polio + Alcohol:Diphtheria + Alcohol:GDP + Hepatitis.B:BMI +
#     Hepatitis.B:Polio + Hepatitis.B:Diphtheria + Hepatitis.B:GDP +
#     Hepatitis.B:Schooling + BMI:Schooling + Polio:Diphtheria +
#     Polio:Schooling + Diphtheria:GDP + Diphtheria:Schooling
#
#                             Df Sum of Sq    RSS    AIC
# - I(infant.deaths^2)         1     3.224 1291.8 449.47
# - Alcohol:BMI                1     6.114 1294.7 449.72
# - I(GDP^2)                   1     7.034 1295.6 449.81
# - I(Diphtheria^2)            1     9.209 1297.8 450.00
# - Alcohol:Hepatitis.B        1     9.510 1298.1 450.03
# - I(Polio^2)                 1     9.660 1298.2 450.04
# - Status:GDP                 1     9.964 1298.5 450.07
# - infant.deaths:GDP          1    10.359 1298.9 450.10
# - Diphtheria:GDP             1    10.965 1299.5 450.15
# - Hepatitis.B:Schooling      1    11.032 1299.6 450.16
# - I(Schooling^2)             1    12.089 1300.6 450.25
# - Hepatitis.B:Diphtheria     1    12.620 1301.2 450.30
# - Status:Polio               1    12.689 1301.2 450.31
# - I(Hepatitis.B^2)           1    12.833 1301.4 450.32
# - Hepatitis.B:GDP            1    12.988 1301.5 450.33
# - I(Alcohol^2)               1    23.641 1312.2 451.27
# - Status:Hepatitis.B         1    25.517 1314.1 451.43
# - Status:Diphtheria          1    27.448 1316.0 451.60
# - Status:infant.deaths       1    35.391 1324.0 452.30
# - Alcohol:Diphtheria         1    42.872 1331.4 452.94
# <none>                                   1288.5 452.99
# - Alcohol:GDP                1    43.915 1332.5 453.03
# - infant.deaths:Schooling    1    44.797 1333.3 453.11
# - Alcohol:Polio              1    50.065 1338.6 453.56
# - Status:Schooling           1    57.054 1345.6 454.16
# - Hepatitis.B:Polio          1    62.955 1351.5 454.67
# - Status:Alcohol             1    64.236 1352.8 454.77
# - Polio:Diphtheria           1    64.410 1353.0 454.79
# - infant.deaths:Diphtheria   1    75.600 1364.2 455.74
# - Hepatitis.B:BMI            1    77.664 1366.2 455.91
# - I(BMI^2)                   1    95.732 1384.3 457.42
# - BMI:Schooling              1    98.233 1386.8 457.63
# - Diphtheria:Schooling       1   100.678 1389.2 457.83
# - infant.deaths:Alcohol      1   117.842 1406.4 459.24
# - infant.deaths:Hepatitis.B  1   175.781 1464.3 463.89
# - Polio:Schooling            1   183.603 1472.2 464.50
# - infant.deaths:Polio        1   214.555 1503.1 466.89
#
# Step:  AIC=449.47
# Life.expectancy ~ Status + infant.deaths + Alcohol + Hepatitis.B +
#     BMI + Polio + Diphtheria + GDP + Schooling + I(Alcohol^2) +
#     I(Hepatitis.B^2) + I(BMI^2) + I(Polio^2) + I(Diphtheria^2) +
#     I(GDP^2) + I(Schooling^2) + Status:infant.deaths + Status:Alcohol +
#     Status:Hepatitis.B + Status:Polio + Status:Diphtheria + Status:GDP +
#     Status:Schooling + infant.deaths:Alcohol + infant.deaths:Hepatitis.B +
#     infant.deaths:Polio + infant.deaths:Diphtheria + infant.deaths:GDP +
#     infant.deaths:Schooling + Alcohol:Hepatitis.B + Alcohol:BMI +
#     Alcohol:Polio + Alcohol:Diphtheria + Alcohol:GDP + Hepatitis.B:BMI +
#     Hepatitis.B:Polio + Hepatitis.B:Diphtheria + Hepatitis.B:GDP +
#     Hepatitis.B:Schooling + BMI:Schooling + Polio:Diphtheria +
#     Polio:Schooling + Diphtheria:GDP + Diphtheria:Schooling
#
#                             Df Sum of Sq    RSS    AIC
# - I(GDP^2)                   1     6.960 1298.7 446.28
# - Alcohol:BMI                1     7.171 1299.0 446.30
# - I(Diphtheria^2)            1     8.883 1300.7 446.45
# - I(Polio^2)                 1    10.513 1302.3 446.59
# - Status:GDP                 1    10.698 1302.5 446.61
# - Alcohol:Hepatitis.B        1    11.806 1303.6 446.71
# - Diphtheria:GDP             1    12.297 1304.1 446.75
# - Hepatitis.B:GDP            1    12.737 1304.5 446.79
# - Hepatitis.B:Schooling      1    13.308 1305.1 446.84
# - Status:Polio               1    13.763 1305.5 446.88
# - I(Schooling^2)             1    14.187 1306.0 446.92
# - infant.deaths:GDP          1    14.589 1306.4 446.95
# - Hepatitis.B:Diphtheria     1    14.899 1306.7 446.98
# - I(Hepatitis.B^2)           1    16.145 1307.9 447.09
# - I(Alcohol^2)               1    25.328 1317.1 447.89
# - Status:Hepatitis.B         1    26.445 1318.2 447.99
# - Status:Diphtheria          1    29.405 1321.2 448.25
# - Status:infant.deaths       1    35.758 1327.5 448.80
# - infant.deaths:Schooling    1    41.902 1333.7 449.33
# - Alcohol:Diphtheria         1    42.950 1334.7 449.42
# <none>                                   1291.8 449.47
# - Alcohol:GDP                1    44.520 1336.3 449.56
# - Alcohol:Polio              1    46.844 1338.6 449.76
# - Status:Schooling           1    57.752 1349.5 450.69
# - Hepatitis.B:Polio          1    65.575 1357.3 451.35
# - Status:Alcohol             1    66.701 1358.5 451.45
# - Polio:Diphtheria           1    68.142 1359.9 451.57
# - Hepatitis.B:BMI            1    88.317 1380.1 453.27
# - I(BMI^2)                   1    95.567 1387.3 453.87
# - Diphtheria:Schooling       1    98.105 1389.9 454.08
# - infant.deaths:Diphtheria   1   111.895 1403.7 455.21
# - infant.deaths:Alcohol      1   114.743 1406.5 455.45
# - BMI:Schooling              1   121.521 1413.3 456.00
# - Polio:Schooling            1   188.455 1480.2 461.32
# - infant.deaths:Hepatitis.B  1   202.241 1494.0 462.39
# - infant.deaths:Polio        1   220.498 1512.3 463.78
#
# Step:  AIC=446.28
# Life.expectancy ~ Status + infant.deaths + Alcohol + Hepatitis.B +
#     BMI + Polio + Diphtheria + GDP + Schooling + I(Alcohol^2) +
#     I(Hepatitis.B^2) + I(BMI^2) + I(Polio^2) + I(Diphtheria^2) +
#     I(Schooling^2) + Status:infant.deaths + Status:Alcohol +
#     Status:Hepatitis.B + Status:Polio + Status:Diphtheria + Status:GDP +
#     Status:Schooling + infant.deaths:Alcohol + infant.deaths:Hepatitis.B +
#     infant.deaths:Polio + infant.deaths:Diphtheria + infant.deaths:GDP +
#     infant.deaths:Schooling + Alcohol:Hepatitis.B + Alcohol:BMI +
#     Alcohol:Polio + Alcohol:Diphtheria + Alcohol:GDP + Hepatitis.B:BMI +
#     Hepatitis.B:Polio + Hepatitis.B:Diphtheria + Hepatitis.B:GDP +
#     Hepatitis.B:Schooling + BMI:Schooling + Polio:Diphtheria +
#     Polio:Schooling + Diphtheria:GDP + Diphtheria:Schooling
#
#                             Df Sum of Sq    RSS    AIC
# - Status:GDP                 1     4.958 1303.7 442.91
# - Hepatitis.B:GDP            1     6.873 1305.6 443.08
# - Alcohol:BMI                1     8.140 1306.9 443.19
# - Alcohol:Hepatitis.B        1     9.651 1308.4 443.32
# - I(Polio^2)                 1     9.852 1308.6 443.34
# - Status:Polio               1    10.968 1309.7 443.44
# - I(Diphtheria^2)            1    11.048 1309.8 443.45
# - Hepatitis.B:Schooling      1    11.721 1310.5 443.50
# - I(Hepatitis.B^2)           1    12.082 1310.8 443.54
# - Diphtheria:GDP             1    12.467 1311.2 443.57
# - Hepatitis.B:Diphtheria     1    13.954 1312.7 443.70
# - I(Schooling^2)             1    15.940 1314.7 443.87
# - Status:Hepatitis.B         1    20.162 1318.9 444.24
# - infant.deaths:GDP          1    22.558 1321.3 444.45
# - Status:Diphtheria          1    23.337 1322.1 444.52
# - I(Alcohol^2)               1    24.344 1323.1 444.61
# - Status:infant.deaths       1    35.250 1334.0 445.55
# - Alcohol:GDP                1    37.640 1336.4 445.76
# - Alcohol:Diphtheria         1    42.703 1341.4 446.19
# <none>                                   1298.7 446.28
# - infant.deaths:Schooling    1    45.629 1344.4 446.44
# - Alcohol:Polio              1    50.739 1349.5 446.88
# - Status:Schooling           1    54.047 1352.8 447.16
# - Status:Alcohol             1    60.130 1358.9 447.68
# - Hepatitis.B:Polio          1    66.877 1365.6 448.25
# - Polio:Diphtheria           1    70.993 1369.7 448.59
# - Hepatitis.B:BMI            1    87.963 1386.7 450.01
# - Diphtheria:Schooling       1    95.501 1394.2 450.63
# - I(BMI^2)                   1    98.336 1397.1 450.86
# - infant.deaths:Diphtheria   1   112.674 1411.4 452.04
# - infant.deaths:Alcohol      1   114.456 1413.2 452.18
# - BMI:Schooling              1   115.661 1414.4 452.28
# - Polio:Schooling            1   188.541 1487.3 458.06
# - infant.deaths:Hepatitis.B  1   204.071 1502.8 459.25
# - infant.deaths:Polio        1   220.890 1519.6 460.53
#
# Step:  AIC=442.91
# Life.expectancy ~ Status + infant.deaths + Alcohol + Hepatitis.B +
#     BMI + Polio + Diphtheria + GDP + Schooling + I(Alcohol^2) +
#     I(Hepatitis.B^2) + I(BMI^2) + I(Polio^2) + I(Diphtheria^2) +
#     I(Schooling^2) + Status:infant.deaths + Status:Alcohol +
#     Status:Hepatitis.B + Status:Polio + Status:Diphtheria + Status:Schooling +
#     infant.deaths:Alcohol + infant.deaths:Hepatitis.B + infant.deaths:Polio +
#     infant.deaths:Diphtheria + infant.deaths:GDP + infant.deaths:Schooling +
#     Alcohol:Hepatitis.B + Alcohol:BMI + Alcohol:Polio + Alcohol:Diphtheria +
#     Alcohol:GDP + Hepatitis.B:BMI + Hepatitis.B:Polio + Hepatitis.B:Diphtheria +
#     Hepatitis.B:GDP + Hepatitis.B:Schooling + BMI:Schooling +
#     Polio:Diphtheria + Polio:Schooling + Diphtheria:GDP + Diphtheria:Schooling
#
#                             Df Sum of Sq    RSS    AIC
# - Hepatitis.B:GDP            1     2.326 1306.0 439.31
# - Alcohol:Hepatitis.B        1     5.359 1309.1 439.57
# - I(Diphtheria^2)            1     6.622 1310.3 439.69
# - Hepatitis.B:Schooling      1     6.819 1310.5 439.70
# - Diphtheria:GDP             1     7.535 1311.2 439.77
# - I(Hepatitis.B^2)           1     8.980 1312.7 439.89
# - Hepatitis.B:Diphtheria     1     9.116 1312.8 439.90
# - Alcohol:BMI                1     9.280 1313.0 439.92
# - I(Polio^2)                 1    10.568 1314.3 440.03
# - Status:Polio               1    11.343 1315.0 440.10
# - Status:Hepatitis.B         1    17.254 1321.0 440.61
# - I(Schooling^2)             1    17.633 1321.3 440.65
# - Status:Diphtheria          1    20.969 1324.7 440.94
# - infant.deaths:GDP          1    21.664 1325.4 441.00
# - I(Alcohol^2)               1    21.737 1325.4 441.00
# - Alcohol:Diphtheria         1    38.478 1342.2 442.45
# - Alcohol:GDP                1    41.343 1345.0 442.69
# <none>                                   1303.7 442.91
# - infant.deaths:Schooling    1    47.401 1351.1 443.21
# - Status:infant.deaths       1    49.000 1352.7 443.35
# - Alcohol:Polio              1    49.536 1353.2 443.39
# - Status:Alcohol             1    56.130 1359.8 443.95
# - Status:Schooling           1    82.554 1386.2 446.16
# - Hepatitis.B:BMI            1    85.195 1388.9 446.38
# - Diphtheria:Schooling       1    95.950 1399.7 447.27
# - I(BMI^2)                   1    96.394 1400.1 447.31
# - Hepatitis.B:Polio          1    96.963 1400.7 447.35
# - Polio:Diphtheria           1   100.288 1404.0 447.63
# - BMI:Schooling              1   118.173 1421.9 449.08
# - infant.deaths:Alcohol      1   123.031 1426.7 449.47
# - infant.deaths:Diphtheria   1   123.108 1426.8 449.48
# - Polio:Schooling            1   194.645 1498.3 455.11
# - infant.deaths:Hepatitis.B  1   218.610 1522.3 456.93
# - infant.deaths:Polio        1   227.104 1530.8 457.57
#
# Step:  AIC=439.31
# Life.expectancy ~ Status + infant.deaths + Alcohol + Hepatitis.B +
#     BMI + Polio + Diphtheria + GDP + Schooling + I(Alcohol^2) +
#     I(Hepatitis.B^2) + I(BMI^2) + I(Polio^2) + I(Diphtheria^2) +
#     I(Schooling^2) + Status:infant.deaths + Status:Alcohol +
#     Status:Hepatitis.B + Status:Polio + Status:Diphtheria + Status:Schooling +
#     infant.deaths:Alcohol + infant.deaths:Hepatitis.B + infant.deaths:Polio +
#     infant.deaths:Diphtheria + infant.deaths:GDP + infant.deaths:Schooling +
#     Alcohol:Hepatitis.B + Alcohol:BMI + Alcohol:Polio + Alcohol:Diphtheria +
#     Alcohol:GDP + Hepatitis.B:BMI + Hepatitis.B:Polio + Hepatitis.B:Diphtheria +
#     Hepatitis.B:Schooling + BMI:Schooling + Polio:Diphtheria +
#     Polio:Schooling + Diphtheria:GDP + Diphtheria:Schooling
#
#                             Df Sum of Sq    RSS    AIC
# - I(Diphtheria^2)            1     5.200 1311.2 435.96
# - Diphtheria:GDP             1     5.275 1311.3 435.96
# - Alcohol:Hepatitis.B        1     7.171 1313.2 436.13
# - Hepatitis.B:Schooling      1     7.879 1313.9 436.19
# - Alcohol:BMI                1     8.314 1314.3 436.23
# - Hepatitis.B:Diphtheria     1    10.050 1316.1 436.38
# - I(Polio^2)                 1    11.601 1317.6 436.52
# - I(Hepatitis.B^2)           1    15.291 1321.3 436.84
# - Status:Polio               1    15.531 1321.5 436.86
# - Status:Hepatitis.B         1    16.118 1322.1 436.91
# - I(Schooling^2)             1    17.733 1323.8 437.05
# - I(Alcohol^2)               1    20.394 1326.4 437.28
# - infant.deaths:GDP          1    22.042 1328.1 437.43
# - Status:Diphtheria          1    24.223 1330.2 437.61
# - Alcohol:GDP                1    40.101 1346.1 438.98
# - Alcohol:Diphtheria         1    42.470 1348.5 439.18
# <none>                                   1306.0 439.31
# - infant.deaths:Schooling    1    48.738 1354.8 439.71
# - Alcohol:Polio              1    49.785 1355.8 439.80
# - Status:infant.deaths       1    51.190 1357.2 439.92
# - Status:Alcohol             1    57.202 1363.2 440.43
# - Status:Schooling           1    80.388 1386.4 442.37
# - Hepatitis.B:BMI            1    82.930 1389.0 442.58
# - I(BMI^2)                   1    96.013 1402.0 443.66
# - Hepatitis.B:Polio          1    99.919 1405.9 443.98
# - Polio:Diphtheria           1   102.150 1408.2 444.16
# - Diphtheria:Schooling       1   104.590 1410.6 444.36
# - BMI:Schooling              1   121.442 1427.5 445.73
# - infant.deaths:Alcohol      1   130.427 1436.5 446.45
# - infant.deaths:Diphtheria   1   137.252 1443.3 446.99
# - Polio:Schooling            1   203.340 1509.4 452.14
# - infant.deaths:Polio        1   237.141 1543.2 454.69
# - infant.deaths:Hepatitis.B  1   240.330 1546.3 454.93
#
# Step:  AIC=435.96
# Life.expectancy ~ Status + infant.deaths + Alcohol + Hepatitis.B +
#     BMI + Polio + Diphtheria + GDP + Schooling + I(Alcohol^2) +
#     I(Hepatitis.B^2) + I(BMI^2) + I(Polio^2) + I(Schooling^2) +
#     Status:infant.deaths + Status:Alcohol + Status:Hepatitis.B +
#     Status:Polio + Status:Diphtheria + Status:Schooling + infant.deaths:Alcohol +
#     infant.deaths:Hepatitis.B + infant.deaths:Polio + infant.deaths:Diphtheria +
#     infant.deaths:GDP + infant.deaths:Schooling + Alcohol:Hepatitis.B +
#     Alcohol:BMI + Alcohol:Polio + Alcohol:Diphtheria + Alcohol:GDP +
#     Hepatitis.B:BMI + Hepatitis.B:Polio + Hepatitis.B:Diphtheria +
#     Hepatitis.B:Schooling + BMI:Schooling + Polio:Diphtheria +
#     Polio:Schooling + Diphtheria:GDP + Diphtheria:Schooling
#
#                             Df Sum of Sq    RSS    AIC
# - Diphtheria:GDP             1     2.013 1313.2 432.33
# - Hepatitis.B:Schooling      1     4.111 1315.3 432.51
# - Hepatitis.B:Diphtheria     1     4.861 1316.1 432.58
# - Alcohol:Hepatitis.B        1     5.653 1316.9 432.65
# - Alcohol:BMI                1     8.859 1320.1 432.93
# - Status:Hepatitis.B         1    11.060 1322.3 433.12
# - I(Hepatitis.B^2)           1    14.925 1326.2 433.45
# - Status:Polio               1    17.215 1328.4 433.65
# - I(Schooling^2)             1    17.892 1329.1 433.71
# - I(Alcohol^2)               1    23.007 1334.2 434.15
# - infant.deaths:GDP          1    24.906 1336.1 434.32
# - Status:Diphtheria          1    25.639 1336.9 434.38
# - I(Polio^2)                 1    28.255 1339.5 434.60
# - Alcohol:Diphtheria         1    37.447 1348.7 435.39
# <none>                                   1311.2 435.96
# - Alcohol:Polio              1    44.590 1355.8 436.00
# - Alcohol:GDP                1    51.433 1362.7 436.58
# - infant.deaths:Schooling    1    53.696 1364.9 436.77
# - Status:infant.deaths       1    54.053 1365.3 436.80
# - Status:Alcohol             1    55.131 1366.3 436.89
# - Hepatitis.B:BMI            1    78.497 1389.7 438.84
# - Status:Schooling           1    85.234 1396.5 439.39
# - I(BMI^2)                   1    94.522 1405.8 440.16
# - Diphtheria:Schooling       1   104.828 1416.0 441.00
# - BMI:Schooling              1   127.919 1439.1 442.86
# - Polio:Diphtheria           1   142.701 1453.9 444.03
# - infant.deaths:Alcohol      1   143.161 1454.4 444.07
# - Hepatitis.B:Polio          1   167.060 1478.3 445.94
# - infant.deaths:Diphtheria   1   174.792 1486.0 446.54
# - Polio:Schooling            1   198.802 1510.0 448.39
# - infant.deaths:Polio        1   233.815 1545.0 451.02
# - infant.deaths:Hepatitis.B  1   258.313 1569.5 452.83
#
# Step:  AIC=432.33
# Life.expectancy ~ Status + infant.deaths + Alcohol + Hepatitis.B +
#     BMI + Polio + Diphtheria + GDP + Schooling + I(Alcohol^2) +
#     I(Hepatitis.B^2) + I(BMI^2) + I(Polio^2) + I(Schooling^2) +
#     Status:infant.deaths + Status:Alcohol + Status:Hepatitis.B +
#     Status:Polio + Status:Diphtheria + Status:Schooling + infant.deaths:Alcohol +
#     infant.deaths:Hepatitis.B + infant.deaths:Polio + infant.deaths:Diphtheria +
#     infant.deaths:GDP + infant.deaths:Schooling + Alcohol:Hepatitis.B +
#     Alcohol:BMI + Alcohol:Polio + Alcohol:Diphtheria + Alcohol:GDP +
#     Hepatitis.B:BMI + Hepatitis.B:Polio + Hepatitis.B:Diphtheria +
#     Hepatitis.B:Schooling + BMI:Schooling + Polio:Diphtheria +
#     Polio:Schooling + Diphtheria:Schooling
#
#                             Df Sum of Sq    RSS    AIC
# - Hepatitis.B:Schooling      1     3.182 1316.4 428.80
# - Hepatitis.B:Diphtheria     1     3.887 1317.1 428.86
# - Alcohol:Hepatitis.B        1     4.679 1317.9 428.93
# - Alcohol:BMI                1     9.065 1322.3 429.31
# - Status:Hepatitis.B         1     9.610 1322.8 429.36
# - I(Hepatitis.B^2)           1    13.721 1327.0 429.72
# - Status:Polio               1    15.346 1328.6 429.86
# - I(Schooling^2)             1    17.766 1331.0 430.07
# - I(Alcohol^2)               1    22.315 1335.5 430.46
# - Status:Diphtheria          1    23.631 1336.9 430.57
# - infant.deaths:GDP          1    25.564 1338.8 430.74
# - I(Polio^2)                 1    26.242 1339.5 430.80
# - Alcohol:Diphtheria         1    35.467 1348.7 431.59
# <none>                                   1313.2 432.33
# - Alcohol:Polio              1    47.305 1360.5 432.59
# - Status:Alcohol             1    53.715 1367.0 433.13
# - infant.deaths:Schooling    1    53.963 1367.2 433.15
# - Status:infant.deaths       1    55.118 1368.4 433.25
# - Alcohol:GDP                1    66.432 1379.7 434.20
# - Hepatitis.B:BMI            1    80.767 1394.0 435.39
# - Status:Schooling           1    88.450 1401.7 436.02
# - I(BMI^2)                   1    93.115 1406.3 436.40
# - Diphtheria:Schooling       1   103.223 1416.5 437.22
# - BMI:Schooling              1   129.512 1442.8 439.34
# - infant.deaths:Alcohol      1   142.537 1455.8 440.37
# - Polio:Diphtheria           1   147.793 1461.0 440.79
# - Hepatitis.B:Polio          1   170.951 1484.2 442.59
# - infant.deaths:Diphtheria   1   172.782 1486.0 442.74
# - Polio:Schooling            1   206.495 1519.7 445.32
# - infant.deaths:Polio        1   242.448 1555.7 448.00
# - infant.deaths:Hepatitis.B  1   256.968 1570.2 449.07
#
# Step:  AIC=428.8
# Life.expectancy ~ Status + infant.deaths + Alcohol + Hepatitis.B +
#     BMI + Polio + Diphtheria + GDP + Schooling + I(Alcohol^2) +
#     I(Hepatitis.B^2) + I(BMI^2) + I(Polio^2) + I(Schooling^2) +
#     Status:infant.deaths + Status:Alcohol + Status:Hepatitis.B +
#     Status:Polio + Status:Diphtheria + Status:Schooling + infant.deaths:Alcohol +
#     infant.deaths:Hepatitis.B + infant.deaths:Polio + infant.deaths:Diphtheria +
#     infant.deaths:GDP + infant.deaths:Schooling + Alcohol:Hepatitis.B +
#     Alcohol:BMI + Alcohol:Polio + Alcohol:Diphtheria + Alcohol:GDP +
#     Hepatitis.B:BMI + Hepatitis.B:Polio + Hepatitis.B:Diphtheria +
#     BMI:Schooling + Polio:Diphtheria + Polio:Schooling + Diphtheria:Schooling
#
#                             Df Sum of Sq    RSS    AIC
# - Hepatitis.B:Diphtheria     1     1.151 1317.6 425.09
# - Alcohol:Hepatitis.B        1     1.519 1317.9 425.13
# - Status:Hepatitis.B         1     6.441 1322.9 425.55
# - Alcohol:BMI                1     9.752 1326.2 425.84
# - I(Hepatitis.B^2)           1    12.213 1328.6 426.06
# - Status:Polio               1    14.454 1330.9 426.25
# - I(Schooling^2)             1    15.897 1332.3 426.37
# - I(Alcohol^2)               1    20.543 1337.0 426.77
# - Status:Diphtheria          1    21.343 1337.8 426.84
# - I(Polio^2)                 1    23.733 1340.2 427.05
# - infant.deaths:GDP          1    26.322 1342.7 427.27
# - Alcohol:Diphtheria         1    37.309 1353.7 428.21
# <none>                                   1316.4 428.80
# - Status:Alcohol             1    50.656 1367.1 429.34
# - Alcohol:Polio              1    51.595 1368.0 429.41
# - infant.deaths:Schooling    1    53.198 1369.6 429.55
# - Status:infant.deaths       1    53.248 1369.7 429.55
# - Alcohol:GDP                1    64.365 1380.8 430.48
# - Hepatitis.B:BMI            1    77.642 1394.1 431.58
# - Status:Schooling           1    85.920 1402.3 432.26
# - I(BMI^2)                   1    90.098 1406.5 432.61
# - BMI:Schooling              1   127.944 1444.4 435.66
# - infant.deaths:Alcohol      1   139.739 1456.2 436.59
# - Diphtheria:Schooling       1   164.179 1480.6 438.51
# - Polio:Diphtheria           1   168.394 1484.8 438.84
# - infant.deaths:Diphtheria   1   169.649 1486.1 438.93
# - Hepatitis.B:Polio          1   188.977 1505.4 440.42
# - Polio:Schooling            1   210.406 1526.8 442.04
# - infant.deaths:Polio        1   245.707 1562.1 444.67
# - infant.deaths:Hepatitis.B  1   253.919 1570.3 445.28
#
# Step:  AIC=425.09
# ...
#
#                             Df Sum of Sq    RSS    AIC
# - I(Alcohol^2)               1     12.90 1352.5 412.88
# - Status:Polio               1     17.41 1357.0 413.26
# - Status:Hepatitis.B         1     21.67 1361.3 413.62
# - I(Hepatitis.B^2)           1     22.62 1362.3 413.70
# - Status:Diphtheria          1     25.27 1364.9 413.93
# - I(Polio^2)                 1     31.44 1371.1 414.44
# - infant.deaths:GDP          1     41.67 1381.3 415.30
# <none>                                   1339.6 415.58
# - Status:infant.deaths       1     56.18 1395.8 416.50
# - Alcohol:Polio              1     66.77 1406.4 417.37
# - Status:Alcohol             1     67.61 1407.2 417.44
# - Alcohol:Diphtheria         1     73.11 1412.7 417.89
# - infant.deaths:Schooling    1     78.21 1417.8 418.30
# - I(BMI^2)                   1     82.72 1422.3 418.67
# - Status:Schooling           1     83.99 1423.6 418.77
# - Alcohol:GDP                1     90.05 1429.7 419.26
# - Hepatitis.B:BMI            1    116.68 1456.3 421.38
# - BMI:Schooling              1    130.05 1469.7 422.43
# - Diphtheria:Schooling       1    162.53 1502.2 424.95
# - infant.deaths:Alcohol      1    198.45 1538.1 427.66
# - infant.deaths:Diphtheria   1    227.68 1567.3 429.83
# - Polio:Schooling            1    232.90 1572.5 430.21
# - infant.deaths:Polio        1    259.25 1598.9 432.12
# - Polio:Diphtheria           1    272.81 1612.5 433.09
# - infant.deaths:Hepatitis.B  1    316.83 1656.5 436.19
# - Hepatitis.B:Polio          1    324.30 1663.9 436.71
#
# Step:  AIC=412.88
# Life.expectancy ~ Status + infant.deaths + Alcohol + Hepatitis.B +
#     BMI + Polio + Diphtheria + GDP + Schooling + I(Hepatitis.B^2) +
#     I(BMI^2) + I(Polio^2) + Status:infant.deaths + Status:Alcohol +
#     Status:Hepatitis.B + Status:Polio + Status:Diphtheria + Status:Schooling +
#     infant.deaths:Alcohol + infant.deaths:Hepatitis.B + infant.deaths:Polio +
#     infant.deaths:Diphtheria + infant.deaths:GDP + infant.deaths:Schooling +
#     Alcohol:Polio + Alcohol:Diphtheria + Alcohol:GDP + Hepatitis.B:BMI +
#     Hepatitis.B:Polio + BMI:Schooling + Polio:Diphtheria + Polio:Schooling +
#     Diphtheria:Schooling
#
#                             Df Sum of Sq    RSS    AIC
# - Status:Polio               1    18.659 1371.2 410.65
# - Status:Hepatitis.B         1    20.473 1373.0 410.80
# - I(Hepatitis.B^2)           1    25.213 1377.8 411.20
# - Status:Diphtheria          1    27.356 1379.9 411.38
# - I(Polio^2)                 1    32.563 1385.1 411.81
# - infant.deaths:GDP          1    37.616 1390.2 412.23
# <none>                                   1352.5 412.88
# - Status:infant.deaths       1    56.750 1409.3 413.80
# - Alcohol:Polio              1    67.995 1420.5 414.71
# - Alcohol:Diphtheria         1    68.511 1421.0 414.76
# - infant.deaths:Schooling    1    70.182 1422.7 414.89
# - I(BMI^2)                   1    72.832 1425.4 415.10
# - Status:Schooling           1    84.239 1436.8 416.02
# - Status:Alcohol             1    89.882 1442.4 416.47
# - Alcohol:GDP                1    93.541 1446.1 416.76
# - Hepatitis.B:BMI            1   115.044 1467.6 418.46
# - BMI:Schooling              1   130.820 1483.4 419.69
# - Diphtheria:Schooling       1   165.900 1518.4 422.38
# - infant.deaths:Alcohol      1   186.014 1538.6 423.89
# - infant.deaths:Diphtheria   1   215.754 1568.3 426.09
# - Polio:Schooling            1   234.295 1586.8 427.44
# - infant.deaths:Polio        1   261.699 1614.2 429.41
# - Polio:Diphtheria           1   262.455 1615.0 429.47
# - infant.deaths:Hepatitis.B  1   305.429 1658.0 432.49
# - Hepatitis.B:Polio          1   313.247 1665.8 433.03
#
# Step:  AIC=410.65
# Life.expectancy ~ Status + infant.deaths + Alcohol + Hepatitis.B +
#     BMI + Polio + Diphtheria + GDP + Schooling + I(Hepatitis.B^2) +
#     I(BMI^2) + I(Polio^2) + Status:infant.deaths + Status:Alcohol +
#     Status:Hepatitis.B + Status:Diphtheria + Status:Schooling +
#     infant.deaths:Alcohol + infant.deaths:Hepatitis.B + infant.deaths:Polio +
#     infant.deaths:Diphtheria + infant.deaths:GDP + infant.deaths:Schooling +
#     Alcohol:Polio + Alcohol:Diphtheria + Alcohol:GDP + Hepatitis.B:BMI +
#     Hepatitis.B:Polio + BMI:Schooling + Polio:Diphtheria + Polio:Schooling +
#     Diphtheria:Schooling
#
#                             Df Sum of Sq    RSS    AIC
# - Status:Diphtheria          1     23.20 1394.4 408.77
# - I(Polio^2)                 1     26.79 1398.0 409.07
# - I(Hepatitis.B^2)           1     28.10 1399.3 409.18
# - Status:Hepatitis.B         1     33.11 1404.3 409.59
# - infant.deaths:GDP          1     38.14 1409.3 410.00
# - Status:infant.deaths       1     43.40 1414.6 410.43
# <none>                                   1371.2 410.65
# - infant.deaths:Schooling    1     71.29 1442.5 412.67
# - I(BMI^2)                   1     73.42 1444.6 412.84
# - Alcohol:Polio              1     80.45 1451.7 413.40
# - Status:Alcohol             1     80.74 1452.0 413.42
# - Alcohol:Diphtheria         1     81.30 1452.5 413.47
# - Alcohol:GDP                1    102.88 1474.1 415.16
# - Hepatitis.B:BMI            1    114.20 1485.4 416.04
# - BMI:Schooling              1    125.92 1497.1 416.95
# - Status:Schooling           1    141.51 1512.7 418.14
# - Diphtheria:Schooling       1    177.19 1548.4 420.82
# - infant.deaths:Alcohol      1    189.68 1560.9 421.74
# - infant.deaths:Diphtheria   1    225.17 1596.4 424.33
# - Polio:Schooling            1    245.56 1616.8 425.79
# - infant.deaths:Polio        1    271.10 1642.3 427.59
# - Polio:Diphtheria           1    277.88 1649.1 428.06
# - infant.deaths:Hepatitis.B  1    317.82 1689.0 430.81
# - Hepatitis.B:Polio          1    326.27 1697.5 431.39
#
# Step:  AIC=408.77
# Life.expectancy ~ Status + infant.deaths + Alcohol + Hepatitis.B +
#     BMI + Polio + Diphtheria + GDP + Schooling + I(Hepatitis.B^2) +
#     I(BMI^2) + I(Polio^2) + Status:infant.deaths + Status:Alcohol +
#     Status:Hepatitis.B + Status:Schooling + infant.deaths:Alcohol +
#     infant.deaths:Hepatitis.B + infant.deaths:Polio + infant.deaths:Diphtheria +
#     infant.deaths:GDP + infant.deaths:Schooling + Alcohol:Polio +
#     Alcohol:Diphtheria + Alcohol:GDP + Hepatitis.B:BMI + Hepatitis.B:Polio +
#     BMI:Schooling + Polio:Diphtheria + Polio:Schooling + Diphtheria:Schooling
#
#                             Df Sum of Sq    RSS    AIC
# - I(Hepatitis.B^2)           1    19.845 1414.2 406.59
# - Status:Hepatitis.B         1    23.795 1418.2 406.91
# - Status:infant.deaths       1    26.897 1421.3 407.16
# - infant.deaths:GDP          1    35.171 1429.6 407.83
# - I(Polio^2)                 1    36.581 1431.0 407.94
# <none>                                   1394.4 408.77
# - Status:Alcohol             1    57.630 1452.0 409.62
# - I(BMI^2)                   1    63.533 1457.9 410.09
# - infant.deaths:Schooling    1    67.613 1462.0 410.41
# - Alcohol:Polio              1    70.959 1465.4 410.67
# - Alcohol:GDP                1    81.882 1476.3 411.53
# - Alcohol:Diphtheria         1    82.748 1477.2 411.59
# - BMI:Schooling              1   111.623 1506.0 413.82
# - Hepatitis.B:BMI            1   114.056 1508.5 414.01
# - Status:Schooling           1   123.600 1518.0 414.73
# - Diphtheria:Schooling       1   160.075 1554.5 417.46
# - infant.deaths:Alcohol      1   179.086 1573.5 418.86
# - infant.deaths:Diphtheria   1   217.582 1612.0 421.64
# - Polio:Schooling            1   224.898 1619.3 422.16
# - infant.deaths:Polio        1   250.469 1644.9 423.96
# - Polio:Diphtheria           1   262.548 1657.0 424.80
# - infant.deaths:Hepatitis.B  1   301.754 1696.2 427.49
# - Hepatitis.B:Polio          1   309.941 1704.3 428.05
#
# Step:  AIC=406.59
# Life.expectancy ~ Status + infant.deaths + Alcohol + Hepatitis.B +
#     BMI + Polio + Diphtheria + GDP + Schooling + I(BMI^2) + I(Polio^2) +
#     Status:infant.deaths + Status:Alcohol + Status:Hepatitis.B +
#     Status:Schooling + infant.deaths:Alcohol + infant.deaths:Hepatitis.B +
#     infant.deaths:Polio + infant.deaths:Diphtheria + infant.deaths:GDP +
#     infant.deaths:Schooling + Alcohol:Polio + Alcohol:Diphtheria +
#     Alcohol:GDP + Hepatitis.B:BMI + Hepatitis.B:Polio + BMI:Schooling +
#     Polio:Diphtheria + Polio:Schooling + Diphtheria:Schooling
#
#                             Df Sum of Sq    RSS    AIC
# - Status:Hepatitis.B         1    16.904 1431.2 404.15
# - Status:infant.deaths       1    24.687 1438.9 404.77
# - infant.deaths:GDP          1    36.253 1450.5 405.69
# <none>                                   1414.2 406.59
# - I(BMI^2)                   1    51.590 1465.8 406.90
# - Status:Alcohol             1    54.210 1468.5 407.11
# - infant.deaths:Schooling    1    68.510 1482.8 408.22
# - Alcohol:GDP                1    69.339 1483.6 408.29
# - Alcohol:Polio              1    73.828 1488.1 408.64
# - Alcohol:Diphtheria         1    80.465 1494.7 409.15
# - BMI:Schooling              1    98.071 1512.3 410.49
# - I(Polio^2)                 1   101.058 1515.3 410.72
# - Status:Schooling           1   111.467 1525.7 411.51
# - Hepatitis.B:BMI            1   114.224 1528.5 411.72
# - Diphtheria:Schooling       1   150.142 1564.4 414.39
# - infant.deaths:Alcohol      1   173.665 1587.9 416.10
# - infant.deaths:Diphtheria   1   205.971 1620.2 418.42
# - Polio:Schooling            1   215.422 1629.7 419.09
# - infant.deaths:Polio        1   242.981 1657.2 421.02
# - Polio:Diphtheria           1   254.552 1668.8 421.82
# - infant.deaths:Hepatitis.B  1   289.326 1703.6 424.19
# - Hepatitis.B:Polio          1   297.063 1711.3 424.71
#
# Step:  AIC=404.15
# Life.expectancy ~ Status + infant.deaths + Alcohol + Hepatitis.B +
#     BMI + Polio + Diphtheria + GDP + Schooling + I(BMI^2) + I(Polio^2) +
#     Status:infant.deaths + Status:Alcohol + Status:Schooling +
#     infant.deaths:Alcohol + infant.deaths:Hepatitis.B + infant.deaths:Polio +
#     infant.deaths:Diphtheria + infant.deaths:GDP + infant.deaths:Schooling +
#     Alcohol:Polio + Alcohol:Diphtheria + Alcohol:GDP + Hepatitis.B:BMI +
#     Hepatitis.B:Polio + BMI:Schooling + Polio:Diphtheria + Polio:Schooling +
#     Diphtheria:Schooling
#
#                             Df Sum of Sq    RSS    AIC
# - infant.deaths:GDP          1     40.60 1471.8 403.56
# <none>                                   1431.2 404.15
# - Status:infant.deaths       1     50.38 1481.5 404.32
# - I(BMI^2)                   1     52.65 1483.8 404.50
# - Status:Alcohol             1     66.72 1497.9 405.58
# - Alcohol:GDP                1     69.92 1501.1 405.83
# - Alcohol:Polio              1     78.60 1509.8 406.49
# - Alcohol:Diphtheria         1     78.80 1510.0 406.51
# - infant.deaths:Schooling    1     79.39 1510.5 406.55
# - BMI:Schooling              1     86.54 1517.7 407.10
# - Status:Schooling           1     96.61 1527.8 407.86
# - I(Polio^2)                 1    104.81 1536.0 408.47
# - Diphtheria:Schooling       1    152.72 1583.9 412.00
# - Hepatitis.B:BMI            1    157.59 1588.8 412.36
# - infant.deaths:Alcohol      1    191.06 1622.2 414.75
# - infant.deaths:Diphtheria   1    219.51 1650.7 416.75
# - Polio:Schooling            1    221.36 1652.5 416.88
# - infant.deaths:Polio        1    250.81 1682.0 418.91
# - Polio:Diphtheria           1    274.27 1705.4 420.51
# - infant.deaths:Hepatitis.B  1    306.51 1737.7 422.66
# - Hepatitis.B:Polio          1    317.52 1748.7 423.39
#
# Step:  AIC=403.56
# Life.expectancy ~ Status + infant.deaths + Alcohol + Hepatitis.B +
#     BMI + Polio + Diphtheria + GDP + Schooling + I(BMI^2) + I(Polio^2) +
#     Status:infant.deaths + Status:Alcohol + Status:Schooling +
#     infant.deaths:Alcohol + infant.deaths:Hepatitis.B + infant.deaths:Polio +
#     infant.deaths:Diphtheria + infant.deaths:Schooling + Alcohol:Polio +
#     Alcohol:Diphtheria + Alcohol:GDP + Hepatitis.B:BMI + Hepatitis.B:Polio +
#     BMI:Schooling + Polio:Diphtheria + Polio:Schooling + Diphtheria:Schooling
#
#                             Df Sum of Sq    RSS    AIC
# - I(BMI^2)                   1    37.688 1509.4 402.66
# - infant.deaths:Schooling    1    42.198 1514.0 403.00
# <none>                                   1471.8 403.56
# - Status:infant.deaths       1    61.185 1532.9 404.44
# - Status:Alcohol             1    67.553 1539.3 404.91
# - Alcohol:Polio              1    69.410 1541.2 405.05
# - Alcohol:Diphtheria         1    81.680 1553.4 405.96
# - Alcohol:GDP                1    81.763 1553.5 405.97
# - BMI:Schooling              1    95.823 1567.6 407.01
# - Status:Schooling           1    97.162 1568.9 407.11
# - I(Polio^2)                 1   103.831 1575.6 407.59
# - Hepatitis.B:BMI            1   130.590 1602.3 409.53
# - Diphtheria:Schooling       1   143.514 1615.3 410.45
# - infant.deaths:Alcohol      1   154.999 1626.8 411.27
# - infant.deaths:Diphtheria   1   182.288 1654.0 413.18
# - Polio:Schooling            1   200.224 1672.0 414.42
# - infant.deaths:Polio        1   229.680 1701.4 416.43
# - Polio:Diphtheria           1   236.043 1707.8 416.86
# - infant.deaths:Hepatitis.B  1   266.776 1738.5 418.91
# - Hepatitis.B:Polio          1   277.741 1749.5 419.63
#
# Step:  AIC=402.66
# Life.expectancy ~ Status + infant.deaths + Alcohol + Hepatitis.B +
#     BMI + Polio + Diphtheria + GDP + Schooling + I(Polio^2) +
#     Status:infant.deaths + Status:Alcohol + Status:Schooling +
#     infant.deaths:Alcohol + infant.deaths:Hepatitis.B + infant.deaths:Polio +
#     infant.deaths:Diphtheria + infant.deaths:Schooling + Alcohol:Polio +
#     Alcohol:Diphtheria + Alcohol:GDP + Hepatitis.B:BMI + Hepatitis.B:Polio +
#     BMI:Schooling + Polio:Diphtheria + Polio:Schooling + Diphtheria:Schooling
#
#                             Df Sum of Sq    RSS    AIC
# - infant.deaths:Schooling    1    26.426 1535.9 400.85
# <none>                                   1509.4 402.66
# - Status:Alcohol             1    65.682 1575.1 403.75
# - Status:infant.deaths       1    67.645 1577.1 403.90
# - Alcohol:Polio              1    70.585 1580.0 404.11
# - Alcohol:GDP                1    73.963 1583.4 404.36
# - BMI:Schooling              1    78.101 1587.5 404.66
# - Alcohol:Diphtheria         1    87.493 1596.9 405.33
# - I(Polio^2)                 1    90.636 1600.1 405.56
# - Hepatitis.B:BMI            1   115.539 1625.0 407.34
# - Status:Schooling           1   119.045 1628.5 407.58
# - infant.deaths:Alcohol      1   130.975 1640.4 408.42
# - Diphtheria:Schooling       1   141.854 1651.3 409.18
# - infant.deaths:Diphtheria   1   167.779 1677.2 410.98
# - Polio:Schooling            1   194.365 1703.8 412.78
# - Polio:Diphtheria           1   222.430 1731.9 414.66
# - infant.deaths:Polio        1   223.913 1733.4 414.76
# - infant.deaths:Hepatitis.B  1   249.701 1759.1 416.46
# - Hepatitis.B:Polio          1   261.240 1770.7 417.21
#
# Step:  AIC=400.85
# Life.expectancy ~ Status + infant.deaths + Alcohol + Hepatitis.B +
#     BMI + Polio + Diphtheria + GDP + Schooling + I(Polio^2) +
#     Status:infant.deaths + Status:Alcohol + Status:Schooling +
#     infant.deaths:Alcohol + infant.deaths:Hepatitis.B + infant.deaths:Polio +
#     infant.deaths:Diphtheria + Alcohol:Polio + Alcohol:Diphtheria +
#     Alcohol:GDP + Hepatitis.B:BMI + Hepatitis.B:Polio + BMI:Schooling +
#     Polio:Diphtheria + Polio:Schooling + Diphtheria:Schooling
#
#                             Df Sum of Sq    RSS    AIC
# <none>                                   1535.9 400.85
# - Alcohol:Polio              1    57.022 1592.9 401.24
# - Status:infant.deaths       1    75.356 1611.2 402.55
# - Status:Alcohol             1    75.983 1611.8 402.60
# - Alcohol:Diphtheria         1    88.640 1624.5 403.50
# - Alcohol:GDP                1    90.728 1626.6 403.64
# - Hepatitis.B:BMI            1    90.869 1626.7 403.65
# - I(Polio^2)                 1    91.012 1626.9 403.66
# - BMI:Schooling              1   110.072 1645.9 405.00
# - Status:Schooling           1   125.873 1661.7 406.10
# - Diphtheria:Schooling       1   131.566 1667.4 406.50
# - infant.deaths:Diphtheria   1   143.660 1679.5 407.33
# - infant.deaths:Alcohol      1   161.198 1697.1 408.52
# - Polio:Schooling            1   172.724 1708.6 409.30
# - Polio:Diphtheria           1   200.337 1736.2 411.14
# - infant.deaths:Polio        1   202.817 1738.7 411.31
# - infant.deaths:Hepatitis.B  1   232.658 1768.5 413.26
# - Hepatitis.B:Polio          1   244.315 1780.2 414.02

# %%
BICmod = lm(Life.expectancy ~ Status + infant.deaths + Alcohol + Hepatitis.B + 
    BMI + Polio + Diphtheria + GDP + Schooling + I(Polio^2) + 
    Status:infant.deaths + Status:Alcohol + Status:Schooling + 
    infant.deaths:Alcohol + infant.deaths:Hepatitis.B + infant.deaths:Polio + 
    infant.deaths:Diphtheria + Alcohol:Polio + Alcohol:Diphtheria + 
    Alcohol:GDP + Hepatitis.B:BMI + Hepatitis.B:Polio + BMI:Schooling + 
    Polio:Diphtheria + Polio:Schooling + Diphtheria:Schooling , data = train_data)

summary(BICmod)

BICtrain_predict = predict.lm(BICmod, train_data)
(BICtrain_mse_OLS = mean((BICtrain_predict - train_data$Life.expectancy)^2))

BICtest_predict = predict.lm(BICmod, test_data)
(BICtest_mse_ols = mean((BICtest_predict - test_data$Life.expectancy)^2))

plot_residuals(BICmod, 'BIcmod')
ggplot (data = test_data, aes (x=Life.expectancy,y= BICtest_predict)) +
  geom_smooth(se=F,method = "lm",colour = "gray35") + geom_point() +
  ggtitle('Linear Regression: Ground Truth vs Predicted') +
  xlab('Ground Truth') +
  ylab('Predicted')
# Out:
# Call:
# lm(formula = Life.expectancy ~ Status + infant.deaths + Alcohol +
#     Hepatitis.B + BMI + Polio + Diphtheria + GDP + Schooling +
#     I(Polio^2) + Status:infant.deaths + Status:Alcohol + Status:Schooling +
#     infant.deaths:Alcohol + infant.deaths:Hepatitis.B + infant.deaths:Polio +
#     infant.deaths:Diphtheria + Alcohol:Polio + Alcohol:Diphtheria +
#     Alcohol:GDP + Hepatitis.B:BMI + Hepatitis.B:Polio + BMI:Schooling +
#     Polio:Diphtheria + Polio:Schooling + Diphtheria:Schooling,
#     data = train_data)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -16.1907  -1.5459   0.2824   2.2200   7.8688
#
# Coefficients:
#                                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)                     1.012e+02  1.875e+01   5.398 5.65e-07 ***
# StatusDeveloping               -5.760e+01  1.676e+01  -3.436 0.000903 ***
# infant.deaths                  -3.279e+00  1.449e+00  -2.262 0.026154 *
# Alcohol                        -3.976e+00  1.819e+00  -2.186 0.031505 *
# Hepatitis.B                     2.043e+00  5.517e-01   3.703 0.000372 ***
# BMI                             6.321e-01  1.539e-01   4.107 8.95e-05 ***
# Polio                          -1.537e+00  3.945e-01  -3.896 0.000190 ***
# Diphtheria                     -8.762e-01  3.979e-01  -2.202 0.030262 *
# GDP                            -6.764e-06  8.718e-05  -0.078 0.938330
# Schooling                       7.529e-01  1.311e+00   0.574 0.567266
# I(Polio^2)                      3.568e-03  1.562e-03   2.284 0.024805 *
# StatusDeveloping:infant.deaths  3.023e+00  1.455e+00   2.078 0.040633 *
# StatusDeveloping:Alcohol        1.907e+00  9.139e-01   2.087 0.039825 *
# StatusDeveloping:Schooling      2.163e+00  8.056e-01   2.686 0.008654 **
# infant.deaths:Alcohol          -1.143e-02  3.760e-03  -3.039 0.003124 **
# infant.deaths:Hepatitis.B      -3.578e-02  9.801e-03  -3.651 0.000443 ***
# infant.deaths:Polio             1.768e-02  5.187e-03   3.409 0.000986 ***
# infant.deaths:Diphtheria        2.145e-02  7.477e-03   2.869 0.005154 **
# Alcohol:Polio                  -5.023e-02  2.779e-02  -1.808 0.074097 .
# Alcohol:Diphtheria              6.766e-02  3.002e-02   2.254 0.026705 *
# Alcohol:GDP                     2.459e-05  1.078e-05   2.280 0.025025 *
# Hepatitis.B:BMI                -2.666e-03  1.168e-03  -2.282 0.024916 *
# Hepatitis.B:Polio              -2.072e-02  5.539e-03  -3.741 0.000325 ***
# BMI:Schooling                  -2.699e-02  1.075e-02  -2.511 0.013854 *
# Polio:Diphtheria                2.018e-02  5.956e-03   3.388 0.001055 **
# Polio:Schooling                 1.051e-01  3.341e-02   3.146 0.002259 **
# Diphtheria:Schooling           -1.063e-01  3.873e-02  -2.746 0.007323 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 4.178 on 88 degrees of freedom
# Multiple R-squared:  0.8228,	Adjusted R-squared:  0.7705
# F-statistic: 15.72 on 26 and 88 DF,  p-value: < 2.2e-16
# [1] 13.35537
# [1] 365.9492
# `geom_smooth()` using formula 'y ~ x'
# Plot with title “”
# plot without title

# %% [markdown]
# Delete insignificant variables:

# %%
BICM = lm(Life.expectancy ~ Status + infant.deaths + Alcohol + Hepatitis.B + 
    BMI + Polio + Diphtheria + I(Polio^2) + 
    Status:infant.deaths + Status:Alcohol + Status:Schooling + 
    infant.deaths:Alcohol + infant.deaths:Hepatitis.B + infant.deaths:Polio + 
    infant.deaths:Diphtheria + Alcohol:Diphtheria + 
    Alcohol:GDP + Hepatitis.B:BMI + Hepatitis.B:Polio + BMI:Schooling + 
    Polio:Diphtheria + Polio:Schooling + Diphtheria:Schooling , data = train_data)

summary(BICM)

BICMtrain_predict = predict.lm(BICM, train_data)
(BICMtrain_mse_OLS = mean((BICMtrain_predict - train_data$Life.expectancy)^2))

BICMtest_predict = predict.lm(BICM, test_data)
(BICMtest_mse_ols = mean((BICMtest_predict - test_data$Life.expectancy)^2))

plot_residuals(BICmod, 'BIcmod')
ggplot (data = test_data, aes (x=Life.expectancy,y= BICMtest_predict)) +
  geom_smooth(se=F,method = "lm",colour = "gray35") + geom_point() +
  ggtitle('Linear Regression: Ground Truth vs Predicted') +
  xlab('Ground Truth') +
  ylab('Predicted')
# Out:
# Call:
# lm(formula = Life.expectancy ~ Status + infant.deaths + Alcohol +
#     Hepatitis.B + BMI + Polio + Diphtheria + I(Polio^2) + Status:infant.deaths +
#     Status:Alcohol + Status:Schooling + infant.deaths:Alcohol +
#     infant.deaths:Hepatitis.B + infant.deaths:Polio + infant.deaths:Diphtheria +
#     Alcohol:Diphtheria + Alcohol:GDP + Hepatitis.B:BMI + Hepatitis.B:Polio +
#     BMI:Schooling + Polio:Diphtheria + Polio:Schooling + Diphtheria:Schooling,
#     data = train_data)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -16.1873  -1.7433   0.5025   2.3302   7.7409
#
# Coefficients:
#                                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)                     1.077e+02  1.833e+01   5.878 6.93e-08 ***
# StatusDeveloping               -6.196e+01  1.654e+01  -3.746 0.000317 ***
# infant.deaths                  -3.405e+00  1.458e+00  -2.336 0.021723 *
# Alcohol                        -4.536e+00  1.805e+00  -2.512 0.013778 *
# Hepatitis.B                     1.490e+00  4.602e-01   3.237 0.001691 **
# BMI                             6.337e-01  1.550e-01   4.089 9.41e-05 ***
# Polio                          -1.174e+00  3.418e-01  -3.433 0.000904 ***
# Diphtheria                     -6.886e-01  3.854e-01  -1.787 0.077349 .
# I(Polio^2)                      4.557e-03  1.467e-03   3.107 0.002533 **
# StatusDeveloping:infant.deaths  3.228e+00  1.460e+00   2.211 0.029593 *
# StatusDeveloping:Alcohol        2.163e+00  9.017e-01   2.399 0.018496 *
# StatusDeveloped:Schooling       1.708e-01  1.272e+00   0.134 0.893497
# StatusDeveloping:Schooling      2.431e+00  9.543e-01   2.547 0.012566 *
# infant.deaths:Alcohol          -8.974e-03  3.519e-03  -2.550 0.012460 *
# infant.deaths:Hepatitis.B      -2.606e-02  8.213e-03  -3.173 0.002062 **
# infant.deaths:Polio             1.170e-02  4.018e-03   2.911 0.004541 **
# infant.deaths:Diphtheria        1.676e-02  7.027e-03   2.385 0.019176 *
# Alcohol:Diphtheria              2.074e-02  1.497e-02   1.385 0.169341
# Alcohol:GDP                     2.592e-05  6.645e-06   3.901 0.000185 ***
# Hepatitis.B:BMI                -2.175e-03  1.141e-03  -1.905 0.059960 .
# Hepatitis.B:Polio              -1.519e-02  4.629e-03  -3.281 0.001474 **
# BMI:Schooling                  -3.087e-02  1.060e-02  -2.914 0.004506 **
# Polio:Diphtheria                1.328e-02  4.580e-03   2.900 0.004686 **
# Polio:Schooling                 5.862e-02  2.149e-02   2.728 0.007666 **
# Diphtheria:Schooling           -5.356e-02  2.556e-02  -2.096 0.038933 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 4.207 on 90 degrees of freedom
# Multiple R-squared:  0.8162,	Adjusted R-squared:  0.7672
# F-statistic: 16.66 on 24 and 90 DF,  p-value: < 2.2e-16
# [1] 13.85191
# [1] 235.4941
# `geom_smooth()` using formula 'y ~ x'
# Plot with title “”
# plot without title

# %% [markdown]
# Finally I decede to choose AICM as my final model. Since it has a relatively high adjusted-$R^2$ with relatively low training MSE and testing MSE.

# %% [markdown]
# ### 2.2 Data Analysis A.2 (10 points)
# Based on the significant factors you found in Analysis A.1, the investigator want to find whether
# some of these significant health and economical factors (except for Status) have different effects
# between developed and developing countries. Please create a model with justification to answer
# this question.

# %%
str(life)
# Out:
# 'data.frame':	141 obs. of  11 variables:
#  $ Life.expectancy  : num  58.8 76.2 74.7 49.6 75.6 75.5 73.5 81.9 84 71.1 ...
#  $ Status           : Factor w/ 2 levels "Developed","Developing": 2 2 2 2 2 2 2 1 1 2 ...
#  $ infant.deaths    : int  74 1 21 78 0 10 1 1 0 5 ...
#  $ Alcohol          : num  0.01 5.28 0.45 7.8 7.84 ...
#  $ Hepatitis.B      : int  66 99 95 77 98 94 94 92 86 8 ...
#  $ BMI              : num  16.7 54.3 53.9 2.4 44.4 59.8 51.2 63.9 55.2 48 ...
#  $ under.five.deaths: int  102 1 24 121 0 11 1 1 0 6 ...
#  $ Polio            : int  66 99 95 81 99 95 96 92 86 85 ...
#  $ Diphtheria       : int  66 99 95 77 98 94 94 92 86 81 ...
#  $ GDP              : num  553 494 4463 3530 12127 ...
#  $ Schooling        : num  9.2 12.5 13.6 9 14.1 16.8 12.3 19.5 15.4 11.7 ...
#  - attr(*, "na.action")= 'omit' Named int [1:41] 11 20 28 39 44 45 46 47 51 53 ...
#   ..- attr(*, "names")= chr [1:41] "166" "310" "438" "614" ...

# %%
life_split = split(life,life$Status)
life_developing = life_split$Developing
life_developed = life_split$Developed

# %%
AICM_developing = lm(Life.expectancy ~ Hepatitis.B + 
    BMI + Polio + Diphtheria + I(Polio^2) + 
    infant.deaths:Alcohol + infant.deaths:Hepatitis.B + infant.deaths:Polio + 
    infant.deaths:Diphtheria + infant.deaths:Schooling + 
    Alcohol:Polio + Alcohol:Diphtheria + Alcohol:GDP + Hepatitis.B:BMI + 
    Hepatitis.B:Polio + BMI:Schooling + Polio:Diphtheria + Polio:Schooling + 
    Diphtheria:Schooling, data = life_developing)
summary(AICM_developing)
plot_residuals(AICM_developing, 'AICM_developing')
# Out:
# Call:
# lm(formula = Life.expectancy ~ Hepatitis.B + BMI + Polio + Diphtheria +
#     I(Polio^2) + infant.deaths:Alcohol + infant.deaths:Hepatitis.B +
#     infant.deaths:Polio + infant.deaths:Diphtheria + infant.deaths:Schooling +
#     Alcohol:Polio + Alcohol:Diphtheria + Alcohol:GDP + Hepatitis.B:BMI +
#     Hepatitis.B:Polio + BMI:Schooling + Polio:Diphtheria + Polio:Schooling +
#     Diphtheria:Schooling, data = life_developing)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -15.2724  -2.2296   0.2532   3.1206   8.1124
#
# Coefficients:
#                             Estimate Std. Error t value Pr(>|t|)
# (Intercept)                5.951e+01  4.264e+00  13.956  < 2e-16 ***
# Hepatitis.B               -1.475e-01  1.635e-01  -0.902 0.369035
# BMI                        7.507e-01  1.753e-01   4.282  4.2e-05 ***
# Polio                     -4.572e-01  1.680e-01  -2.722 0.007631 **
# Diphtheria                 3.497e-02  1.866e-01   0.187 0.851743
# I(Polio^2)                 2.150e-03  9.750e-04   2.206 0.029659 *
# infant.deaths:Alcohol     -1.167e-04  3.527e-03  -0.033 0.973683
# Hepatitis.B:infant.deaths  3.653e-03  2.658e-03   1.374 0.172371
# Polio:infant.deaths        1.515e-03  1.386e-03   1.093 0.277185
# Diphtheria:infant.deaths  -4.556e-03  2.642e-03  -1.725 0.087582 .
# infant.deaths:Schooling   -3.255e-03  6.059e-03  -0.537 0.592302
# Polio:Alcohol             -8.656e-03  1.187e-02  -0.729 0.467526
# Diphtheria:Alcohol         3.151e-03  1.186e-02   0.266 0.790918
# Alcohol:GDP                2.661e-05  1.130e-05   2.354 0.020489 *
# Hepatitis.B:BMI           -1.084e-03  1.153e-03  -0.940 0.349648
# Hepatitis.B:Polio          1.736e-03  1.529e-03   1.135 0.259004
# BMI:Schooling             -4.721e-02  1.235e-02  -3.821 0.000229 ***
# Polio:Diphtheria          -2.143e-03  1.587e-03  -1.350 0.179889
# Polio:Schooling            2.438e-02  1.384e-02   1.761 0.081246 .
# Diphtheria:Schooling       1.718e-02  1.321e-02   1.301 0.196228
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 4.788 on 102 degrees of freedom
# Multiple R-squared:  0.7138,	Adjusted R-squared:  0.6605
# F-statistic: 13.39 on 19 and 102 DF,  p-value: < 2.2e-16
# Plot with title “”

# %% [markdown]
# Since there are only developed countries, but there are too many variabels in the AICM model, so we can't implement this model into developed countries.  Then, we choose the simple linear regression model but drop the high colinearity variable $under.five.deaths$.

# %%
lm_developing = lm(Life.expectancy ~ infant.deaths + Alcohol+ Hepatitis.B
                 + BMI + Polio + Diphtheria + GDP + Schooling, data = life_developing)
summary(lm_developing)
plot_residuals(lm_developing, 'lm_developing')
# Out:
# Call:
# lm(formula = Life.expectancy ~ infant.deaths + Alcohol + Hepatitis.B +
#     BMI + Polio + Diphtheria + GDP + Schooling, data = life_developing)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -15.5971  -3.1892   0.8043   3.4462  10.4874
#
# Coefficients:
#                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)    3.970e+01  2.847e+00  13.945  < 2e-16 ***
# infant.deaths -4.001e-03  8.033e-03  -0.498  0.61942
# Alcohol       -4.772e-01  1.699e-01  -2.808  0.00587 **
# Hepatitis.B    1.137e-02  2.946e-02   0.386  0.70021
# BMI            5.071e-02  2.895e-02   1.752  0.08248 .
# Polio          2.629e-02  2.727e-02   0.964  0.33710
# Diphtheria    -4.854e-03  3.729e-02  -0.130  0.89665
# GDP            8.453e-05  7.575e-05   1.116  0.26683
# Schooling      2.172e+00  2.869e-01   7.570 1.09e-11 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 5.364 on 113 degrees of freedom
# Multiple R-squared:  0.6021,	Adjusted R-squared:  0.5739
# F-statistic: 21.37 on 8 and 113 DF,  p-value: < 2.2e-16
# Plot with title “”

# %%
lm_developed = lm(Life.expectancy ~ infant.deaths + Alcohol+ Hepatitis.B
                 + BMI + Polio + Diphtheria + GDP + Schooling, data = life_developed)
summary(lm_developed)
plot_residuals(lm_developed, 'lm_developed')
# Out:
# Call:
# lm(formula = Life.expectancy ~ infant.deaths + Alcohol + Hepatitis.B +
#     BMI + Polio + Diphtheria + GDP + Schooling, data = life_developed)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -6.8284 -1.4583  0.5031  1.6060  4.9925
#
# Coefficients:
#                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)    8.445e+01  2.104e+01   4.015  0.00246 **
# infant.deaths -1.857e+00  1.305e+00  -1.423  0.18522
# Alcohol       -2.455e-01  4.016e-01  -0.611  0.55472
# Hepatitis.B   -9.003e-02  6.228e-02  -1.445  0.17895
# BMI            8.617e-02  5.606e-02   1.537  0.15533
# Polio         -1.026e+00  1.178e+00  -0.872  0.40387
# Diphtheria     1.066e+00  1.113e+00   0.959  0.36038
# GDP            1.081e-04  6.103e-05   1.771  0.10701
# Schooling     -2.632e-01  8.981e-01  -0.293  0.77551
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 3.697 on 10 degrees of freedom
# Multiple R-squared:  0.6714,	Adjusted R-squared:  0.4085
# F-statistic: 2.554 on 8 and 10 DF,  p-value: 0.08319
# Plot with title “”

# %% [markdown]
# Here is the summary of the developed countries and the effects that these diseases and vices have on life expectancy. This R squared is close to 0! My interpretation is that these factors do not affect life expectancy heavily: better healthcare systems and outcomes result in aging-related conditions being more of a factor in affecting life expectancy, rather than diseases that are either cured or well managed in the healthcare system of developed countries. Thus, none of these intercepts are particularly effective in being able to approximate life expectancy in developed countries.

# %% [markdown]
# ## 3 Discussion (5 points)
# State your conclusions regarding the influence of these health and economic factors on life ex-
# pectancy, and summarize the main results supporting your conclusions. Discuss the implications
# of your findings. What are some limitations of the current study? Include a discussion of possible
# violations of model assumptions. What are some possible interactions we ignored?

# %% [markdown]
# ## 4 Lay Abstract (5 points)
# Write a lay abstract (approximately 200 words) that summarizes your research aims and findings
# for a general audience. The target audience is policy makers and scientists with more general
# training, and should not include any mathematical notation or technical terms (e.g., do not say
# “linear regression model”). It is easiest to write this last, but please include this at the beginning
# of your report.
